# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname = 'C:\Windows\Fonts\malgun.ttf').get_name()
rc('font',family=font_name)

from matplotlib.pylab import rcParams
rcParams['font.family'] = 'AppleGothic' #영어 <> maigun Gothic(맑은고딕)
rcParams['figure.figsize'] = 17,8

import warnings
warnings.filterwarnings('ignore')

# %%
red = pd.read_csv('winequality-red.csv',sep=';',encoding='utf-8')
red['type']=0
red.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  type
# 0      9.4        5     0
# 1      9.8        5     0
# ...

# %%
white = pd.read_csv('winequality-white.csv',sep=';',encoding='utf-8')
white['type']=1
white.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality  type
# 0      8.8        6     1
# 1      9.5        6     1
# ...

# %%
red.shape, white.shape
# Out:
# ((1599, 13), (4898, 13))

# %%
wine = pd.concat([red,white], axis=0, ignore_index=True)
wine.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 6492                 24.0                  92.0  0.99114  3.27       0.50
# 6493                 57.0                 168.0  0.99490  3.15       0.46
# 6494                 30.0                 111.0  0.99254  2.99       0.46
# 6495                 20.0                 110.0  0.98869  3.34       0.38
# 6496                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality  type
# ...

# %%
wine.shape
# Out:
# (6497, 13)

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   int64
#  12  type                  6497 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 660.0 KB

# %%
wine.quality.unique()

# %%
# 튜플 정렬 : sorted(tuple.key) method
list(sorted(wine.quality.unique()))
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
wine.quality.value_counts().sort_index()
# Out:
# 3      30
# 4     216
# 5    2138
# 6    2836
# 7    1079
# 8     193
# 9       5
# Name: quality, dtype: int64

# %%
wine.loc[wine.quality==9]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 2373            9.1              0.27         0.45            10.6      0.035
# 2419            6.6              0.36         0.29             1.6      0.021
# 2426            7.4              0.24         0.36             2.0      0.031
# 2475            6.9              0.36         0.34             4.2      0.018
# 3204            7.1              0.26         0.49             2.2      0.032
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 2373                 28.0                 124.0  0.99700  3.20       0.46
# 2419                 24.0                  85.0  0.98965  3.41       0.61
# 2426                 27.0                 139.0  0.99055  3.28       0.48
# 2475                 57.0                 119.0  0.98980  3.28       0.36
# 3204                 31.0                 113.0  0.99030  3.37       0.42
#
#       alcohol  quality  type
# ...

# %% [markdown]
# ### EDA

# %%
wine.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'type'],
#       dtype='object')

# %%
wine.columns = wine.columns.str.replace(' ','_')
wine.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'type'],
#       dtype='object')

# %%
wine.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6497.000000       6497.000000  6497.000000     6497.000000
# mean        7.215307          0.339666     0.318633        5.443235
# std         1.296434          0.164636     0.145318        4.757804
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6497.000000          6497.000000           6497.000000  6497.000000
# mean      0.056034            30.525319            115.744574     0.994697
# std       0.035034            17.749400             56.521855     0.002999
# ...

# %%
wine.groupby('fixed_acidity').quality.describe()
# Out:
#                count  mean       std  min  25%  50%  75%  max
# fixed_acidity
# 3.8              1.0   6.0       NaN  6.0  6.0  6.0  6.0  6.0
# 3.9              1.0   8.0       NaN  8.0  8.0  8.0  8.0  8.0
# 4.2              2.0   5.0  2.828427  3.0  4.0  5.0  6.0  7.0
# 4.4              3.0   7.0  1.000000  6.0  6.5  7.0  7.5  8.0
# 4.5              1.0   5.0       NaN  5.0  5.0  5.0  5.0  5.0
# ...              ...   ...       ...  ...  ...  ...  ...  ...
# 14.3             1.0   6.0       NaN  6.0  6.0  6.0  6.0  6.0
# 15.0             2.0   7.0  0.000000  7.0  7.0  7.0  7.0  7.0
# 15.5             2.0   5.0  0.000000  5.0  5.0  5.0  5.0  5.0
# 15.6             2.0   6.0  1.414214  5.0  5.5  6.0  6.5  7.0
# 15.9             1.0   5.0       NaN  5.0  5.0  5.0  5.0  5.0
#
# [106 rows x 8 columns]

# %%
red_quality = wine[wine.type == 0]
# red_quality = wine.loc[wine.type == 0,'quality']
white_quality = wine[wine.type == 1]

# %%
sns.distplot(red_quality.quality, label = 'red_quality')
sns.distplot(white_quality.quality, label = 'white_quality')
plt.legend()

# %% [markdown]
# ### T 검정
#     두 개의 항목의 차이가 통계적으로 유의한지 알기 위해
#     p-value < 0.05 : 95% 신뢰수준 -> 두 그룹간 통계적으로 유의

# %%
# !pip install statsmodels
import statsmodels.api as sm

# %%
t, pvalue, df=sm.stats.ttest_ind(red_quality, white_quality)

# %%
'T값은 %.3f이고, pvalue는 %.10f' %(t,pvalue)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Study\분석 및 시각화\시각화\5일차\wine.ipynb 셀 22 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Study/%EB%B6%84%EC%84%9D%20%EB%B0%8F%20%EC%8B%9C%EA%B0%81%ED%99%94/%EC%8B%9C%EA%B0%81%ED%99%94/5%EC%9D%BC%EC%B0%A8/wine.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> 'T값은 %.3f이고' %(t)
#
# TypeError: only size-1 arrays can be converted to Python scalars

# %%
wine.corr()
# Out:
#                       fixed_acidity  volatile_acidity  citric_acid  \
# fixed_acidity              1.000000          0.219008     0.324436
# volatile_acidity           0.219008          1.000000    -0.377981
# citric_acid                0.324436         -0.377981     1.000000
# residual_sugar            -0.111981         -0.196011     0.142451
# chlorides                  0.298195          0.377124     0.038998
# free_sulfur_dioxide       -0.282735         -0.352557     0.133126
# total_sulfur_dioxide      -0.329054         -0.414476     0.195242
# density                    0.458910          0.271296     0.096154
# pH                        -0.252700          0.261454    -0.329808
# sulphates                  0.299568          0.225984     0.056197
# alcohol                   -0.095452         -0.037640    -0.010493
# quality                   -0.076743         -0.265699     0.085532
# type                      -0.486740         -0.653036     0.187397
#
# ...

# %%
# 하나의 항목을 기준으로 corr 보고 싶을 때
wine.corrwith(wine.quality).sort_values()
# Out:
# density                -0.305858
# volatile_acidity       -0.265699
# chlorides              -0.200666
# fixed_acidity          -0.076743
# total_sulfur_dioxide   -0.041385
# residual_sugar         -0.036980
# pH                      0.019506
# sulphates               0.038485
# free_sulfur_dioxide     0.055463
# citric_acid             0.085532
# type                    0.119323
# alcohol                 0.444319
# quality                 1.000000
# dtype: float64

# %% [markdown]
# ### 산점도그래프

# %%
# 레드와인 300개, 화이트와인 300개 랜덤 샘플링
def sampling(data,n=300):
    return data.loc[np.random.choice(data.index, replace=False, size=n)]

red = wine[wine.type==0]
white = wine[wine.type==1]

red_sample = sampling(red)
white_sample = sampling(white)

# %%
red_sample.shape, white_sample.shape
# Out:
# ((300, 13), (300, 13))

# %%
wine_sample = pd.concat([red_sample,white_sample],axis=0)
wine_sample.head()
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 488            11.6              0.32         0.55             2.8      0.081
# 236             7.2              0.63         0.00             1.9      0.097
# 1580            7.4              0.35         0.33             2.4      0.068
# 867             6.9              0.51         0.23             2.0      0.072
# 413             9.9              0.40         0.53             6.7      0.097
#
#       free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 488                  35.0                  67.0  1.00020  3.32       0.92
# 236                  14.0                  38.0  0.99675  3.37       0.58
# 1580                  9.0                  26.0  0.99470  3.36       0.60
# 867                  13.0                  22.0  0.99438  3.40       0.84
# 413                   6.0                  19.0  0.99860  3.27       0.82
#
#       alcohol  quality  type
# ...

# %%
sns.pairplot(wine_sample,kind='reg',hue='type',vars=['quality','pH','alcohol','total_sulfur_dioxide']) 
# reg : 회귀분석
# vars : 원하는 변수들 입력
