# %%
# !pip show certifi
# Out:
# Name: certifi
# Version: 2022.9.24
# Summary: Python package for providing Mozilla's CA Bundle.
# Home-page: https://github.com/certifi/python-certifi
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.com
# License: MPL-2.0
# Location: c:\programdata\miniconda3\envs\pythonproject\lib\site-packages
# Requires:
# Required-by: requests

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs
import csv
import requests
import pandas as pd
import re
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities #다음화면으로 빨리 넘어갈때
from selenium.common.exceptions import UnexpectedAlertPresentException #selenium 이용시 Alert을 제어
import urllib.request
import random
from selenium.webdriver.chrome.options import Options

# %%
# view는 스크롤을 계속 내리는 코드를 작성해줘야 됨
# 스크롤을 끝까지 내린 후 링크를 모두 수집
# 수집한 링크를 하나씩 들어가서 데이터 수집
# 월별로 최대 1000개 크롤링 가능

# %%
# 크롤링 시작과 끝 날짜(달 별로 크롤링)
first_days = pd.date_range('2022/01/01','2022/10/31', freq='MS')   # 각 달의 첫 날
last_days = pd.date_range('2022/01/01','2022/10/31', freq='M')  # 각 달의 마지막 날

# keyword_list = ['인스타술집','이색술집','감성술집', '담금술집', '분위기술집', '정글포차', '인테리어술집', '새로운술집', '감성주점', '컨셉술집'] # 검색키워드 추가
# 지역 선정 방법 어떻게??
# keyword를 한줄로 검색해서 크롤링

keyword_main = ['인스타술집','이색술집','감성술집', '컨셉술집']
keyword_sub = ['을지로', '신당']
keyword_list = []
for i in keyword_main:
    for j in keyword_sub:
        keyword_list.append(j+i)
print(keyword_list)
# Out:
# ['을지로인스타술집', '신당인스타술집', '을지로이색술집', '신당이색술집', '을지로감성술집', '신당감성술집', '을지로컨셉술집', '신당컨셉술집']

# %%
# 크롬드라이버 제어
chrome_options = Options()
chrome_options.add_argument('--no-sandbox') #bypass OS security model
chrome_options.add_argument('--disable-dex-shm-usage')#overcome limited resource problems
# options.add_argument('--headless') # 브라우저 백그라운드 모드

chrome_path = 'chromedriver.exe' #현재 컴퓨터의 크롬드라이버 위치

# %%
# 블로그 주소 수집
blog_url_list = []

# 네이버에 키워드 검색
for keyword in keyword_list:
    url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=blog&query={}&oquery={}'.format(keyword, keyword)

    driver = webdriver.Chrome(executable_path=chrome_path, chrome_options=chrome_options)
    driver.implicitly_wait(3)

    driver.get(url)
    time.sleep(3)

    url_want = 990  # 월별 1000개까지만 가능하기 때문에 개수 설정

    driver.find_element('xpath','//*[@id="snb"]/div[1]/div/div[2]/a').click() #검색 옵션 클릭

    # 날짜 지정
    for k in range(len(first_days)):
        try:
            # 시작과 끝의 년월일 설정
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[1]/a[9]/i').click() #직접 입력
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[1]/div/div/div/ul/li[{0}]'.format(first_days.year[k]-2002)).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[{0}]/a'.format(first_days.month[k])).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[{0}]/a'.format(first_days.day[k])).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[1]/span[3]/a').click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[1]/div/div/div/ul/li[{0}]'.format(last_days.year[k]-2002)).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[{0}]/a'.format(last_days.month[k])).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[{0}]/a'.format(last_days.day[k])).click()
            driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[3]/button').click()

            # 스크롤 조작
            last_height = driver.execute_script('return document.body.scrollHeight')
            scroll = (url_want/30)-1    # 한 페이지에 기본으로 30개 글이 나옴
            
            # 스크롤 다운
            for i in range(int(scroll)):
                driver.execute_script('window.scrollTo(0, document.body.scrollHeight)')  # 0부터 끝까지 스크롤 내림
                time.sleep(random.uniform(1,1.7))
                
                new_height = driver.execute_script('return document.body.scrollHeight')
                if(new_height == last_height):
                    break

                last_height = new_height

            soup = bs(driver.page_source, 'lxml')
            blog_url = soup.find_all('a', class_ = 'api_txt_lines total_tit')   # 첫번째 view 제목 class

            # url 주소 수집
            for i in blog_url:
                blog_url_list.append(i['href']) # 주소 수집
            
            print(f'{keyword} 키워드 {first_days.year[k]}년 {first_days.month[k]}월', len(blog_url), '개 블로그 url 주소 수집') 

            driver.execute_script('window.scrollTo(0,0)')   # 스크롤 밑으로 내려가지 않게 해줌

        except:
            pass
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23392\1590242383.py:8: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=chrome_path, chrome_options=chrome_options)
# 을지로인스타술집 키워드 2022년 1월 39 개 블로그 url 주소 수집
# 을지로인스타술집 키워드 2022년 2월 26 개 블로그 url 주소 수집
# 을지로인스타술집 키워드 2022년 3월 21 개 블로그 url 주소 수집
# 을지로인스타술집 키워드 2022년 4월 24 개 블로그 url 주소 수집
# 을지로인스타술집 키워드 2022년 5월 41 개 블로그 url 주소 수집
# 을지로인스타술집 키워드 2022년 6월 60 개 블로그 url 주소 수집
# 을지로인스타술집 키워드 2022년 7월 52 개 블로그 url 주소 수집
# 을지로인스타술집 키워드 2022년 8월 30 개 블로그 url 주소 수집
# 을지로인스타술집 키워드 2022년 9월 46 개 블로그 url 주소 수집
# 을지로인스타술집 키워드 2022년 10월 50 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 1월 30 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 2월 27 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 3월 30 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 4월 42 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 5월 33 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 6월 39 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 7월 50 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 8월 48 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 9월 53 개 블로그 url 주소 수집
# 신당인스타술집 키워드 2022년 10월 49 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 1월 21 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 2월 12 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 3월 19 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 4월 21 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 5월 26 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 6월 32 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 7월 33 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 8월 30 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 9월 21 개 블로그 url 주소 수집
# 을지로이색술집 키워드 2022년 10월 18 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 1월 11 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 2월 2 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 3월 4 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 4월 5 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 5월 6 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 6월 9 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 7월 6 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 8월 5 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 9월 8 개 블로그 url 주소 수집
# 신당이색술집 키워드 2022년 10월 14 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 1월 278 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 2월 244 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 3월 255 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 4월 298 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 5월 372 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 6월 395 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 7월 472 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 8월 474 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 9월 414 개 블로그 url 주소 수집
# 을지로감성술집 키워드 2022년 10월 440 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 1월 27 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 2월 20 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 3월 25 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 4월 26 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 5월 30 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 6월 55 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 7월 33 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 8월 42 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 9월 52 개 블로그 url 주소 수집
# 신당감성술집 키워드 2022년 10월 58 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 1월 98 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 2월 58 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 3월 98 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 4월 87 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 5월 107 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 6월 124 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 7월 147 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 8월 145 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 9월 150 개 블로그 url 주소 수집
# 을지로컨셉술집 키워드 2022년 10월 113 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 1월 13 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 2월 15 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 3월 19 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 4월 16 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 5월 21 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 6월 18 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 7월 21 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 8월 25 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 9월 21 개 블로그 url 주소 수집
# 신당컨셉술집 키워드 2022년 10월 16 개 블로그 url 주소 수집

# %%
len(blog_url_list)
# Out:
# 6415

# %% [markdown]
# ### 강사님 코드

# %%
# # 블로그 주소 수집

# blog_url_list = []

# #네이버에 키워드 검색
# for keyword in keyword_list:
#     url = 'https://search.naver.com/search.naver?sm=tab_hty.top&where=blog&query={}&oquery={}'.format(keyword, keyword)
        
#     driver = webdriver.Chrome(executable_path=chrome_path, chrome_options=chrome_options)
#     driver.implicitly_wait(3)
    
#     driver.get(url)
#     time.sleep(3)
    
#     url_want = 990 #
    
#     driver.find_element('xpath','//*[@id="snb"]/div[1]/div/div[2]/a').click() #검색 옵션 클릭

#     #날짜 지정
#     for k in range(len(first_days)):
#         try:
#             #시작과 끝의 년월일 설정
#             driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[1]/a[9]/i').click() #직접 입력
#             driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[1]/div/div/div/ul/li[{0}]'.format(first_days.year[k]-2002)).click()
#             driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[{0}]/a'.format(first_days.month[k])).click()
#             driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[{0}]/a'.format(first_days.day[k])).click()
#             driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[1]/span[3]/a').click()
#             driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[1]/div/div/div/ul/li[{0}]'.format(last_days.year[k]-2002)).click()
#             driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[2]/div/div/div/ul/li[{0}]/a'.format(last_days.month[k])).click()
#             driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[2]/div[3]/div/div/div/ul/li[{0}]/a'.format(last_days.day[k])).click()
#             driver.find_element('xpath','//*[@id="snb"]/div[2]/ul/li[3]/div/div[2]/div[3]/button').click()            
            
            
#             # 스크롤 조작
#             last_height = driver.execute_script('return document.body.scrollHeight')
            
#             scroll = (url_want/30)-1 #한 페이지에 기본으로 30개 글이 나옴
            
#             # 스크롤 다운
#             for i in range(int(scroll)):
#                 driver.execute_script('window.scrollTo(0,document.body.scrollHeight)')
#                 time.sleep(random.uniform(1,1.7))
                
#                 new_height = driver.execute_script('return document.body.scrollHeight')
                
#                 if new_height == last_height:
#                     break
                    
#                 last_height = new_height
                
                
#             soup = bs(driver.page_source, 'lxml')
#             blog_url = soup.find_all('a',class_='api_txt_lines total_tit')
            
#             # url 주소 수집
#             for i in blog_url:
#                 blog_url_list.append(i['href']) #주소 수집
                
#             print('{0} 키워드 {1}년{2}월'.format(keyword, 
#                                             first_days.year[k], frist_days.month[k]), 
#                   len(blog_url),'개 블로그 url 주소 수집')
            
            
#             driver.execute_script('window.scrollTo(0,0)')
            
#         except:
#             pass

# %%
# 수집 후 url list 중복 확인
real_list = set(blog_url_list)
blog_url_list = list(real_list)
len(blog_url_list)
# Out:
# 5523

# %%
# 파일 저장(블로그 주소)
k = pd.DataFrame(blog_url_list)
k.to_csv('url_list_술집.csv', encoding='utf-8-sig')

# %%
# 블로그 크롤링
url = pd.read_csv('url_list_술집.csv')
blog_url_list = list(url['0'])

# %%
no_naver_blog1=[]

start = time.time()


time_list = [] #시간
review_list = [] #리뷰
comment_list = [] #댓글
like_list = [] #좋아요수
url_list = [] #url주소
count = 0

driver = webdriver.Chrome(executable_path=chrome_path, chrome_options=chrome_options) #크롬 드라이버 위치만 바꿔주시면 됩니다.
for url in blog_url_list: #기본적으로 고치지 않으시지만, n번째 크롤링에서 멈췄다면, blog_url_list를 blog_url_list[n:]으로 고칩니다.
    if 'naver' in url: #네이버 블로그만 수집(다른 사이트가 섞이면 크롤링 에러가 남)
    
        count += 1
        driver.get(url) #url 하나씩 글을 수집할꺼야
        time.sleep(1)

        try:
            # 전체 본문 가지고 와서
            driver.switch_to.frame('mainFrame') #네이버는 mainFrame을 바꿔줘야 수집이 됌
            time.sleep(1)
        
            soup = bs(driver.page_source, 'lxml') #뷰티풀숩을 이용해서 구문 분석(lxml 파싱 이용. 모든 테그에서 데이터를 추출위함)
            postview = soup.find('div', attrs={'id': re.compile('post-view.+')}).get_text()

            reg = re.compile(r'[\s+]') #r은 raw string. \s+는 공백문자
            postview_reg = reg.sub(' ',postview) #공백을 띄어쓰기로 대치해서 본문 글 수집
            try:
                # 좋아요수
                like = driver.find_element("xpath", "//span[@class='u_likeit_list_btn _button btn_sympathy pcol2 off']/em[@class='u_cnt _count']")
                like = like.text
            except:
                like = [] #좋아요 없으면 빈 리스트
            
            try:
                timeline = driver.find_element("xpath", "//span[@class='se_publishDate pcol2']") #수정 안 한 경우
        
            except:
                timeline = driver.find_element("xpath", "//p[@class='date fil5 pcol2 _postAddDate']") #수정 한 경우
            timeline = timeline.text

            try:
                driver.find_element(By.CSS_SELECTOR,'span.btn_arr').click() #댓글 내리는 버튼(태그명.클래스선택자)
                #driver.find_element_by_css_selector('span.btn_arr').click()
                time.sleep(1.7)

                comment_blog = []
                comment = driver.find_element(By.CSS_SELECTOR,'span.u_cbox_contents') #댓글
                #comment = driver.find_elements_by_css_selector('span.u_cbox_contents')
                for i in comment: #댓글 수집
                    com = str(i.text) #
                    com = reg.sub(' ',com) 
                    comment_blog.append(([com]))
            except: 
                comment_blog = []
             
            time_list.append(timeline)
            review_list.append(postview_reg)
            comment_list.append(comment_blog)
            url_list.append(url)
            like_list.append(like)
            time.sleep(random.uniform(1,1.6))
        except UnexpectedAlertPresentException:
            pass
    else:
        no_naver_blog1.append(url)
        print('네이버 블로그 아닌 url: ',url)
        
    if count%200 ==0:
        print('{}개 블로그 크롤링 완료'.format(count))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_23392\2760139126.py:13: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(executable_path=chrome_path, chrome_options=chrome_options) #크롬 드라이버 위치만 바꿔주시면 됩니다.
# 네이버 블로그 아닌 url:  https://coolnjazzylife.tistory.com/3432
# 네이버 블로그 아닌 url:  https://boodraw.tistory.com/entry/%ED%95%9C%EB%82%A8%EB%8F%99%ED%95%9C%EA%B0%95%EC%A7%84%EC%8A%A4%EC%8B%9C-%EB%A7%9B%EC%A7%91-%EC%8A%A4%EC%8B%9C%EC%8A%A4%EC%99%80
# 200개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://unfreelancer.tistory.com/110
# 네이버 블로그 아닌 url:  https://jeffreysays.tistory.com/6832
# 네이버 블로그 아닌 url:  https://sangmusang.tistory.com/entry/%ED%94%84%EB%A6%AC%EB%AF%B8%EC%97%84-%ED%95%9C%EB%8F%88%EB%A7%8C-%EA%B3%A0%EC%A7%91%ED%95%98%EB%8A%94-%EA%B3%A0%EA%B8%B0-%EB%A7%9B%EC%A7%91-%EC%8B%A0%EB%8F%84%EC%84%B8%EA%B8%B0-%EB%8B%A4%EB%85%80%EC%99%94%EC%96%B4%EC%9A%94
# 400개 블로그 크롤링 완료
# 600개 블로그 크롤링 완료
# 800개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://mltr1017.tistory.com/601
# 네이버 블로그 아닌 url:  https://kona.tistory.com/644
# 1000개 블로그 크롤링 완료
# 1200개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://unfreelancer.tistory.com/106
# 1400개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https
 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://harrison-jo.tistory.com/entry/%EB%82%98%EA%B2%BD%EC%9B%90-%EB%82%98%EC%9D%B4-%EA%B3%A0%ED%96%A5-%ED%95%99%EB%A0%A5-%EC%9D%B4%EB%A0%A5-%EC%9E%AC%EC%82%B0-%ED%94%84%EB%A1%9C%ED%95%84
# 5400개 블로그 크롤링 완료
# 네이버 블로그 아닌 url:  https://hyggehaja.tistory.com/entry/%EB%A7%9B%EC%A7%91%EC%B0%BE%EA%B8%B0-%ED%94%BC%EC%9E%90%EC%99%80-%EB%96%A1%EB%B3%B6%EC%9D%B4-%EC%A4%91%EC%97%90-%EA%B3%A0%EB%A5%B4%EA%B8%B0-%ED%9E%98%EB%93%A4%EB%A9%B4-%ED%95%9C%EB%B2%88%EC%97%90-%EB%A8%B9%EC%9E%90-%EC%B2%AD%EB%85%84-%EB%8B%A4%EB%B0%A9

# %%
len(time_list)
# Out:
# 5475

# %%
data = {'time':time_list, 'review':review_list, 'comment':comment_list, 'like':like_list, 'url':url_list}
df = pd.DataFrame(data)
print('크롤링 소요 시간: ', time.time()-start)
print('총 {}개 블로그 크롤링 완료'.format(count))
# Out:
# 크롤링 소요 시간:  76612.07729363441
# 총 5475개 블로그 크롤링 완료

# %%
# 파일 저장(블로그 주소)
d = pd.DataFrame(df)
d.to_csv('네이버 뷰 술집.csv', encoding='utf-8-sig')

# %%
df
# Out:
#                      time                                             review  \
# 0       2022. 5. 8. 14:08          Tasty Road     을지로3가술집 "아트몬스터 을지로점", 힙...
# 1     2022. 10. 31. 10:05          맛집/술     강남/ 강남역 맥주집 을지로 가맥 랭맥       H...
# 2       2022. 2. 4. 16:44          백수 일상     [백수일기] 뒤죽박죽 2021년도 마지막 일기였던것...
# 3      2022. 7. 24. 20:45             [블챌] 주간일기 챌린지     [2022 7월 셋째주] 핫플탐...
# 4      2022. 5. 10. 16:27          먹방찍기욧     인스타감성 흐르는 건대 파스타 맛집       서울...
# ...                   ...                                                ...
# 5470    2022. 5. 27. 8:04          나를 많이 흔든 곳     울산 삼산동 술집 : 인스타 감성 뿜뿜 와...
# 5471    2022. 7. 4. 20:00          냐미     신당역 칵테일bar 주신당  이색칵테일바 추천!     ...
# 5472   2022. 4. 26. 12:15          일상을올려요     어느덧 4월말이라니!       경으니으니   ・...
# 5473    2022. 8. 25. 9:27             맛집     [을지로 맛집]을지 장만옥(홍콩감성 제대로 즐기는 ...
# 5474   2022. 8. 28. 15:27             [블챌] 주간일기 챌린지     을지로와인바 아스론가_조용하고 ...
#
#      comment like                                              url
# 0         []   []     https://blog.naver.com/glass325/222724760862
# 1         []   10  https://blog.naver.com/h_annah1226/222915445656
# 2         []   12      https://blog.naver.com/ppp4112/222638850897
# 3         []    2      https://blog.naver.com/hu_some/222827161667
# 4         []    3     https://blog.naver.com/newbea44/222727484006
# ...      ...  ...                                              ...
# 5470      []   14    https://blog.naver.com/hongyoumi/222748484932
# 5471      []    7     https://blog.naver.com/gywn8617/222800060567
# 5472      []   11      https://blog.naver.com/epsqj08/222711909012
# 5473      []   []     https://blog.naver.com/dhluxury/222857597110
# 5474      []    3    https://blog.naver.com/qnwkalswn/222860224768
#
# [5475 rows x 5 columns]
