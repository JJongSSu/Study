# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time
from tqdm import tqdm_notebook as tqdm

# %%
driver = webdriver.Chrome(ChromeDriverManager().install())

# %%
driver.get('https://www.musinsa.com/app/')

# %%
driver.maximize_window()

# %%
from bs4 import BeautifulSoup as bs
import requests as req
from selenium.webdriver.common.keys import Keys

# %%
finding = driver.find_element_by_css_selector('#search_query')
finding.click()
finding.send_keys('향수')
finding.send_keys(Keys.ENTER)
time.sleep(1)

# %%
botton = driver.find_element_by_xpath('/html/body/div[2]/div[3]/div[3]/button[3]')
botton.click()

# %%
botton2 = driver.find_element_by_xpath('/html/body/div[2]/div[3]/section/div[3]/div/section[1]/header/a/h2')
botton2.click()

# %%
# title_list = []
# volum_list = []
# price_list = []
# stars_list = []
# heart_list = []

# for i in tqdm(range(24)):
#     page = 'https://www.musinsa.com/search/musinsa/goods?q=%ED%96%A5%EC%88%98&list_kind=small&sortCode=pop&sub_sort=&page={}&display_cnt=0&saleGoods=&includeSoldOut=&setupGoods=&popular=&category1DepthCode=&category2DepthCodes=&category3DepthCodes=&selectedFilters=&category1DepthName=&category2DepthName=&brandIds=&price=&colorCodes=&contentType=&styleTypes=&includeKeywords=&excludeKeywords=&originalYn=N&tags=&campaignId=&serviceType=&eventType=&type=&season=&measure=&openFilterLayout=N&selectedOrderMeasure=&shoeSizeOption=&groupSale=&d_cat_cd=&attribute='.format(i)
#     driver.get(page)
#     time.sleep(2)

#     title = driver.find_elements_by_css_selector('p.item_title > a')
#     volum = driver.find_elements_by_css_selector('p.list_info > a')
#     price = driver.find_elements_by_css_selector('div.article_info > p.price')
#     stars = driver.find_elements_by_css_selector('p.point > span.count')
#     heart = driver.find_elements_by_css_selector('p.txt_cnt_like')
#     for i in title:
#         title_list.append(i.text)
#     for i in volum:
#         volum_list.append(i.text)
#     for i in price:
#         price_list.append(i.text)
#     for i in stars:
#         stars_list.append(i.text)
#     for i in heart:
#         heart_list.append(i.text)
#     time.sleep(2)



# len(title_list),len(volum_list),len(price_list),len(stars_list),len(heart_list)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11596\3423450199.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(24)):
#   0%|          | 0/24 [00:00<?, ?it/s]
# (2346, 2220, 2220, 1142, 2160)

# %%
# total_list = []
# for i in tqdm(range(24)):
#     page = 'https://www.musinsa.com/search/musinsa/goods?q=%ED%96%A5%EC%88%98&list_kind=small&sortCode=pop&sub_sort=&page={}&display_cnt=0&saleGoods=&includeSoldOut=&setupGoods=&popular=&category1DepthCode=&category2DepthCodes=&category3DepthCodes=&selectedFilters=&category1DepthName=&category2DepthName=&brandIds=&price=&colorCodes=&contentType=&styleTypes=&includeKeywords=&excludeKeywords=&originalYn=N&tags=&campaignId=&serviceType=&eventType=&type=&season=&measure=&openFilterLayout=N&selectedOrderMeasure=&shoeSizeOption=&groupSale=&d_cat_cd=&attribute='.format(i)
#     driver.get(page)
#     soup = bs(driver.page_source, 'html.parser')
#     total = soup.select('div.li_inner')
#     total_list.append(total)
# len(total_list)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11596\977029539.py:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(24)):
#   0%|          | 0/24 [00:00<?, ?it/s]
# 24

# %%
total_list = []
brand_list = []
title_list = []
price_list = []
stars_list = []
heart_list = []

for i in tqdm(range(24)):
    page = 'https://www.musinsa.com/search/musinsa/goods?q=%ED%96%A5%EC%88%98&list_kind=small&sortCode=pop&sub_sort=&page={}&display_cnt=0&saleGoods=&includeSoldOut=&setupGoods=&popular=&category1DepthCode=&category2DepthCodes=&category3DepthCodes=&selectedFilters=&category1DepthName=&category2DepthName=&brandIds=&price=&colorCodes=&contentType=&styleTypes=&includeKeywords=&excludeKeywords=&originalYn=N&tags=&campaignId=&serviceType=&eventType=&type=&season=&measure=&openFilterLayout=N&selectedOrderMeasure=&shoeSizeOption=&groupSale=&d_cat_cd=&attribute='.format(i)
    driver.get(page)
    time.sleep(2)

    soup = bs(driver.page_source, 'html.parser')
    total = soup.select('ul.snap-article-list.boxed-article-list.article-list.center.list.goods_small_media8 > li.li_box')

    for i in tqdm(range(len(total))):
        brand = total[i].select('p.item_title > a')[0].text
        title = total[i].select('p.list_info > a')[0].text
        price = total[i].select('p.price')[0].text

        # try:
        #     stars = total[i].select('p.point > span.count')[0].text
        # except:
        #     stars = 0

        # try:
        #     heart = total[i].select('p.txt_cnt_like')[0].text
        # except:    
        #     heart = 0
        
        brand_list.append(brand)
        title_list.append(title)  
        price_list.append(price)
        # if(stars in total): 
        #     Image = driver.find_element_by_css_selector('img.lazyload lazy')
        #     Image.click()
        #     stars = driver.find_element_by_css_selector('p.product_article_contents > span.prd-score__rating')
        #     stars_list.append(stars)
        # elif(heart in total):
        #     heart_list.append(heart)
        # else:
        #     pass
        time.sleep(2)

    total_list.append(total)

len(total_list), len(brand_list), len(title_list), len(price_list), len(stars_list), len(heart_list)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11596\2645342626.py:8: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(24)):
#   0%|          | 0/24 [00:00<?, ?it/s]
# C:\Users\user\AppData\Local\Temp\ipykernel_11596\2645342626.py:16: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(len(total))):
# ...
#   0%|          | 0/88 [00:00<?, ?it/s]
# (24, 2158, 2158, 2158, 0, 0)

# %%
total[0]
stars = total[0].select('p.point > span.count')
heart = total[0].select('p.txt_cnt_like')
for i in heart:
    print(i.text)
# Out:
#  6

# %%
data = {'브랜드':brand_list,'상품명':title_list,'가격':price_list}
musinsa_data = pd.DataFrame(data)
musinsa_data
# Out:
#            브랜드                                                상품명  \
# 0           클린  \n                            \n              ...
# 1     무신사 스탠다드  \n                            \n              ...
# 2          포맨트  \n                            \n              ...
# 3           클린  \n                            \n              ...
# 4           랑방  \n                            \n              ...
# ...        ...                                                ...
# 2153        머지  \n                            \n              ...
# 2154        머지  \n                            \n              ...
# 2155       메리뮤  \n                            \n              ...
# 2156        펜세  \n                            \n              ...
# 2157      딥퍼랑스  \n                            \n              ...
#
#                                                      가격
# 0               \n93,000원 49,900원\n
# 1               \n19,900원 16,890원\n
# 2               \n62,000원 51,500원\n
# ...

# %%
page = 'https://www.musinsa.com/search/musinsa/goods?q=%ED%96%A5%EC%88%98&list_kind=small&sortCode=pop&sub_sort=&page=1&display_cnt=0&saleGoods=&includeSoldOut=&setupGoods=&popular=&category1DepthCode=&category2DepthCodes=&category3DepthCodes=&selectedFilters=&category1DepthName=&category2DepthName=&brandIds=&price=&colorCodes=&contentType=&styleTypes=&includeKeywords=&excludeKeywords=&originalYn=N&tags=&campaignId=&serviceType=&eventType=&type=&season=&measure=&openFilterLayout=N&selectedOrderMeasure=&shoeSizeOption=&groupSale=&d_cat_cd=&attribute='
soup = bs(driver.page_source, 'html.parser')
total = soup.select('ul.snap-article-list.boxed-article-list.article-list.center.list.goods_small_media8 > li.li_box')
total
# Out:
# [<li class="li_box">
#  <div class="icon_new">SALE 46%</div>
#  <div alt="12179" class="box-icon-right">
#  </div>
#  <div class="icon_group">
#  <ul>
#  <li class="icon_life sight_out" title="라이프">라이프</li>
#  </ul>
#  </div>
#  <div class="li_inner">
#  <div class="list_img">
# ...

# %%
total[7].select('p.price')[0].text
# Out:
# '\n46,000원 41,400원\n                    '

# %%
stars_list = []
heart_list = []

for i in tqdm(range(1)):
    page = 'https://www.musinsa.com/search/musinsa/goods?q=%ED%96%A5%EC%88%98&list_kind=small&sortCode=pop&sub_sort=&page={}&display_cnt=0&saleGoods=&includeSoldOut=&setupGoods=&popular=&category1DepthCode=&category2DepthCodes=&category3DepthCodes=&selectedFilters=&category1DepthName=&category2DepthName=&brandIds=&price=&colorCodes=&contentType=&styleTypes=&includeKeywords=&excludeKeywords=&originalYn=N&tags=&campaignId=&serviceType=&eventType=&type=&season=&measure=&openFilterLayout=N&selectedOrderMeasure=&shoeSizeOption=&groupSale=&d_cat_cd=&attribute='.format(i)
    driver.get(page)
    time.sleep(2)

    for i in tqdm(range(len(total))):
        Image = driver.find_elements_by_css_selector('img.lazyload.lazy')
        Image[i].click()
        try:
            stars = driver.find_element_by_css_selector('a.prd-score__link > span.prd-score__rating')
            stars_list.append(stars.text)
        except:
            stars = '0'
            stars_list.append(stars)

        try:
            heart = driver.find_element_by_css_selector('span.prd_like_cnt')
            heart_list.append(heart.text)
        except:    
            heart = '0'
            heart_list.append(heart)
            time.sleep(2)
        driver.back()
        time.sleep(2)

len(stars_list), len(heart_list)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_11596\1953469857.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(1)):
#   0%|          | 0/1 [00:00<?, ?it/s]
# C:\Users\user\AppData\Local\Temp\ipykernel_11596\1953469857.py:9: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(len(total))):
#   0%|          | 0/88 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Study\데이터 수집, 웹 개요\4일차\mbti.ipynb 셀 16 in <cell line: 4>()
# ...

# %%
stars_list, heart_list
# Out:
# (['4.9', '4.8'], ['4,438', '2,156'])

# %%
heart = driver.find_element_by_css_selector('span.prd_like_cnt')
heart.text
# Out:
# '2,156'

# %%
Image = driver.find_elements_by_css_selector('img.lazyload.lazy')
Image[0].click()

# %%
stars = driver.find_element_by_css_selector('a.prd-score__link > span.prd-score__rating')
stars.text
# Out:
# '4.8'

# %%
len(heart_list)
# Out:
# 88
