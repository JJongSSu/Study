# %%
# !pip install bs4

# %%
# 태그 찾기
soup.select("tag_name")

# 특정 태그와 class
# 중복되는 태그 구분
soup.select("tag_name.class_name")

# 하위 태그가 많을 때
soup.select("tag > 하위tag_name")
soup.select("tag.class_name > 하위tag_name")

# %%
from bs4 import BeautifulSoup as bs

# %%
import requests as req

# %%
res = req.get('http://www.naver.com')

# %%
res.text
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네
# ...

# %%
soup = bs(res.text, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
naver = soup.select("a.nav")
naver
# Out:
# [<a class="nav" data-clk="svc.mail" href="https://mail.naver.com/"><i class="ico_mail"></i>메일</a>,
#  <a class="nav" data-clk="svc.cafe" href="https://section.cafe.naver.com/">카페</a>,
#  <a class="nav" data-clk="svc.blog" href="https://section.blog.naver.com/">블로그</a>,
#  <a class="nav" data-clk="svc.kin" href="https://kin.naver.com/">지식iN</a>,
#  <a class="nav shop" data-clk="svc.shopping" href="https://shopping.naver.com/"><span class="blind">쇼핑</span></a>,
#  <a class="nav shoplive" data-clk="svc.shoppinglive" href="https://shoppinglive.naver.com/home"><span class="blind">쇼핑LIVE</span></a>,
#  <a class="nav" data-clk="svc.pay" href="https://order.pay.naver.com/home">Pay</a>,
#  <a class="nav" data-clk="svc.tvcast" href="https://tv.naver.com/"><i class="ico_tv"></i>TV</a>,
#  <a class="nav" data-clk="svc.dic" href="https://dict.naver.com/">사전</a>,
#  <a class="nav" data-clk="svc.news" href="https://news.naver.com/">뉴스</a>,
# ...

# %%
# content 뽑을 때
# naver type이 list이기 때문에 index 사용가능
naver[0].text
# Out:
# '메일'

# %%
naver[1].text
# Out:
# '카페'

# %%
for i in naver:
    print(i.text)
# Out:
# 메일
# 카페
# 블로그
# 지식iN
# 쇼핑
# 쇼핑LIVE
# Pay
# TV
# 사전
# 뉴스
# 증권
# 부동산
# 지도
# VIBE
# 도서
# 웹툰

# %%
# naver 코스피 [종목명, 현재가]
res1 = req.get("https://finance.naver.com/sise/sise_quant.naver")
soup1 = bs(res1.text, 'html.parser')
title = soup1.select("a.tltle")
price = soup1.select("td.number")

# %%
len(title)
# Out:
# 100

# %%
title_list = []
for i in title:
    title_list.append(i.text)

# %%
len(price)
# Out:
# 1000

# %%
price_raw_list = []
for i in price:
    price_raw_list.append(i.text)

# %%
price_list = []
for i in range(0,1000):
    if (i % 10 == 0):
        a = price_raw_list[i]
        price_list.append(a)
price_list
# Out:
# ['3,075',
#  '145',
#  '4,835',
#  '15,070',
#  '4,845',
#  '58,000',
#  '165',
#  '8,870',
#  '788',
#  '17,500',
#  '100',
#  '9,940',
#  '125',
#  '27,950',
#  '2,745',
#  '1,685',
#  '2,415',
#  '52,400',
#  '3,005',
#  '5,140',
#  '53,000',
#  '295',
#  '14,400',
#  '2,300',
#  '18,000',
#  '27,950',
#  '1,130',
#  '485',
#  '76,800',
#  '21,000',
#  '1,840',
#  '31,800',
#  '110',
#  '3,225',
#  '3,245',
#  '1,210',
#  '36,000',
#  '30,800',
#  '14,990',
#  '2,800',
#  '93,700',
#  '7,230',
#  '5,680',
#  '2,475',
#  '20,380',
#  '11,700',
#  '4,670',
#  '2,990',
#  '26,350',
#  '71',
#  '11,355',
#  '101,275',
#  '6,200',
#  '10,600',
#  '69,500',
#  '5,530',
#  '22,900',
#  '5,390',
#  '16,200',
#  '278',
#  '1,910',
#  '1,275',
#  '4,315',
#  '10,800',
#  '3,415',
#  '8,480',
#  '1,300',
#  '5,010',
#  '38,850',
#  '1,135',
#  '26,250',
#  '2,210',
#  '4,835',
#  '50,100',
#  '6,465',
#  '5,410',
#  '80,500',
#  '2,405',
#  '1,685',
#  '1,335',
#  '178,500',
#  '14,215',
# ...

# %%
len(price_list)
# Out:
# 100

# %%
price_list = []
for i in range(0,1000):
    if (i % 10 == 0):
        price_list.append(price[i].text)
price_list
# Out:
# ['3,075',
#  '145',
#  '4,835',
#  '15,070',
#  '4,845',
#  '58,000',
#  '165',
#  '8,870',
#  '788',
#  '17,500',
#  '100',
#  '9,940',
#  '125',
#  '27,950',
#  '2,745',
#  '1,685',
#  '2,415',
#  '52,400',
#  '3,005',
#  '5,140',
#  '53,000',
#  '295',
#  '14,400',
#  '2,300',
#  '18,000',
#  '27,950',
#  '1,130',
#  '485',
#  '76,800',
#  '21,000',
#  '1,840',
#  '31,800',
#  '110',
#  '3,225',
#  '3,245',
#  '1,210',
#  '36,000',
#  '30,800',
#  '14,990',
#  '2,800',
#  '93,700',
#  '7,230',
#  '5,680',
#  '2,475',
#  '20,380',
#  '11,700',
#  '4,670',
#  '2,990',
#  '26,350',
#  '71',
#  '11,355',
#  '101,275',
#  '6,200',
#  '10,600',
#  '69,500',
#  '5,530',
#  '22,900',
#  '5,390',
#  '16,200',
#  '278',
#  '1,910',
#  '1,275',
#  '4,315',
#  '10,800',
#  '3,415',
#  '8,480',
#  '1,300',
#  '5,010',
#  '38,850',
#  '1,135',
#  '26,250',
#  '2,210',
#  '4,835',
#  '50,100',
#  '6,465',
#  '5,410',
#  '80,500',
#  '2,405',
#  '1,685',
#  '1,335',
#  '178,500',
#  '14,215',
# ...

# %%
import pandas as pd

# %%
# data table 만들 때 길이가 동일해야 가능
data = {'종목명':title_list,'현재가':price_list}

# %%
kospi = pd.DataFrame(data)
kospi
# Out:
#                        종목명     현재가
# 0         KODEX 200선물인버스2X   3,075
# 1   삼성 인버스 2X WTI원유 선물 ETN     145
# 2        KODEX 코스닥150선물인버스   4,835
# 3               KODEX 레버리지  15,070
# 4                KODEX 인버스   4,845
# ..                     ...     ...
# 95                 삼성엔지니어링  10,055
# 96                   조광페인트  40,750
# 97                   HSD엔진   8,040
# 98                    명신산업   4,390
# 99     TIGER 미국필라델피아반도체나스닥  24,300
#
# [100 rows x 2 columns]

# %%
# 엑셀파일로 저장
kospi.to_excel('코스피지수.xlsx', encoding='utf-8-sig')
# utf-8-sig / euc-kr
