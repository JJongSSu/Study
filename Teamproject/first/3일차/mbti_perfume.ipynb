# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
from tqdm import tqdm_notebook as tqdm

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname = 'C:\Windows\Fonts\malgun.ttf').get_name()
rc('font',family=font_name)

import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('향수사이트.csv',encoding='utf-8')

# %%
data
# Out:
#       Unnamed: 0     구분                      이름       브랜드  \
# 0              0   Best        조말론 블랙베리 앤 베이 코롱       조말론
# 1              1   Best      산타마리아노벨라 프리지아 50ml  산타마리아노벨라
# 2              2   Best  르라보 어나더 13 오 드 퍼퓸 50ml       르라보
# 3              3   Best   르라보 상탈 33 오 드 퍼퓸 50ml       르라보
# 4              4   Best    톰포드 오드우드 오 드 퍼퓸 50ml       톰포드
# ...          ...    ...                     ...       ...
# 3014        3014  Women          더 에어리 톤업 크림 2종        머지
# 3015        3015  Women  CONTOUR SHADING 컨투어 쉐딩      쓰리씨이
# 3016        3016  Women       소프트 터치 리퀴드 블러셔 3종        머지
# 3017        3017  Women        더 퍼스트 크리미 컨실러 5종        머지
# 3018        3018  Women      인샤워 바디 퍼퓸 2종 250ml      바디홀릭
#
#                                               설명        가격   평점   하트
# 0            유기농으로 키운 블랙베리의 건강한 맛을 그대로 재현한 베스트셀러   83,800원  4.8  NaN
# 1                      새하얀 수건을 개어놓은 듯한 고혹적인 비누향기  103,500원  4.8  NaN
# 2                 바닐라와 동물적인 암브레트 씨드에서 주는 우디한 살내음  220,000원  5.0  NaN
# 3     짙은 고동나무와 푸릇한 파피루스가 울창하게 심어져 있는 오스트레일리아의 숲속  220,000원  4.9  NaN
# 4                  오우드의 성숙함을 극대화, 톰포드 클래식 섹시의 정수  265,000원  4.8  NaN
# ...                                          ...       ...  ...  ...
# 3014                                         NaN   14,900원  NaN  NaN
# 3015                                         NaN   21,600원  NaN  NaN
# 3016                                         NaN   12,900원  NaN  NaN
# 3017                                         NaN    9,800원  NaN  NaN
# 3018                                         NaN   13,800원  NaN  NaN
#
# [3019 rows x 8 columns]

# %%
data.loc[data.이름.str.contains('프루티')]
# Out:
#       Unnamed: 0     구분                                             이름    브랜드  \
# 1421        1421  Women       [보나파르트] 프루티우디 상쾌한 카리스마 명품 니치 남성용 향수 32ML    지땅느
# 1422        1422  Women       [켈리포니아] 프루티우디 후레쉬블랙베리 명품 니치 남여공용 향수 32ML    지땅느
# 1449        1449  Women        [프루티플로랄] 프루티플로럴 달달상큼한 명품 니치 여성용 향수 32ML    지땅느
# 1455        1455  Women          [시즌스] 프루티플로럴 코사무이풍 명품 니치 남여공용 향수 32ML    지땅느
# 1561        1561  Women       [보나파르트] 프루티우디 상쾌한 카리스마 명품 니치 남성용 향수 32ML    지땅느
# 1562        1562  Women       [켈리포니아] 프루티우디 후레쉬블랙베리 명품 니치 남여공용 향수 32ML    지땅느
# 1568        1568  Women        [프루티플로랄] 프루티플로럴 달달상큼한 명품 니치 여성용 향수 32ML    지땅느
# 1571        1571  Women      [머스키센슈얼] 프루티시프레 가을향 그윽한 명품 니치 여성용 향수 32ML    지땅느
# 1578        1578  Women          [시즌스] 프루티플로럴 코사무이풍 명품 니치 남여공용 향수 32ML    지땅느
# 1689        1689  Women                                포켓 퍼퓸 프루티솝 18ml  마이달리아
# 1728        1728  Women            [체리쉬] 프루티 러블리 달콤한 명품 니치 여성용 향수 32ML    지땅느
# 1904        1904  Women       [베리스위티] 프루티바닐릭 산딸기 카라멜 명품 니치 여성용 향수 32ML    지땅느
# 2002        2002  Women       [허니피치] 프루티플로럴 복숭아와 허니 명품 니치 남여공용 향수 32ML    지땅느
# 2004        2004  Women         [러블리] 프루티플로럴 물결치는플로럴 명품 니치 여성용 향수 32ML    지땅느
# 2031        2031  Women                 [프레쉬 프루티] 싱글퍼퓸 EDP 8ml (2종 택1)    클라엘
# 2101        2101  Women      [바닐라블랙베리] 프루티 바닐라 라즈베리 명품 니치 남여공용 향수 32ML    지땅느
# 2117        2117  Women                          몽탈 프리티 프루티 오드퍼퓸 100ml     몽탈
# 2183        2183  Women       [슈가씨클라멘] 시트러스프루티 청포도샴페인 명품니치 남여공용향수 32ML    지땅느
# 2202        2202  Women  [팬시스프링] 프루티시트러스 새큼한 화이트머스키 명품 니치 남여공용 향수 32ML    지땅느
# 2203        2203  Women    [프리지아페어] 프루티플로럴 새콤하고신선한꽃 명품 니치 남여공용 향수 32ML    지땅느
# 2252        2252  Women                          몽탈 프리티 프루티 오드퍼퓸 100ml     몽탈
# 2288        2288  Women       [슈가씨클라멘] 시트러스프루티 청포도샴페인 명품니치 남여공용향수 32ML    지땅느
#
#        설명       가격   평점   하트
# 1421  NaN  29,000원  0.0    8
# 1422  NaN  29,000원  0.0    5
# 1449  NaN  29,000원  5.0   22
# 1455  NaN  29,000원  5.0  249
# 1561  NaN  29,000원  0.0    5
# 1562  NaN  29,000원  0.0    9
# 1568  NaN  29,000원  4.9  121
# 1571  NaN  29,000원  4.9   72
# 1578  NaN  29,000원  0.0    6
# 1689  NaN  11,900원  0.0    9
# 1728  NaN  29,000원  0.0    4
# 1904  NaN  29,000원  0.0    4
# 2002  NaN  29,000원  0.0  NaN
# 2004  NaN  29,000원  5.0   26
# 2031  NaN  17,000원  0.0    3
# 2101  NaN  29,000원  0.0  NaN
# 2117  NaN  30,000원  5.0   10
# 2183  NaN  29,000원  4.0   31
# 2202  NaN  29,000원  0.0    2
# 2203  NaN  29,000원  0.0    2
# 2252  NaN  30,000원  0.0   13
# 2288  NaN  29,000원  0.0    3

# %%
data.loc[data.이름.str.contains('시트러스')]
# Out:
#       Unnamed: 0      구분                                             이름  \
# 285          285  Unisex                     록시땅 시트러스 버베나 오 드 뚜왈렛 100ml
# 1342        1342   Women                     오 드 퍼퓸 50ml 아로마틱 시트러스 니치향수
# 1419        1419   Women       [아쿠아로얄] 시트러스워터리오리엔탈푸제아 명품 니치 남성용 향수 32ML
# 1452        1452   Women     [포멜로] 시트러스 자몽의상큼쌉스름 스포티 명품 니치 남여공용 향수 32ML
# 1456        1456   Women      [버베나] 시트러스허브 레몬우디 상큼한 명품 니치 남녀 공용 향수 32ML
# 1543        1543   Women            [얼그레이큐커미] 시트러스우디 명품 니치 남여공용 향수 32ML
# 1559        1559   Women       [아쿠아로얄] 시트러스워터리오리엔탈푸제아 명품 니치 남성용 향수 32ML
# 1572        1572   Women        [오렌지베르가못] 시트러스 스위트레몬 명품 니치 남여공용 향수 32ML
# 1575        1575   Women     [포멜로] 시트러스 자몽의상큼쌉스름 스포티 명품 니치 남여공용 향수 32ML
# 1661        1661   Women    [라보헤미아] 우디시트러스 은은한 바닐라우디 명품 니치 남여공용 향수 32ML
# 1750        1750   Women     [앰파이어] 시트러스우디 고급진 고풍스러움 명품 니치 남여공용 향수 32ML
# 1803        1803   Women     [앰파이어] 시트러스우디 고급진 고풍스러움 명품 니치 남여공용 향수 32ML
# 1813        1813   Women           [그레이프프르트] 시트러스 자몽 명품 니치 남여공용 향수 32ML
# 1814        1814   Women      [센슈얼로즈] 시트러스플로럴 달달향긋한 장미 명품니치 남여공용향수 32ML
# 1899        1899   Women         디어에이(Dear.A) 벨벳 텍스처 솔리드 퍼퓸 001 시트러스 헤븐
# 1993        1993   Women         디어에이(Dear.A) 벨벳 텍스처 솔리드 퍼퓸 001 시트러스 헤븐
# 2093        2093   Women                [프레쉬 시트러스] 싱글퍼퓸 EDP 8ml (2종 택1)
# 2180        2180   Women       [오렌지시트러스바질] 시트러스 쌉싸름상쾌한 명품니치 남여공용향수 32ML
# 2183        2183   Women       [슈가씨클라멘] 시트러스프루티 청포도샴페인 명품니치 남여공용향수 32ML
# 2202        2202   Women  [팬시스프링] 프루티시트러스 새큼한 화이트머스키 명품 니치 남여공용 향수 32ML
# 2204        2204   Women      [그린허브] 우디허브 레몬시트러스 제라늄 명품 니치 남여공용 향수 32ML
# 2205        2205   Women           [허니레몬] 시트러스 레몬과허니 명품 니치 남여공용 향수 32ML
# 2220        2220   Women     [아쿠아] 시트러스 후레쉬허브 세련미 넘치는명품 니치 남여공용 향수 32ML
# 2288        2288   Women       [슈가씨클라멘] 시트러스프루티 청포도샴페인 명품니치 남여공용향수 32ML
# 2307        2307   Women     [아쿠아] 시트러스 후레쉬허브 세련미 넘치는명품 니치 남여공용 향수 32ML
# 2362        2362   Women                       오 드 퍼퓸 50ml 시트러스 마린 니치향수
#
#         브랜드                                 설명       가격   평점   하트
# 285     록시땅  편안한 쉼, 위로, 배려가 되는 은은한 시트러스 버베나 향기  55,800원  4.7  NaN
# 1342    라임유                                NaN  38,000원  0.0    2
# 1419    지땅느                                NaN  29,000원  5.0    5
# 1452    지땅느                                NaN  29,000원  0.0    9
# 1456    지땅느                                NaN  29,000원  0.0   15
# 1543    지땅느                                NaN  29,000원  5.0   47
# 1559    지땅느                                NaN  29,000원  0.0    2
# 1572    지땅느                                NaN  29,000원  0.0    1
# 1575    지땅느                                NaN  29,000원  0.0    9
# 1661    지땅느                                NaN  29,000원  0.0  NaN
# 1750    지땅느                                NaN  29,000원  0.0    3
# 1803    지땅느                                NaN  29,000원  0.0    3
# 1813    지땅느                                NaN  29,000원  0.0    7
# 1814    지땅느                                NaN  29,000원  5.0    6
# 1899  닥터엘시아                                NaN  15,300원  0.0    7
# 1993  닥터엘시아                                NaN  15,300원  0.0  NaN
# 2093    클라엘                                NaN  17,000원  5.0   13
# 2180    지땅느                                NaN  29,000원  0.0  NaN
# 2183    지땅느                                NaN  29,000원  4.0   31
# 2202    지땅느                                NaN  29,000원  0.0    2
# 2204    지땅느                                NaN  29,000원  0.0    1
# 2205    지땅느                                NaN  29,000원  0.0    8
# 2220    지땅느                                NaN  29,000원  0.0    2
# 2288    지땅느                                NaN  29,000원  0.0    3
# 2307    지땅느                                NaN  29,000원  0.0    3
# 2362    라임유                                NaN  38,000원  0.0    0
