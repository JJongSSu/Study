# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import time
from tqdm import tqdm_notebook as tqdm

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import dates
from datetime import datetime
 
from matplotlib.ticker import MultipleLocator, IndexLocator, FuncFormatter
from matplotlib.dates import MonthLocator, DateFormatter


from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname = 'C:\Windows\Fonts\malgun.ttf').get_name()
rc('font',family=font_name)

import warnings
warnings.filterwarnings('ignore')

# %%
a = pd.read_csv('향수검색(2017~2018).csv')
a1 = pd.read_csv('향수검색(2018~2019).csv')
a2 = pd.read_csv('향수검색(2019~2020).csv')
a3 = pd.read_csv('향수검색(2020~2021).csv')
a4 = pd.read_csv('향수검색(2021~2022).csv')
a5 = pd.read_csv('향수검색(2022).csv')

# %%
a.iloc[-1,:], a1.iloc[0,:]
# Out:
# (날짜    2018-01-01
#  향수            68
#  Name: 96, dtype: object,
#  날짜    2018-01-01
#  향수            40
#  Name: 0, dtype: object)

# %%
a1.향수 = (a1.향수 * 68) / 40
a1
# Out:
#              날짜    향수
# 0    2018-01-01  68.0
# 1    2018-01-02  71.4
# 2    2018-01-03  68.0
# 3    2018-01-04  62.9
# 4    2018-01-05  61.2
# ..          ...   ...
# 361  2018-12-28  95.2
# 362  2018-12-29  88.4
# 363  2018-12-30  91.8
# 364  2018-12-31  93.5
# 365  2019-01-01  98.6
#
# [366 rows x 2 columns]

# %%
a1.iloc[-1,:],a2.iloc[0,:]
# Out:
# (날짜    2019-01-01
#  향수          98.6
#  Name: 365, dtype: object,
#  날짜    2019-01-01
#  향수            51
#  Name: 0, dtype: object)

# %%
a2.향수 = (a2.향수 * 98.6) / 51
a2
# Out:
#              날짜          향수
# 0    2019-01-01   98.600000
# 1    2019-01-02  104.400000
# 2    2019-01-03  123.733333
# 3    2019-01-04  104.400000
# 4    2019-01-05  119.866667
# ..          ...         ...
# 361  2019-12-28   96.666667
# 362  2019-12-29  112.133333
# 363  2019-12-30   98.600000
# 364  2019-12-31   88.933333
# 365  2020-01-01  100.533333
#
# [366 rows x 2 columns]

# %%
a2.iloc[-1,:],a3.iloc[0,:]
# Out:
# (날짜    2020-01-01
#  향수    100.533333
#  Name: 365, dtype: object,
#  날짜    2020-01-01
#  향수            46
#  Name: 0, dtype: object)

# %%
a3.향수 = (a3.향수 * 100.533333) / 46
a3
# Out:
#              날짜          향수
# 0    2020-01-01  100.533333
# 1    2020-01-02  111.460869
# 2    2020-01-03  109.275362
# 3    2020-01-04  107.089855
# 4    2020-01-05  124.573913
# ..          ...         ...
# 362  2020-12-28  187.953623
# 363  2020-12-29  170.469565
# 364  2020-12-30  205.437680
# 365  2020-12-31  144.243478
# 366  2021-01-01  159.542028
#
# [367 rows x 2 columns]

# %%
a3.iloc[-1,:],a4.iloc[0,:]
# Out:
# (날짜    2021-01-01
#  향수    159.542028
#  Name: 366, dtype: object,
#  날짜    2021-01-01
#  향수            58
#  Name: 0, dtype: object)

# %%
a4.향수 = (a4.향수 * 159.542028) / 58
a4
# Out:
#              날짜          향수
# 0    2021-01-01  159.542028
# 1    2021-01-02  165.043477
# 2    2021-01-03  187.049274
# 3    2021-01-04  192.550723
# 4    2021-01-05  184.298550
# ..          ...         ...
# 361  2021-12-28  176.046376
# 362  2021-12-29  209.055071
# 363  2021-12-30  165.043477
# 364  2021-12-31  159.542028
# 365  2022-01-01  154.040579
#
# [366 rows x 2 columns]

# %%
a4.iloc[-1,:],a5.iloc[0,:]
# Out:
# (날짜    2022-01-01
#  향수    154.040579
#  Name: 365, dtype: object,
#  날짜    2022-01-01
#  향수            54
#  Name: 0, dtype: object)

# %%
a5.향수 = (a5.향수 * 154.040579) / 54
a5
# Out:
#              날짜          향수
# 0    2022-01-01  154.040579
# 1    2022-01-02  213.945249
# 2    2022-01-03  199.682232
# 3    2022-01-04  222.503059
# 4    2022-01-05  191.124422
# ..          ...         ...
# 265  2022-09-23  122.661943
# 266  2022-09-24  136.924959
# 267  2022-09-25  142.630166
# 268  2022-09-26  193.977025
# 269  2022-09-27  148.335372
#
# [270 rows x 2 columns]

# %%
sum_click = pd.concat([a,a1,a2,a3,a4,a5],axis=0,ignore_index=True)
sum_click
sum_click.to_csv('향수검색')

# %%
sum_click
# Out:
#               날짜          향수
# 0     2017-09-27   51.000000
# 1     2017-09-28   35.000000
# 2     2017-09-29   45.000000
# 3     2017-09-30   43.000000
# 4     2017-10-01   45.000000
# ...          ...         ...
# 1827  2022-09-23  122.661943
# 1828  2022-09-24  136.924959
# 1829  2022-09-25  142.630166
# 1830  2022-09-26  193.977025
# 1831  2022-09-27  148.335372
#
# [1832 rows x 2 columns]

# %%
sum_click['datetime'] = pd.to_datetime(sum_click['날짜'])
sum_click
# Out:
#               날짜          향수   datetime
# 0     2017-09-27   51.000000 2017-09-27
# 1     2017-09-28   35.000000 2017-09-28
# 2     2017-09-29   45.000000 2017-09-29
# 3     2017-09-30   43.000000 2017-09-30
# 4     2017-10-01   45.000000 2017-10-01
# ...          ...         ...        ...
# 1827  2022-09-23  122.661943 2022-09-23
# 1828  2022-09-24  136.924959 2022-09-24
# 1829  2022-09-25  142.630166 2022-09-25
# 1830  2022-09-26  193.977025 2022-09-26
# 1831  2022-09-27  148.335372 2022-09-27
#
# [1832 rows x 3 columns]

# %%
sum_click.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1832 entries, 0 to 1831
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   날짜        1832 non-null   object
#  1   향수        1832 non-null   float64
#  2   datetime  1832 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 43.1+ KB

# %%
sum_click.loc[sum_click['날짜']=='2021-01-01']
# Out:
#               날짜          향수   datetime
# 1195  2021-01-01  159.542028 2021-01-01
# 1196  2021-01-01  159.542028 2021-01-01

# %%
sum_click_2022 = sum_click.iloc[1195:,:]

# %%
fig = plt.figure(figsize=(20,10))
fig.set_facecolor('white')
ax = fig.add_subplot()
ax.plot(sum_click_2022["datetime"], sum_click_2022["향수"],alpha=0.5)

ax.xaxis.set_major_locator(MonthLocator(interval=5)) ## 5개월마다 메인 눈금을 표시한다.
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d')) ## 날짜 표시 형식
ax.xaxis.set_minor_locator(MonthLocator(interval=1)) ## 1개월마다 서브 눈금을 표시한다.
 
ax.tick_params(axis='x',which='major',length=10,width=2,color='k')

# plt.scatter(['2022-02-13'],[sum_click[sum_click['datetime'] == '2022-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2022-05-16'],[sum_click[sum_click['datetime'] == '2022-05-16']["향수"]], c='red', s=200)
# plt.scatter(['2021-02-13'],[sum_click[sum_click['datetime'] == '2021-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2021-05-16'],[sum_click[sum_click['datetime'] == '2021-05-16']["향수"]], c='red', s=200)
# plt.scatter(['2020-02-13'],[sum_click[sum_click['datetime'] == '2020-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2020-05-16'],[sum_click[sum_click['datetime'] == '2020-05-16']["향수"]], c='red', s=200)
# plt.scatter(['2019-02-13'],[sum_click[sum_click['datetime'] == '2019-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2019-05-16'],[sum_click[sum_click['datetime'] == '2019-05-16']["향수"]], c='red', s=200)
# plt.scatter(['2018-02-13'],[sum_click[sum_click['datetime'] == '2018-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2018-05-16'],[sum_click[sum_click['datetime'] == '2018-05-16']["향수"]], c='red', s=200)

plt.axvline(x = datetime(2021,1,1), linestyle='--',alpha=0.5)
plt.axvline(x = datetime(2022,1,1), linestyle='--',alpha=0.5)

plt.title('연도별 향수 검색량')
plt.xlabel('연도')
plt.ylabel('검색량')
plt.xticks(rotation=45)
plt.ylim(0,300)
 
plt.show()
# plt.savefig('향수검색량(2022).png')

# %%
fig = plt.figure(figsize=(20,10))
fig.set_facecolor('white')
ax = fig.add_subplot()
ax.plot(sum_click["datetime"], sum_click["향수"],alpha=0.5)

ax.xaxis.set_major_locator(MonthLocator(interval=5)) ## 5개월마다 메인 눈금을 표시한다.
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d')) ## 날짜 표시 형식
ax.xaxis.set_minor_locator(MonthLocator(interval=1)) ## 1개월마다 서브 눈금을 표시한다.
 
ax.tick_params(axis='x',which='major',length=10,width=2,color='k')

# plt.scatter(['2022-02-13'],[sum_click[sum_click['datetime'] == '2022-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2022-05-16'],[sum_click[sum_click['datetime'] == '2022-05-16']["향수"]], c='red', s=200)
# plt.scatter(['2021-02-13'],[sum_click[sum_click['datetime'] == '2021-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2021-05-16'],[sum_click[sum_click['datetime'] == '2021-05-16']["향수"]], c='red', s=200)
# plt.scatter(['2020-02-13'],[sum_click[sum_click['datetime'] == '2020-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2020-05-16'],[sum_click[sum_click['datetime'] == '2020-05-16']["향수"]], c='red', s=200)
# plt.scatter(['2019-02-13'],[sum_click[sum_click['datetime'] == '2019-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2019-05-16'],[sum_click[sum_click['datetime'] == '2019-05-16']["향수"]], c='red', s=200)
# plt.scatter(['2018-02-13'],[sum_click[sum_click['datetime'] == '2018-02-13']["향수"]], c='red', s=200)
# plt.scatter(['2018-05-16'],[sum_click[sum_click['datetime'] == '2018-05-16']["향수"]], c='red', s=200)

plt.axvline(x = datetime(2018,1,1), linestyle='--',alpha=0.5)
plt.axvline(x = datetime(2019,1,1), linestyle='--',alpha=0.5)
plt.axvline(x = datetime(2020,1,1), linestyle='--',alpha=0.5)
plt.axvline(x = datetime(2021,1,1), linestyle='--',alpha=0.5)
plt.axvline(x = datetime(2022,1,1), linestyle='--',alpha=0.5)

plt.title('연도별 향수 검색량')
plt.xlabel('연도')
plt.ylabel('검색량')
plt.xticks(rotation=45)
plt.ylim(0,300)
 
plt.show()
plt.savefig('향수검색량.png')

# %%
# plt.figure(figsize=(20,10))
# plt.plot(sum_click["날짜"], sum_click["향수"])

# plt.scatter(['2022-02-13'],[sum_click[sum_click['날짜'] == '2022-02-13']["향수"]], c='red')
# plt.scatter(['2022-05-16'],[sum_click[sum_click['날짜'] == '2022-05-16']["향수"]], c='red')
# plt.scatter(['2021-02-13'],[sum_click[sum_click['날짜'] == '2021-02-13']["향수"]], c='red')
# plt.scatter(['2021-05-16'],[sum_click[sum_click['날짜'] == '2021-05-16']["향수"]], c='red')
# plt.scatter(['2020-02-13'],[sum_click[sum_click['날짜'] == '2020-02-13']["향수"]], c='red')
# plt.scatter(['2020-05-16'],[sum_click[sum_click['날짜'] == '2020-05-16']["향수"]], c='red')
# plt.scatter(['2019-02-13'],[sum_click[sum_click['날짜'] == '2019-02-13']["향수"]], c='red')
# plt.scatter(['2019-05-16'],[sum_click[sum_click['날짜'] == '2019-05-16']["향수"]], c='red')
# plt.scatter(['2018-02-13'],[sum_click[sum_click['날짜'] == '2018-02-13']["향수"]], c='red')
# plt.scatter(['2018-05-16'],[sum_click[sum_click['날짜'] == '2018-05-16']["향수"]], c='red')

# plt.axvline('2018-01-01',linestyle='--')
# plt.axvline('2019-01-01',linestyle='--')
# plt.axvline('2020-01-01',linestyle='--')
# plt.axvline('2021-01-01',linestyle='--')
# plt.axvline('2022-01-01',linestyle='--')

# plt.xticks(rotation=90)
# plt.xlim()
# plt.show()

# %%
trend1 = pd.read_csv('향수검색량1.csv',encoding='utf-8')
trend1.head()
# Out:
#            날짜  향수
# 0  2021-09-27  80
# 1  2021-09-28  78
# 2  2021-09-29  88
# 3  2021-09-30  83
# 4  2021-10-01  84

# %%
plt.figure(figsize=(20,10))
trend1.plot(x='날짜',y='향수',c='#0599e8')
plt.xticks(rotation=45)
plt.scatter(['2022-02-13'],[trend1[trend1['날짜'] == '2022-02-13']["향수"]], c='red')
plt.show()

# %%
type(trend1["날짜"][0])
# Out:
# str

# %%
trend1.loc[trend1['날짜'] == '2022-02-13']['날짜']

# %%
trend = pd.read_csv('2017-2018.csv',encoding='utf-8')
trend1 = pd.read_csv('2018-2019.csv',encoding='utf-8')
trend2 = pd.read_csv('2019-2020.csv',encoding='utf-8')
trend3 = pd.read_csv('2020-2021.csv',encoding='utf-8')
trend4 = pd.read_csv('2021-2022.csv',encoding='utf-8')
trend.head()
# Out:
#            날짜  향수
# 0  2017-09-27  30
# 1  2017-09-28  20
# 2  2017-09-29  26
# 3  2017-09-30  25
# 4  2017-10-01  26

# %%
trend_total = pd.concat([trend,trend1,trend2,trend3,trend4])
trend_total['날짜']=trend_total.날짜.str[:4]
trend_total
# Out:
#        날짜  향수
# 0    2017  30
# 1    2017  20
# 2    2017  26
# 3    2017  25
# 4    2017  26
# ..    ...  ..
# 361  2022  43
# 362  2022  48
# 363  2022  50
# 364  2022  68
# 365  2022  52
#
# [1831 rows x 2 columns]

# %%
trend_2017 = pd.Series(trend_total[trend_total['날짜'] == '2017']['향수'].sum())
trend_2018 = pd.Series(trend_total[trend_total['날짜'] == '2018']['향수'].sum())
trend_2019 = pd.Series(trend_total[trend_total['날짜'] == '2019']['향수'].sum())
trend_2020 = pd.Series(trend_total[trend_total['날짜'] == '2020']['향수'].sum())
trend_2021 = pd.Series(trend_total[trend_total['날짜'] == '2021']['향수'].sum())
trend_2022 = pd.Series(trend_total[trend_total['날짜'] == '2022']['향수'].sum())
trend_every = pd.DataFrame({'2017':trend_2017,'2018':trend_2018,'2019':trend_2019,'2020':trend_2020,'2021':trend_2021,'2022':trend_2022})
trend_every
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Study\Teamproject\first\3일차\trend.ipynb 셀 28 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Study/Teamproject/first/3%EC%9D%BC%EC%B0%A8/trend.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> trend_2017 = pd.Series(trend_total[trend_total['날짜'] == '2017']['향수'].sum())
#       <a href='vscode-notebook-cell:/c%3A/Study/Teamproject/first/3%EC%9D%BC%EC%B0%A8/trend.ipynb#X36sZmlsZQ%3D%3D?line=1'>2</a> trend_2018 = pd.Series(trend_total[trend_total['날짜'] == '2018']['향수'].sum())
#       <a href='vscode-notebook-cell:/c%3A/Study/Teamproject/first/3%EC%9D%BC%EC%B0%A8/trend.ipynb#X36sZmlsZQ%3D%3D?line=2'>3</a> trend_2019 = pd.Series(trend_total[trend_total['날짜'] == '2019']['향수'].sum())
#
# NameError: name 'trend_total' is not defined

# %%
trend_every.values
# Out:
# array([[ 3579, 17811, 22879, 23026, 15814]], dtype=int64)

# %%
t = trend_every.T
t.columns = ['검색량']
t
# Out:
#         검색량
# 2017   3579
# 2018  17811
# 2019  22879
# 2020  23026
# 2021  15814

# %%
t = trend_every.T
t.columns = ['검색량']
t

temp = t['검색량']
y = temp[['2017','2018','2019','2020','2021']]
y

ax = t.plot(kind='bar',legend=None, color='#d395d0')
# #'#ffc000', '#8fd9b6', '#d395d0', 0599e8

plt.plot(y, c='r', marker = 'o', ls='-', lw = 2, ms = 5, mfc = 'r', mew = 1, mec = 'r')

for p in ax.patches:
    left, bottom, width, height = p.get_bbox().bounds
    ax.annotate("%d"%height, (left+width/2, height*1.01), ha='center')

plt.xticks(rotation=0)
plt.ylim(0,30000)
plt.xlabel('연도')
plt.ylabel('검색량')
plt.title('연도별 향수 검색량')
plt.show()
plt.savefig('향수검색량(네이버).png')

# %%
money1 = pd.read_csv('화장품과향수 수출입.csv',encoding='cp949')
money1.head()
# Out:
#                     품목별        항목   단위   2020.01 월   2020.02 월   2020.03 월  \
# 0                    총액  수출액[천달러]  천달러  43103061.0  40911819.0  46167204.0
# 1                    총액  수입액[천달러]  천달러  42718100.0  36977247.0  41803860.0
# 2              식품 및 산동물  수출액[천달러]  천달러    464273.0    468124.0    545261.0
# 3              식품 및 산동물  수입액[천달러]  천달러   2627428.0   2005395.0   2262352.0
# 4  중분류 03의 동물을 제외한 산 동물  수출액[천달러]  천달러       190.0       398.0       181.0
#
#     2020.04 월   2020.05 월   2020.06 월   2020.07 월  ...   2021.09 월  \
# 0  36270183.0  34854511.0  39214071.0  42785144.0  ...  55913862.0
# 1  37932611.0  34661974.0  35794860.0  38849185.0  ...  51636341.0
# 2    545869.0    460918.0    531000.0    542869.0  ...    602458.0
# 3   2304002.0   2379665.0   2301011.0   2413044.0  ...   2641506.0
# 4       120.0       195.0       387.0       443.0  ...       587.0
#
#     2021.10 월   2021.11 월   2021.12 월   2022.01 월   2022.02 월   2022.03 월  \
# 0  55660373.0  60330542.0  60734117.0  55460865.0  54154313.0  63785078.0
# 1  53847824.0  57357549.0  61159671.0  60363481.0  53133762.0  63593038.0
# 2    690808.0    744879.0    786504.0    626650.0    611226.0    714919.0
# 3   2754248.0   3021359.0   3096336.0   3038687.0   2623332.0   3376922.0
# 4       711.0       827.0       615.0       612.0       530.0       775.0
#
#     2022.04 월   2022.05 월   2022.06 월
# 0  57849157.0  61579891.0  57625856.0
# 1  60326206.0  63194249.0  60200435.0
# 2    724140.0    710015.0    662101.0
# 3   3248464.0   3261850.0   2977361.0
# 4       548.0       729.0       590.0
#
# [5 rows x 33 columns]

# %%
money1.index.str.contains('향수')

# %%
money = pd.read_csv('화장품과향수_수출입_1.csv',encoding='utf-8',index_col='품목별')
money
# Out:
#                            항목   단위  2020.01 월  2020.02 월  2020.03 월  \
# 품목별
# 향수 및 화장품,화장용품(비누제외)  수출액[천달러]  천달러     457396     511342     751075
# 향수 및 화장품,화장용품(비누제외)  수입액[천달러]  천달러     145211     134051     131773
#
#                      2020.04 월  2020.05 월  2020.06 월  2020.07 월  2020.08 월  \
# 품목별
# 향수 및 화장품,화장용품(비누제외)     549864     550866     540095     581815     564114
# 향수 및 화장품,화장용품(비누제외)     122813     106444     121283     127440     123310
#
#                      ...  2021.09 월  2021.10 월  2021.11 월  2021.12 월  \
# 품목별                  ...
# 향수 및 화장품,화장용품(비누제외)  ...     852136     781467     856152     671517
# 향수 및 화장품,화장용품(비누제외)  ...     135540     142346     137730     156103
#
#                      2022.01 월  2022.02 월  2022.03 월  2022.04 월  2022.05 월  \
# 품목별
# 향수 및 화장품,화장용품(비누제외)     553822     559575     693407     696093     821203
# 향수 및 화장품,화장용품(비누제외)     135690     140972     158256     149163     141925
#
#                      2022.06 월
# 품목별
# 향수 및 화장품,화장용품(비누제외)     646052
# 향수 및 화장품,화장용품(비누제외)     151026
#
# [2 rows x 32 columns]

# %%
money.T.iloc[2:,:].index.str[:7]
# Out:
# Index(['2020.01', '2020.02', '2020.03', '2020.04', '2020.05', '2020.06',
#        '2020.07', '2020.08', '2020.09', '2020.10', '2020.11', '2020.12',
#        '2021.01', '2021.02', '2021.03', '2021.04', '2021.05', '2021.06',
#        '2021.07', '2021.08', '2021.09', '2021.10', '2021.11', '2021.12',
#        '2022.01', '2022.02', '2022.03', '2022.04', '2022.05', '2022.06'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
# plt.plot(data=money)
money.T.iloc[2:,:].plot()
plt.title('연도별 향수 수출 및 수입현황')
plt.xlabel('날짜')
plt.ylabel('수출/수입액(백만달러)')
plt.ylim(0,1000000)
plt.legend(loc='upper right')

# %%
m = money.transpose()
index = m.index[2:]
m = m.loc[index]
m.columns = ["export", "import"]
m
# Out:
#            export  import
# 2020.01 월  457396  145211
# 2020.02 월  511342  134051
# 2020.03 월  751075  131773
# 2020.04 월  549864  122813
# 2020.05 월  550866  106444
# 2020.06 월  540095  121283
# 2020.07 월  581815  127440
# 2020.08 월  564114  123310
# 2020.09 월  817107  134287
# 2020.10 월  707818  134055
# 2020.11 월  741458  127855
# 2020.12 월  669906  144332
# 2021.01 월  743006  136388
# 2021.02 월  610811  121027
# 2021.03 월  839739  141795
# 2021.04 월  866794  148475
# 2021.05 월  776680  141313
# 2021.06 월  703654  142966
# 2021.07 월  641113  143385
# 2021.08 월  672812  148887
# 2021.09 월  852136  135540
# 2021.10 월  781467  142346
# 2021.11 월  856152  137730
# 2021.12 월  671517  156103
# 2022.01 월  553822  135690
# 2022.02 월  559575  140972
# 2022.03 월  693407  158256
# 2022.04 월  696093  149163
# 2022.05 월  821203  141925
# 2022.06 월  646052  151026

# %%
plt.figure(figsize=(20,10))
plt.plot(m["export"],label='export')
plt.plot(m["import"],label='import')
plt.title('연도별 향수 수출 및 수입현황')
plt.xlabel('날짜')
plt.ylabel('수출/수입액(백만달러)')
plt.ylim(0,1000000)
plt.xticks(rotation=45)
plt.legend(loc='upper right')
plt.show()
plt.savefig('향수_수출입.jpg',dpi=600)

# %%
review = pd.read_csv('리뷰작성날짜.csv',encoding='utf-8')
review.columns = ['인덱스','리뷰작성날짜']
review = review.drop(['인덱스'], axis=1)
review
# Out:
#           리뷰작성날짜
# 0     2022-07-27
# 1     2022-07-26
# 2     2022-05-29
# 3     2022-05-29
# 4     2022-05-17
# ...          ...
# 2703  2021-10-25
# 2704  2021-10-24
# 2705  2021-10-18
# 2706  2021-10-16
# 2707  2021-10-07
#
# [2708 rows x 1 columns]

# %%
review.value_counts()
# Out:
# 리뷰작성날짜
# 2020-06-19    14
# 2022-02-22    14
# 2020-11-04    12
# 2022-05-13    11
# 2022-05-18    11
#               ..
# 2020-03-01     1
# 2021-12-30     1
# 2021-12-29     1
# 2021-12-28     1
# 2021-10-25     1
# Length: 982, dtype: int64

# %%
count = pd.DataFrame(review.value_counts(),columns=['count'])
count
# Out:
#             count
# 리뷰작성날짜
# 2020-06-19     14
# 2022-02-22     14
# 2020-11-04     12
# 2022-05-13     11
# 2022-05-18     11
# ...           ...
# 2020-03-01      1
# 2021-12-30      1
# 2021-12-29      1
# 2021-12-28      1
# 2021-10-25      1
#
# [982 rows x 1 columns]

# %%
count = count.sort_index(ascending=True)
count
# Out:
#             count
# 리뷰작성날짜
# 2018-10-04      2
# 2018-10-09      1
# 2018-10-26      1
# 2018-11-19      1
# 2018-11-22      1
# ...           ...
# 2022-09-23      2
# 2022-09-24      3
# 2022-09-26     10
# 2022-09-27     10
# 2022-09-28      5
#
# [982 rows x 1 columns]

# %%
count.plot()
# Out:
# <AxesSubplot:xlabel='리뷰작성날짜'>
