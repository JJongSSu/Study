# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname = 'C:\Windows\Fonts\malgun.ttf').get_name()
rc('font',family=font_name)

import warnings
warnings.filterwarnings('ignore')

# %%
red = pd.read_csv('3조 향수 관련 설문 조사(응답) - 설문지 응답 시트1.csv',sep=',',encoding='utf-8')
red
# Out:
#                       타임스탬프 본인의 성함을 작성해 주세요 당신은  향수에 관심이 있나요?  \
# 0    2022. 9. 23 오후 6:14:42             이호재                 네
# 1    2022. 9. 23 오후 6:19:03             김윤호                 네
# 2    2022. 9. 23 오후 6:19:18             문채원               아니요
# 3    2022. 9. 23 오후 6:20:09             이소현                 네
# 4    2022. 9. 23 오후 6:20:11      맨앞 맨오른쪽 사람                 네
# 5    2022. 9. 23 오후 6:20:55             유현지                 네
# 6    2022. 9. 23 오후 6:21:52             윤소정                 네
# 7    2022. 9. 23 오후 6:23:09             이예지               아니요
# 8    2022. 9. 23 오후 6:29:18             이종수                 네
# 9    2022. 9. 23 오후 6:31:30             진효영                 네
# 10   2022. 9. 23 오후 7:04:01             김세화                 네
# 11   2022. 9. 23 오후 8:47:08             서인혁                 네
# 12  2022. 9. 23 오후 10:27:10             권소현                 네
# 13  2022. 9. 23 오후 10:50:16             강은정               아니요
# ...

# %%
red.drop(red.index[14])
# Out:
#                       타임스탬프 본인의 성함을 작성해 주세요 당신은  향수에 관심이 있나요?  \
# 0    2022. 9. 23 오후 6:14:42             이호재                 네
# 1    2022. 9. 23 오후 6:19:03             김윤호                 네
# 2    2022. 9. 23 오후 6:19:18             문채원               아니요
# 3    2022. 9. 23 오후 6:20:09             이소현                 네
# 4    2022. 9. 23 오후 6:20:11      맨앞 맨오른쪽 사람                 네
# 5    2022. 9. 23 오후 6:20:55             유현지                 네
# 6    2022. 9. 23 오후 6:21:52             윤소정                 네
# 7    2022. 9. 23 오후 6:23:09             이예지               아니요
# 8    2022. 9. 23 오후 6:29:18             이종수                 네
# 9    2022. 9. 23 오후 6:31:30             진효영                 네
# 10   2022. 9. 23 오후 7:04:01             김세화                 네
# 11   2022. 9. 23 오후 8:47:08             서인혁                 네
# 12  2022. 9. 23 오후 10:27:10             권소현                 네
# 13  2022. 9. 23 오후 10:50:16             강은정               아니요
# ...

# %%
red.iloc[4,1] = '정지환'

# %%
red
# Out:
#                       타임스탬프 본인의 성함을 작성해 주세요 당신은  향수에 관심이 있나요?  \
# 0    2022. 9. 23 오후 6:14:42             이호재                 네
# 1    2022. 9. 23 오후 6:19:03             김윤호                 네
# 2    2022. 9. 23 오후 6:19:18             문채원               아니요
# 3    2022. 9. 23 오후 6:20:09             이소현                 네
# 4    2022. 9. 23 오후 6:20:11             정지환                 네
# 5    2022. 9. 23 오후 6:20:55             유현지                 네
# 6    2022. 9. 23 오후 6:21:52             윤소정                 네
# 7    2022. 9. 23 오후 6:23:09             이예지               아니요
# 8    2022. 9. 23 오후 6:29:18             이종수                 네
# 9    2022. 9. 23 오후 6:31:30             진효영                 네
# 10   2022. 9. 23 오후 7:04:01             김세화                 네
# 11   2022. 9. 23 오후 8:47:08             서인혁                 네
# 12  2022. 9. 23 오후 10:27:10             권소현                 네
# 13  2022. 9. 23 오후 10:50:16             강은정               아니요
# ...

# %%
red.iloc[:,4]
# Out:
# 0     ENTP
# 1     ENFJ
# 2     ESTP
# 3     Enfp
# 4     INFP
# 5     istp
# 6     isfj
# 7     infp
# 8     Infj
# 9     Enfj
# 10    INFP
# 11    Infj
# 12    Isfp
# 13    Istj
# 14    ENPJ
# 15    ISTJ
# 16    INTP
# 17    INFJ
# 18    INTJ
# 19    INT?
# 20    Infp
# 21    INTP
# Name: 당신의 mbti은 무엇인가요?, dtype: object

# %%
mbti = []
for i in red.iloc[:,4]:
    mbti.append(i.lower())
mbti
# Out:
# ['entp',
#  'enfj',
#  'estp',
#  'enfp',
#  'infp',
#  'istp',
#  'isfj',
#  'infp',
#  'infj',
#  'enfj',
#  'infp',
#  'infj',
#  'isfp',
#  'istj',
#  'enpj',
#  'istj',
#  'intp',
#  'infj',
#  'intj',
#  'int?',
#  'infp',
#  'intp']

# %%
red.iloc[:,4] = mbti
red
# Out:
#                       타임스탬프 본인의 성함을 작성해 주세요 당신은  향수에 관심이 있나요?  \
# 0    2022. 9. 23 오후 6:14:42             이호재                 네
# 1    2022. 9. 23 오후 6:19:03             김윤호                 네
# 2    2022. 9. 23 오후 6:19:18             문채원               아니요
# 3    2022. 9. 23 오후 6:20:09             이소현                 네
# 4    2022. 9. 23 오후 6:20:11             정지환                 네
# 5    2022. 9. 23 오후 6:20:55             유현지                 네
# 6    2022. 9. 23 오후 6:21:52             윤소정                 네
# 7    2022. 9. 23 오후 6:23:09             이예지               아니요
# 8    2022. 9. 23 오후 6:29:18             이종수                 네
# 9    2022. 9. 23 오후 6:31:30             진효영                 네
# 10   2022. 9. 23 오후 7:04:01             김세화                 네
# 11   2022. 9. 23 오후 8:47:08             서인혁                 네
# 12  2022. 9. 23 오후 10:27:10             권소현                 네
# 13  2022. 9. 23 오후 10:50:16             강은정               아니요
# ...

# %%
red.iloc[19,4] = 'intj'

# %%
import random

# %%
color = ["#"+''.join([random.choice('0123456789ABCDEF') for j in range(6)])]

red.iloc[:,4].value_counts().plot(kind='bar',alpha=0.7, color = '#0599e8')
plt.xticks(rotation=0)
plt.savefig('mbti.png')

# %%
plt.figure(figsize=(5,5))
red.iloc[:,2].value_counts().plot(kind='pie',autopct='%.2f%%', colors = ['#8fd9b6', '#ff9999'], explode = [0.01,0.01], counterclock=False)
plt.savefig('qu1.png')

# %%
plt.figure(figsize=(7,7))
red.iloc[:,3].value_counts().plot(kind='pie', autopct='%.2f%%', colors = ['#8fd9b6', '#ffc000', '#ff9999'], explode = [0.01,0.01,0.01],
                                    wedgeprops={'width': 0.7, 'edgecolor': 'w', 'linewidth': 2}, counterclock=False)
plt.savefig('qu2.png')
