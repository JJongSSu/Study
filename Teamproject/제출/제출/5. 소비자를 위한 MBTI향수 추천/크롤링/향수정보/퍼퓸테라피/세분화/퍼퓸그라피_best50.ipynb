# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
driver = webdriver.Chrome(ChromeDriverManager().install())
from bs4 import BeautifulSoup as bs
import time
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import pandas as pd
from tqdm import tqdm_notebook as tqdm

# %%
page = 'https://perfumegraphy.com/category/best-50/512/'

# %%
actions = ActionChains(driver)
driver.get(page)
driver.maximize_window()
actions.perform()

# %%
name_list=[]
price_list=[]
brand_list=[]
stars_list=[]
exp_list=[]
for i in range(1,4):
    page_url = 'https://perfumegraphy.com/category/best-50/512/?page={}'.format(i)
    driver.get(page_url)
    time.sleep(2)
    soup = bs(driver.page_source,'html.parser')
    for i in tqdm(range(1,21)):
        try:
            exp = driver.find_element_by_css_selector('#contents > div.xans-element-.xans-product.xans-product-normalpackage > div.xans-element-.xans-product.xans-product-listnormal.ec-base-product.prdArea1.on > ul > li:nth-child({}) > div.description > ul > li.summary'.format(i))
            exp_list.append(exp.text)
            button = driver.find_element_by_css_selector('#contents > div.xans-element-.xans-product.xans-product-normalpackage > div.xans-element-.xans-product.xans-product-listnormal.ec-base-product.prdArea1.on > ul > li:nth-child({}) > div.description > strong > a > span'.format(i))
            button.click()
            soup = bs(driver.page_source,'html.parser')
            name = driver.find_element_by_css_selector('#contents > div.xans-element-.xans-product.xans-product-detail > div.detailArea > div.fixOpt > div.infoArea > div.cont.sb > div.xans-element-.xans-product.xans-product-detaildesign > table:nth-child(1) > tbody > tr.tit.t1.xans-record- > td > span')
            name_list.append(name.text)
            price = driver.find_element_by_css_selector('#span_product_price_text')
            price_list.append(price.text)
            brand = driver.find_element_by_css_selector('#contents > div.xans-element-.xans-product.xans-product-detail > div.detailArea > div.fixOpt > div.infoArea > div.brand-category > a > span.brand-title')
            brand_list.append(brand.text)
            stars = driver.find_element_by_css_selector('#contents > div.xans-element-.xans-product.xans-product-detail > div.detailArea > div.fixOpt > div.infoArea > div.cont.sb > div.xans-element-.xans-product.xans-product-detaildesign > table:nth-child(1) > tbody > tr:nth-child(6) > td > span > span > div')
            stars_list.append(stars.text)
            time.sleep(2)
            driver.get(page_url)
        except:
            pass
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_7984\2480216667.py:11: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for i in tqdm(range(1,21)):
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
len(exp_list)
# Out:
# 51

# %%
len(name_list)
len(price_list)
# Out:
# 51

# %%
price_list
# Out:
# ['83,800원 21.7% 할인',
#  '103,500원 24.5% 할인',
#  '220,000원 21.4% 할인',
#  '220,000원 21.4% 할인',
#  '265,000원 27.4% 할인',
#  '73,000원 30.5% 할인',
#  '130,000원 36.6% 할인',
#  '87,800원 17.9% 할인',
#  '152,000원 22.1% 할인',
#  '174,500원 14.9% 할인',
#  '85,000원 22.0% 할인',
#  '83,800원 21.7% 할인',
#  '65,200원 17.5% 할인',
#  '81,800원 23.6% 할인',
#  '160,000원 17.9% 할인',
#  '87,800원 11.3% 할인',
#  '87,800원 17.9% 할인',
#  '174,500원 14.9% 할인',
#  '174,500원 14.9% 할인',
#  '65,200원 17.5% 할인',
#  '197,000원 17.9% 할인',
#  '265,000원 14.0% 할인',
#  '65,200원 17.5% 할인',
#  '145,000원 17.1% 할인',
#  '395,000원 15.1% 할인',
#  '82,000원 20.4% 할인',
#  '107,000원 25.2% 할인',
#  '174,500원 14.9% 할인',
#  '285,000원 7.5% 할인',
#  '128,000원 10.5% 할인',
#  '174,500원 14.9% 할인',
#  '87,800원 12.2% 할인',
#  '197,000원 17.9% 할인',
#  '197,000원 17.9% 할인',
#  '170,000원 17.1% 할인',
#  '174,500원 14.9% 할인',
#  '65,200원 17.5% 할인',
#  '195,000원 25.9% 할인',
#  '174,500원 14.9% 할인',
#  '193,500원 15.9% 할인',
#  '145,000원 17.1% 할인',
#  '102,000원 25.5% 할인',
#  '205,000원 14.6% 할인',
#  '196,500원 16.4% 할인',
#  '103,500원 24.5% 할인',
#  '125,000원 7.4% 할인',
#  '148,000원 27.8% 할인',
#  '365,000원 22.3% 할인',
#  '90,000원 12.6% 할인',
#  '170,000원 17.1% 할인',
#  '288,000원 38.7% 할인']

# %%
len(brand_list
# Out:
# ['조말론',
#  '산타마리아노벨라',
#  '르라보',
#  '르라보',
#  '톰포드',
#  '아쿠아 디 파르마',
#  '세르주루텐',
#  '조말론',
#  '산타마리아노벨라',
#  '세르주루텐',
#  '에르메스',
#  '조말론',
#  '아이젠버그',
#  '조말론',
#  '톰포드',
#  '조말론',
#  '조말론',
#  '세르주루텐',
#  '세르주루텐',
#  '아이젠버그',
#  '바이레도',
#  '킬리안',
#  '아이젠버그',
#  '메종 마르지엘라',
#  '세르주루텐',
#  '입생로랑',
#  '구찌',
#  '세르주루텐',
#  '킬리안',
#  '딥티크',
#  '세르주루텐',
#  '조말론',
#  '바이레도',
#  '바이레도',
#  '불리 1803',
#  '세르주루텐',
#  '아이젠버그',
#  '프레데릭말',
#  '세르주루텐',
#  '바이레도',
#  '메종 마르지엘라',
#  '산타마리아노벨라',
#  '바이레도',
#  '딥티크',
#  '산타마리아노벨라',
#  '디올',
#  '세르주루텐',
#  '톰포드',
#  '디올',
#  '불리 1803',
#  '톰포드']

# %%
stars_list
# Out:
# ['4.8',
#  '4.8',
#  '5.0',
#  '4.9',
#  '4.8',
#  '4.8',
#  '4.8',
#  '5.0',
#  '4.8',
#  '5.0',
#  '4.9',
#  '4.9',
#  '4.8',
#  '4.8',
#  '4.9',
#  '4.8',
#  '4.8',
#  '5.0',
#  '5.0',
#  '4.7',
#  '4.7',
#  '5.0',
#  '4.9',
#  '4.7',
#  '0.0',
#  '4.8',
#  '4.8',
#  '4.3',
#  '4.9',
#  '4.9',
#  '5.0',
#  '4.8',
#  '5.0',
#  '5.0',
#  '4.9',
#  '5.0',
#  '4.8',
#  '4.7',
#  '5.0',
#  '5.0',
#  '4.8',
#  '4.9',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.8',
#  '4.9',
#  '4.9',
#  '4.8',
#  '4.9',
#  '4.9']

# %%
name =pd.Series(name_list)
price =pd.Series(price_list)
brand =pd.Series(brand_list)
stars =pd.Series(stars_list)
exp = pd.Series(exp_list)

# %%
df = pd.concat([name,brand,exp,price,stars],axis=1)
df
# Out:
#                                          0          1  \
# 0                         조말론 블랙베리 앤 베이 코롱        조말론
# 1                       산타마리아노벨라 프리지아 50ml   산타마리아노벨라
# 2                   르라보 어나더 13 오 드 퍼퓸 50ml        르라보
# 3                    르라보 상탈 33 오 드 퍼퓸 50ml        르라보
# 4                     톰포드 오드우드 오 드 퍼퓸 50ml        톰포드
# 5             아쿠아 디 파르마 미르토 디 파나레아 오 드 뚜왈렛  아쿠아 디 파르마
# 6                    세르주루텐 라 휘드 베흘랑 오 드 퍼퓸      세르주루텐
# 7                        조말론 허니서클 앤 다바나 코롱        조말론
