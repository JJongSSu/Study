# %%
# 라이브러리 import
from selenium import webdriver
import time
import pandas as pd
import re
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys

from webdriver_manager.chrome import ChromeDriverManager

# %%
# 크롬드라이버 제어
chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument('--disable-dex-shm-usage')

keys = Keys()

# %%
url_list = ['https://smartstore.naver.com/hangangbrewery/products/5463952480?NaPm=ct%3Dlb0i1l94%7Cci%3Dd56864a57fc69d0ad81db810e9193bfef0e47ab3%7Ctr%3Dslsl%7Csn%3D1157257%7Chk%3Db5f9abf4ef48d1e74b3c0ad416b239de8566dd5b']

driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_3748\22654422.py:3: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)

# %%
all_count=0
text_list= []
star_list= []
date_list= []

for target_url in url_list:
    end = False
    
    driver.get(target_url)
    driver.implicitly_wait(3)
    time.sleep(1)
    count = 0
    
    review_num = driver.find_element('xpath', '//*[@id="content"]/div/div[2]/div[1]/div[2]/div[1]/a/strong')
    review_num = review_num.text
    review_num = re.sub('[^#0-9 ]',"", review_num)
    review_num = int(review_num)
    
    try:
        driver.find_element('xpath', '//*[@id="content"]/div/div[3]/div[3]/ul/li[2]/a').click()
    except:
        driver.find_element('xpath', '//*[@id="content"]/div/div[3]/div[4]/ul/li[2]').click()
    
    time.sleep(1)
    
    while(True):
        for i in range(20):
            # 공통 경로
            path = driver.find_element('xpath', f'//*[@id="REVIEW"]/div/div[3]/div[2]/ul/li[{i+1}]/div')
            try: # 판매자 댓글 없을때                    
                review = path.find_element('xpath', 'div/div/div[1]/div/div[1]/div[2]/div')
                star = path.find_element('xpath', 'div/div/div[1]/div/div[1]/div[1]/div[2]/div[1]/em')
                date = path.find_element('xpath', 'div/div/div[1]/div/div[1]/div[1]/div[2]/div[2]/span')

            except:
                try: # 판매자 댓글 있을때
                    review = path.find_element('xpath', 'div[1]/div/div[1]/div/div[1]/div[2]/div')
                    star = path.find_element('xpath', 'div[1]/div/div[1]/div/div[1]/div[1]/div[2]/div[1]/em')
                    date = path.find_element('xpath', 'div[1]/div/div[1]/div/div/div[1]/div[2]/div[2]/span')

                except: # 경로가 다른경우
                    review = path.find_element('xpath', 'div/div/div[1]/div/div/div[2]/div')
                    star = path.find_element('xpath', 'div/div/div[1]/div/div/div[1]/div[2]/div[1]/em')
                    date = path.find_element('xpath', 'div/div/div[1]/div/div/div[1]/div[2]/div[2]/span')
                    
            r_span_num = len(review.find_elements('xpath','span'))
            
            if r_span_num == 1: # BEST, 한달사용기 등이 없을때
                review = review.find_element('xpath', 'span')
            else: # 있을때
                review = review.find_element('xpath', f'span[{r_span_num}]')
                
            review = review.text
            review = re.sub('[^#0-9a-zA-Zㄱ-ㅣ가-힣 ]',"", review)
            star = star.text
            star = re.sub('[^#0-9 ]',"", star)
            date = date.text

            text_list.append(review)
            star_list.append(star)
            date_list.append(date)
            
            count = count + 1
            all_count = all_count + 1
            
            if count == review_num:
                end = True
                print('{}개 리뷰 크롤링, 다음'.format(count))
                break
        
        print('총 {}개 리뷰 크롤링'.format(all_count))
        
        if end:
            break
        
        next = 12
        next_bool = True
        while(next_bool): # 다음 버튼 클릭
            try:
                driver.find_element('xpath', f'//*[@id="REVIEW"]/div/div[3]/div[2]/div/div/a[{next}]').click()
                next_bool = False
            except:
                next = next -1
                
        driver.implicitly_wait(3)
        time.sleep(1)
# Out:
# 총 20개 리뷰 크롤링
# 총 40개 리뷰 크롤링
# 총 60개 리뷰 크롤링
# 총 80개 리뷰 크롤링
# 총 100개 리뷰 크롤링
# 총 120개 리뷰 크롤링
# 총 140개 리뷰 크롤링
# 총 160개 리뷰 크롤링
# 총 180개 리뷰 크롤링
# 총 200개 리뷰 크롤링
# 총 220개 리뷰 크롤링
# 총 240개 리뷰 크롤링
# 총 260개 리뷰 크롤링
# 총 280개 리뷰 크롤링
# 총 300개 리뷰 크롤링
# 총 320개 리뷰 크롤링
# 총 340개 리뷰 크롤링
# 총 360개 리뷰 크롤링
# 총 380개 리뷰 크롤링
# 총 400개 리뷰 크롤링
# 총 420개 리뷰 크롤링
# 총 440개 리뷰 크롤링
# 총 460개 리뷰 크롤링
# 총 480개 리뷰 크롤링
# 총 500개 리뷰 크롤링
# 총 520개 리뷰 크롤링
# 총 540개 리뷰 크롤링
# 총 560개 리뷰 크롤링
# 총 580개 리뷰 크롤링
# 총 600개 리뷰 크롤링
# 총 620개 리뷰 크롤링
# 총 640개 리뷰 크롤링
# 총 660개 리뷰 크롤링
# 총 680개 리뷰 크롤링
# 총 700개 리뷰 크롤링
# 총 720개 리뷰 크롤링
# 총 740개 리뷰 크롤링
# 총 760개 리뷰 크롤링
# 총 780개 리뷰 크롤링
# 총 800개 리뷰 크롤링
# 총 820개 리뷰 크롤링
# 총 840개 리뷰 크롤링
# 총 860개 리뷰 크롤링
# 총 880개 리뷰 크롤링
# 총 900개 리뷰 크롤링
# 총 920개 리뷰 크롤링
# 총 940개 리뷰 크롤링
# 총 960개 리뷰 크롤링
# 총 980개 리뷰 크롤링
# 총 1000개 리뷰 크롤링
# 총 1020개 리뷰 크롤링
# 총 1040개 리뷰 크롤링
# 총 1060개 리뷰 크롤링
# 총 1080개 리뷰 크롤링
# 총 1100개 리뷰 크롤링
# 총 1120개 리뷰 크롤링
# 총 1140개 리뷰 크롤링
# 총 1160개 리뷰 크롤링
# 총 1180개 리뷰 크롤링
# 총 1200개 리뷰 크롤링
# 총 1220개 리뷰 크롤링
# 총 1240개 리뷰 크롤링
# 총 1260개 리뷰 크롤링
# 총 1280개 리뷰 크롤링
# 총 1300개 리뷰 크롤링
# 총 1320개 리뷰 크롤링
# 총 1340개 리뷰 크롤링
# 총 1360개 리뷰 크롤링
# 총 1380개 리뷰 크롤링
# 총 1400개 리뷰 크롤링
# 총 1420개 리뷰 크롤링
# 총 1440개 리뷰 크롤링
# 총 1460개 리뷰 크롤링
# 총 1480개 리뷰 크롤링
# 총 1500개 리뷰 크롤링
# 총 1520개 리뷰 크롤링
# 총 1540개 리뷰 크롤링
# 총 1560개 리뷰 크롤링
# 총 1580개 리뷰 크롤링
# 총 1600개 리뷰 크롤링
# 총 1620개 리뷰 크롤링
# 총 1640개 리뷰 크롤링
# 총 1660개 리뷰 크롤링
# 총 1680개 리뷰 크롤링
# 총 1700개 리뷰 크롤링
# 총 1720개 리뷰 크롤링
# 총 1740개 리뷰 크롤링
# 총 1760개 리뷰 크롤링
# 총 1780개 리뷰 크롤링
# 총 1800개 리뷰 크롤링
# 총 1820개 리뷰 크롤링
# 총 1840개 리뷰 크롤링
# 총 1860개 리뷰 크롤링
# 총 1880개 리뷰 크롤링
# 총 1900개 리뷰 크롤링
# 총 1920개 리뷰 크롤링
# 총 1940개 리뷰 크롤링
# 총 1960개 리뷰 크롤링
# 총 1980개 리뷰 크롤링
# 총 2000개 리뷰 크롤링
# 총 2020개 리뷰 크롤링
# 총 2040개 리뷰 크롤링
# 총 2060개 리뷰 크롤링
# 총 2080개 리뷰 크롤링
# 총 2100개 리뷰 크롤링
# 총 2120개 리뷰 크롤링
# 총 2140개 리뷰 크롤링
# 총 2160개 리뷰 크롤링
# 총 2180개 리뷰 크롤링
# 총 2200개 리뷰 크롤링
# 총 2220개 리뷰 크롤링
# 총 2240개 리뷰 크롤링
# 총 2260개 리뷰 크롤링
# 총 2280개 리뷰 크롤링
# 총 2300개 리뷰 크롤링
# 총 2320개 리뷰 크롤링
# 총 2340개 리뷰 크롤링
# 총 2360개 리뷰 크롤링
# 총 2380개 리뷰 크롤링
# 총 2400개 리뷰 크롤링
# 총 2420개 리뷰 크롤링
# 총 2440개 리뷰 크롤링
# 총 2460개 리뷰 크롤링
# 총 2480개 리뷰 크롤링
# 총 2500개 리뷰 크롤링
# 총 2520개 리뷰 크롤링
# 총 2540개 리뷰 크롤링
# 총 2560개 리뷰 크롤링
# 총 2580개 리뷰 크롤링
# 총 2600개 리뷰 크롤링
# 총 2620개 리뷰 크롤링
# 총 2640개 리뷰 크롤링
# 총 2660개 리뷰 크롤링
# 총 2680개 리뷰 크롤링
# 총 2700개 리뷰 크롤링
# 총 2720개 리뷰 크롤링
# 총 2740개 리뷰 크롤링
# 총 2760개 리뷰 크롤링
# 총 2780개 리뷰 크롤링
# 총 2800개 리뷰 크롤링
# 총 2820개 리뷰 크롤링
# 총 2840개 리뷰 크롤링
# 총 2860개 리뷰 크롤링
# 총 2880개 리뷰 크롤링
# 총 2900개 리뷰 크롤링
# 총 2920개 리뷰 크롤링
# 총 2940개 리뷰 크롤링
# 총 2960개 리뷰 크롤링
# 총 2980개 리뷰 크롤링
# 총 3000개 리뷰 크롤링
# 총 3020개 리뷰 크롤링
# 총 3040개 리뷰 크롤링
# 총 3060개 리뷰 크롤링
# 총 3080개 리뷰 크롤링
# 총 3100개 리뷰 크롤링
# 총 3120개 리뷰 크롤링
# 총 3140개 리뷰 크롤링
# 총 3160개 리뷰 크롤링
# 총 3180개 리뷰 크롤링
# 총 3200개 리뷰 크롤링
# 총 3220개 리뷰 크롤링
# 총 3240개 리뷰 크롤링
# 총 3260개 리뷰 크롤링
# 총 3280개 리뷰 크롤링
# 총 3300개 리뷰 크롤링
# 총 3320개 리뷰 크롤링
# 총 3340개 리뷰 크롤링
# 총 3360개 리뷰 크롤링
# 총 3380개 리뷰 크롤링
# 총 3400개 리뷰 크롤링
# 총 3420개 리뷰 크롤링
# 총 3440개 리뷰 크롤링
# 총 3460개 리뷰 크롤링
# 총 3480개 리뷰 크롤링
# 총 3500개 리뷰 크롤링
# 총 3520개 리뷰 크롤링
# 총 3540개 리뷰 크롤링
# 총 3560개 리뷰 크롤링
# 총 3580개 리뷰 크롤링
# 총 3600개 리뷰 크롤링
# 총 3620개 리뷰 크롤링
# 총 3640개 리뷰 크롤링
# 총 3660개 리뷰 크롤링
# 총 3680개 리뷰 크롤링
# 총 3700개 리뷰 크롤링
# 총 3720개 리뷰 크롤링
# 총 3740개 리뷰 크롤링
# 총 3760개 리뷰 크롤링
# 총 3780개 리뷰 크롤링
# 총 3800개 리뷰 크롤링
# 총 3820개 리뷰 크롤링
# 총 3840개 리뷰 크롤링
# 총 3860개 리뷰 크롤링
# 총 3880개 리뷰 크롤링
# 총 3900개 리뷰 크롤링
# 총 3920개 리뷰 크롤링
# 총 3940개 리뷰 크롤링
# 총 3960개 리뷰 크롤링
# 총 3980개 리뷰 크롤링
# 총 4000개 리뷰 크롤링
# 총 4020개 리뷰 크롤링
# 총 4040개 리뷰 크롤링
# 총 4060개 리뷰 크롤링
# 총 4080개 리뷰 크롤링
# 총 4100개 리뷰 크롤링
# 총 4120개 리뷰 크롤링
# 총 4140개 리뷰 크롤링
# 총 4160개 리뷰 크롤링
# 총 4180개 리뷰 크롤링
# 총 4200개 리뷰 크롤링
# 총 4220개 리뷰 크롤링
# 총 4240개 리뷰 크롤링
# 총 4260개 리뷰 크롤링
# 총 4280개 리뷰 크롤링
# 총 4300개 리뷰 크롤링
# 총 4320개 리뷰 크롤링
# 총 4340개 리뷰 크롤링
# 총 4360개 리뷰 크롤링
# 총 4380개 리뷰 크롤링
# 총 4400개 리뷰 크롤링
# 총 4420개 리뷰 크롤링
# 총 4440개 리뷰 크롤링
# 총 4460개 리뷰 크롤링
# 총 4480개 리뷰 크롤링
# 총 4500개 리뷰 크롤링
# 총 4520개 리뷰 크롤링
# 총 4540개 리뷰 크롤링
# 총 4560개 리뷰 크롤링
# 총 4580개 리뷰 크롤링
# 총 4600개 리뷰 크롤링
# 총 4620개 리뷰 크롤링
# 총 4640개 리뷰 크롤링
# 총 4660개 리뷰 크롤링
# 총 4680개 리뷰 크롤링
# 총 4700개 리뷰 크롤링
# 총 4720개 리뷰 크롤링
# 총 4740개 리뷰 크롤링
# 총 4760개 리뷰 크롤링
# 총 4780개 리뷰 크롤링
# 총 4800개 리뷰 크롤링
# 총 4820개 리뷰 크롤링
# 총 4840개 리뷰 크롤링
# 총 4860개 리뷰 크롤링
# 총 4880개 리뷰 크롤링
# 총 4900개 리뷰 크롤링
# 총 4920개 리뷰 크롤링
# 총 4940개 리뷰 크롤링
# 총 4960개 리뷰 크롤링
# 총 4980개 리뷰 크롤링
# 총 5000개 리뷰 크롤링
# 총 5020개 리뷰 크롤링
# 총 5040개 리뷰 크롤링
# 총 5060개 리뷰 크롤링
# 총 5080개 리뷰 크롤링
# 총 5100개 리뷰 크롤링
# 총 5120개 리뷰 크롤링
# 총 5140개 리뷰 크롤링
# 총 5160개 리뷰 크롤링
# 총 5180개 리뷰 크롤링
# 총 5200개 리뷰 크롤링
# 총 5220개 리뷰 크롤링
# 총 5240개 리뷰 크롤링
# 총 5260개 리뷰 크롤링
# 총 5280개 리뷰 크롤링
# 총 5300개 리뷰 크롤링
# 총 5320개 리뷰 크롤링
# 총 5340개 리뷰 크롤링
# 총 5360개 리뷰 크롤링
# 총 5380개 리뷰 크롤링
# 총 5400개 리뷰 크롤링
# 총 5420개 리뷰 크롤링
# 총 5440개 리뷰 크롤링
# 총 5460개 리뷰 크롤링
# 총 5480개 리뷰 크롤링
# 총 5500개 리뷰 크롤링
# 총 5520개 리뷰 크롤링
# 총 5540개 리뷰 크롤링
# 총 5560개 리뷰 크롤링
# 총 5580개 리뷰 크롤링
# 총 5600개 리뷰 크롤링
# 총 5620개 리뷰 크롤링
# 총 5640개 리뷰 크롤링
# 총 5660개 리뷰 크롤링
# 총 5680개 리뷰 크롤링
# 총 5700개 리뷰 크롤링
# 총 5720개 리뷰 크롤링
# 총 5740개 리뷰 크롤링
# 총 5760개 리뷰 크롤링
# 총 5780개 리뷰 크롤링
# 총 5800개 리뷰 크롤링
# 총 5820개 리뷰 크롤링
# 총 5840개 리뷰 크롤링
# 총 5860개 리뷰 크롤링
# 총 5880개 리뷰 크롤링
# 총 5900개 리뷰 크롤링
# 총 5920개 리뷰 크롤링
# 총 5940개 리뷰 크롤링
# 총 5960개 리뷰 크롤링
# 총 5980개 리뷰 크롤링
# 총 6000개 리뷰 크롤링
# 총 6020개 리뷰 크롤링
# 총 6040개 리뷰 크롤링
# 총 6060개 리뷰 크롤링
# 총 6080개 리뷰 크롤링
# 총 6100개 리뷰 크롤링
# 총 6120개 리뷰 크롤링
# 총 6140개 리뷰 크롤링
# 총 6160개 리뷰 크롤링
# 총 6180개 리뷰 크롤링
# 총 6200개 리뷰 크롤링
# 총 6220개 리뷰 크롤링
# 총 6240개 리뷰 크롤링
# 총 6260개 리뷰 크롤링
# 총 6280개 리뷰 크롤링
# 총 6300개 리뷰 크롤링
# 총 6320개 리뷰 크롤링
# 총 6340개 리뷰 크롤링
# 총 6360개 리뷰 크롤링
# 총 6380개 리뷰 크롤링
# 총 6400개 리뷰 크롤링
# 총 6420개 리뷰 크롤링
# 총 6440개 리뷰 크롤링
# 총 6460개 리뷰 크롤링
# 총 6480개 리뷰 크롤링
# 총 6500개 리뷰 크롤링
# 총 6520개 리뷰 크롤링
# 총 6540개 리뷰 크롤링
# 총 6560개 리뷰 크롤링
# 총 6580개 리뷰 크롤링
# 총 6600개 리뷰 크롤링
# 총 6620개 리뷰 크롤링
# 총 6640개 리뷰 크롤링
# 총 6660개 리뷰 크롤링
# 총 6680개 리뷰 크롤링
# 총 6700개 리뷰 크롤링
# 총 6720개 리뷰 크롤링
# 총 6740개 리뷰 크롤링
# 총 6760개 리뷰 크롤링
# 총 6780개 리뷰 크롤링
# 총 6800개 리뷰 크롤링
# 총 6820개 리뷰 크롤링
# 총 6840개 리뷰 크롤링
# 총 6860개 리뷰 크롤링
# 총 6880개 리뷰 크롤링
# 총 6900개 리뷰 크롤링
# 총 6920개 리뷰 크롤링
# 총 6940개 리뷰 크롤링
# 총 6960개 리뷰 크롤링
# 총 6980개 리뷰 크롤링
# 총 7000개 리뷰 크롤링
# 총 7020개 리뷰 크롤링
# 총 7040개 리뷰 크롤링
# 총 7060개 리뷰 크롤링
# 총 7080개 리뷰 크롤링
# 총 7100개 리뷰 크롤링
# 총 7120개 리뷰 크롤링
# 총 7140개 리뷰 크롤링
# 총 7160개 리뷰 크롤링
# 총 7180개 리뷰 크롤링
# 총 7200개 리뷰 크롤링
# 총 7220개 리뷰 크롤링
# 총 7240개 리뷰 크롤링
# 총 7260개 리뷰 크롤링
# 총 7280개 리뷰 크롤링
# 총 7300개 리뷰 크롤링
# 총 7320개 리뷰 크롤링
# 총 7340개 리뷰 크롤링
# 총 7360개 리뷰 크롤링
# 총 7380개 리뷰 크롤링
# 총 7400개 리뷰 크롤링
# 총 7420개 리뷰 크롤링
# 총 7440개 리뷰 크롤링
# 총 7460개 리뷰 크롤링
# 총 7480개 리뷰 크롤링
# 총 7500개 리뷰 크롤링
# 총 7520개 리뷰 크롤링
# 총 7540개 리뷰 크롤링
# 총 7560개 리뷰 크롤링
# 총 7580개 리뷰 크롤링
# 총 7600개 리뷰 크롤링
# 총 7620개 리뷰 크롤링
# 총 7640개 리뷰 크롤링
# 총 7660개 리뷰 크롤링
# 총 7680개 리뷰 크롤링
# 총 7700개 리뷰 크롤링
# 총 7720개 리뷰 크롤링
# 총 7740개 리뷰 크롤링
# 총 7760개 리뷰 크롤링
# 총 7780개 리뷰 크롤링
# 총 7800개 리뷰 크롤링
# 총 7820개 리뷰 크롤링
# 총 7840개 리뷰 크롤링
# 총 7860개 리뷰 크롤링
# 총 7880개 리뷰 크롤링
# 총 7900개 리뷰 크롤링
# 총 7920개 리뷰 크롤링
# 총 7940개 리뷰 크롤링
# 총 7960개 리뷰 크롤링
# 총 7980개 리뷰 크롤링
# 총 8000개 리뷰 크롤링
# 총 8020개 리뷰 크롤링
# 총 8040개 리뷰 크롤링
# 총 8060개 리뷰 크롤링
# 총 8080개 리뷰 크롤링
# 총 8100개 리뷰 크롤링
# 총 8120개 리뷰 크롤링
# 총 8140개 리뷰 크롤링
# 총 8160개 리뷰 크롤링
# 총 8180개 리뷰 크롤링
# 총 8200개 리뷰 크롤링
# 총 8220개 리뷰 크롤링
# 총 8240개 리뷰 크롤링
# 총 8260개 리뷰 크롤링
# 총 8280개 리뷰 크롤링
# 총 8300개 리뷰 크롤링
# 총 8320개 리뷰 크롤링
# 총 8340개 리뷰 크롤링
# 총 8360개 리뷰 크롤링
# 총 8380개 리뷰 크롤링
# 총 8400개 리뷰 크롤링
# 총 8420개 리뷰 크롤링
# 총 8440개 리뷰 크롤링
# 총 8460개 리뷰 크롤링
# 총 8480개 리뷰 크롤링
# 총 8500개 리뷰 크롤링
# 총 8520개 리뷰 크롤링
# 총 8540개 리뷰 크롤링
# 총 8560개 리뷰 크롤링
# 총 8580개 리뷰 크롤링
# 총 8600개 리뷰 크롤링
# 총 8620개 리뷰 크롤링
# 총 8640개 리뷰 크롤링
# 총 8660개 리뷰 크롤링
# 총 8680개 리뷰 크롤링
# 총 8700개 리뷰 크롤링
# 총 8720개 리뷰 크롤링
# 총 8740개 리뷰 크롤링
# 총 8760개 리뷰 크롤링
# 총 8780개 리뷰 크롤링
# 총 8800개 리뷰 크롤링
# 총 8820개 리뷰 크롤링
# 총 8840개 리뷰 크롤링
# 총 8860개 리뷰 크롤링
# 총 8880개 리뷰 크롤링
# 총 8900개 리뷰 크롤링
# 총 8920개 리뷰 크롤링
# 총 8940개 리뷰 크롤링
# 총 8960개 리뷰 크롤링
# 총 8980개 리뷰 크롤링
# 총 9000개 리뷰 크롤링
# 총 9020개 리뷰 크롤링
# 총 9040개 리뷰 크롤링
# 총 9060개 리뷰 크롤링
# 총 9080개 리뷰 크롤링
# 총 9100개 리뷰 크롤링
# 총 9120개 리뷰 크롤링
# 총 9140개 리뷰 크롤링
# 총 9160개 리뷰 크롤링
# 총 9180개 리뷰 크롤링
# 총 9200개 리뷰 크롤링
# 총 9220개 리뷰 크롤링
# 총 9240개 리뷰 크롤링
# 총 9260개 리뷰 크롤링
# 총 9280개 리뷰 크롤링
# 총 9300개 리뷰 크롤링
# 총 9320개 리뷰 크롤링
# 총 9340개 리뷰 크롤링
# 총 9360개 리뷰 크롤링
# 총 9380개 리뷰 크롤링
# 총 9400개 리뷰 크롤링
# 총 9420개 리뷰 크롤링
# 총 9440개 리뷰 크롤링
# 총 9460개 리뷰 크롤링
# 총 9480개 리뷰 크롤링
# 총 9500개 리뷰 크롤링
# 총 9520개 리뷰 크롤링
# 총 9540개 리뷰 크롤링
# 총 9560개 리뷰 크롤링
# 총 9580개 리뷰 크롤링
# 총 9600개 리뷰 크롤링
# 총 9620개 리뷰 크롤링
# 총 9640개 리뷰 크롤링
# 총 9660개 리뷰 크롤링
# 총 9680개 리뷰 크롤링
# 총 9700개 리뷰 크롤링
# 총 9720개 리뷰 크롤링
# 총 9740개 리뷰 크롤링
# 총 9760개 리뷰 크롤링
# 총 9780개 리뷰 크롤링
# 총 9800개 리뷰 크롤링
# 총 9820개 리뷰 크롤링
# 총 9840개 리뷰 크롤링
# 총 9860개 리뷰 크롤링
# 총 9880개 리뷰 크롤링
# 총 9900개 리뷰 크롤링
# 총 9920개 리뷰 크롤링
# 총 9940개 리뷰 크롤링
# 총 9960개 리뷰 크롤링
# 총 9980개 리뷰 크롤링
# 총 10000개 리뷰 크롤링
# 총 10020개 리뷰 크롤링
# 총 10040개 리뷰 크롤링
# 총 10060개 리뷰 크롤링
# 총 10080개 리뷰 크롤링
# 총 10100개 리뷰 크롤링
# 총 10120개 리뷰 크롤링
# 총 10140개 리뷰 크롤링
# 총 10160개 리뷰 크롤링
# 총 10180개 리뷰 크롤링
# 총 10200개 리뷰 크롤링
# 총 10220개 리뷰 크롤링
# 총 10240개 리뷰 크롤링
# 총 10260개 리뷰 크롤링
# 총 10280개 리뷰 크롤링
# 총 10300개 리뷰 크롤링
# 총 10320개 리뷰 크롤링
# 총 10340개 리뷰 크롤링
# 총 10360개 리뷰 크롤링
# 총 10380개 리뷰 크롤링
# 총 10400개 리뷰 크롤링
# 총 10420개 리뷰 크롤링
# 총 10440개 리뷰 크롤링
# 총 10460개 리뷰 크롤링
# 총 10480개 리뷰 크롤링
# 총 10500개 리뷰 크롤링
# 총 10520개 리뷰 크롤링
# 총 10540개 리뷰 크롤링
# 총 10560개 리뷰 크롤링
# 총 10580개 리뷰 크롤링
# 총 10600개 리뷰 크롤링
# 총 10620개 리뷰 크롤링
# 총 10640개 리뷰 크롤링
# 총 10660개 리뷰 크롤링
# 총 10680개 리뷰 크롤링
# 총 10700개 리뷰 크롤링
# 총 10720개 리뷰 크롤링
# 총 10740개 리뷰 크롤링
# 총 10760개 리뷰 크롤링
# 총 10780개 리뷰 크롤링
# 총 10800개 리뷰 크롤링
# 총 10820개 리뷰 크롤링
# 총 10840개 리뷰 크롤링
# 총 10860개 리뷰 크롤링
# 총 10880개 리뷰 크롤링
# 총 10900개 리뷰 크롤링
# 총 10920개 리뷰 크롤링
# 총 10940개 리뷰 크롤링
# 총 10960개 리뷰 크롤링
# 총 10980개 리뷰 크롤링
# 총 11000개 리뷰 크롤링
# 총 11020개 리뷰 크롤링
# 총 11040개 리뷰 크롤링
# 총 11060개 리뷰 크롤링
# 총 11080개 리뷰 크롤링
# 총 11100개 리뷰 크롤링
# 총 11120개 리뷰 크롤링
# 총 11140개 리뷰 크롤링
# 총 11160개 리뷰 크롤링
# 총 11180개 리뷰 크롤링
# 총 11200개 리뷰 크롤링
# 총 11220개 리뷰 크롤링
# 총 11240개 리뷰 크롤링
# 총 11260개 리뷰 크롤링
# 총 11280개 리뷰 크롤링
# 총 11300개 리뷰 크롤링
# 총 11320개 리뷰 크롤링
# 총 11340개 리뷰 크롤링
# 총 11360개 리뷰 크롤링
# 총 11380개 리뷰 크롤링
# 총 11400개 리뷰 크롤링
# 총 11420개 리뷰 크롤링
# 총 11440개 리뷰 크롤링
# 총 11460개 리뷰 크롤링
# 총 11480개 리뷰 크롤링
# 총 11500개 리뷰 크롤링
# 총 11520개 리뷰 크롤링
# 총 11540개 리뷰 크롤링
# 총 11560개 리뷰 크롤링
# 총 11580개 리뷰 크롤링
# 총 11600개 리뷰 크롤링
# 총 11620개 리뷰 크롤링
# 총 11640개 리뷰 크롤링
# 총 11660개 리뷰 크롤링
# 총 11680개 리뷰 크롤링
# 총 11700개 리뷰 크롤링
# 총 11720개 리뷰 크롤링
# 총 11740개 리뷰 크롤링
# 총 11760개 리뷰 크롤링
# 총 11780개 리뷰 크롤링
# 총 11800개 리뷰 크롤링
# 총 11820개 리뷰 크롤링
# 총 11840개 리뷰 크롤링
# 총 11860개 리뷰 크롤링
# 총 11880개 리뷰 크롤링
# 총 11900개 리뷰 크롤링
# 총 11920개 리뷰 크롤링
# 총 11940개 리뷰 크롤링
# 총 11960개 리뷰 크롤링
# 총 11980개 리뷰 크롤링
# 총 12000개 리뷰 크롤링
# 총 12020개 리뷰 크롤링
# 총 12040개 리뷰 크롤링
# 총 12060개 리뷰 크롤링
# 총 12080개 리뷰 크롤링
# 총 12100개 리뷰 크롤링
# 총 12120개 리뷰 크롤링
# 총 12140개 리뷰 크롤링
# 총 12160개 리뷰 크롤링
# 총 12180개 리뷰 크롤링
# 총 12200개 리뷰 크롤링
# 총 12220개 리뷰 크롤링
# 총 12240개 리뷰 크롤링
# 총 12260개 리뷰 크롤링
# 총 12280개 리뷰 크롤링
# 총 12300개 리뷰 크롤링
# 총 12320개 리뷰 크롤링
# 총 12340개 리뷰 크롤링
# 총 12360개 리뷰 크롤링
# 총 12380개 리뷰 크롤링
# 총 12400개 리뷰 크롤링
# 총 12420개 리뷰 크롤링
# 총 12440개 리뷰 크롤링
# 총 12460개 리뷰 크롤링
# 총 12480개 리뷰 크롤링
# 총 12500개 리뷰 크롤링
# 총 12520개 리뷰 크롤링
# 총 12540개 리뷰 크롤링
# 총 12560개 리뷰 크롤링
# 총 12580개 리뷰 크롤링
# 총 12600개 리뷰 크롤링
# 총 12620개 리뷰 크롤링
# 총 12640개 리뷰 크롤링
# 총 12660개 리뷰 크롤링
# 총 12680개 리뷰 크롤링
# 총 12700개 리뷰 크롤링
# 총 12720개 리뷰 크롤링
# 총 12740개 리뷰 크롤링
# 총 12760개 리뷰 크롤링
# 총 12780개 리뷰 크롤링
# 총 12800개 리뷰 크롤링
# 총 12820개 리뷰 크롤링
# 총 12840개 리뷰 크롤링
# 총 12860개 리뷰 크롤링
# 총 12880개 리뷰 크롤링
# 총 12900개 리뷰 크롤링
# 총 12920개 리뷰 크롤링
# 총 12940개 리뷰 크롤링
# 총 12960개 리뷰 크롤링
# 총 12980개 리뷰 크롤링
# 총 13000개 리뷰 크롤링
# 총 13020개 리뷰 크롤링
# 13022개 리뷰 크롤링, 다음
# 총 13022개 리뷰 크롤링

# %%
len(text_list), len(star_list)
# Out:
# (13022, 13022)

# %%
data = {'date' : date_list,
        'star' : star_list,
        'text' : text_list
        }

df = pd.DataFrame(data)

df['date'] = pd.to_datetime(('20' + df['date']))

len(df)
# Out:
# 13022

# %%
df
# Out:
#             date star                                               text
# 0     2022-11-22    5  표문 막걸리는 제가 제일 좋아하는 막걸리예요표문막걸리 런칭 첫 라이브 에서부터 편의...
# 1     2022-11-22    5  와라이브 이벤트에 후디 당첨되었어요와 진짜 당첨될줄 몰랐는데 너무 기분이 좋네요후디...
# 2     2022-11-26    5  한강주조를 처음 알게된건 인사동 어느 고기집이었는데 부모님과 함께 간단히 마시려고 ...
# 3     2022-11-28    5  축구경기 보며 마셨어요부드럽고 은은한 단맛이 너무 좋아요계속 생각나는 맛이네요 라이...
# 4     2022-11-24    5          가격이 많이 내렸네여곰표 막걸리 중독성있습니다쏘는맛없지만 부드럽고 맛있어요
# ...          ...  ...                                                ...
# 13017 2021-04-27    5
# 13018 2021-04-25    5                               캠핑와서 먹었어요부드럽게 잘 넘어가요
# 13019 2021-04-07    5                                       감사합니다 또감사합니다
# 13020 2022-04-30    5                               다른 막걸리랑 달라요도특하고 맛있어요
# 13021 2022-04-20    5                                늘 먹던거 냉장고 떨어지면 불안해요
#
# [13022 rows x 3 columns]

# %%
df.dropna(inplace=True) # 글이없는 리뷰 드랍
df.reset_index(drop=True, inplace=True)
df
# Out:
#             date star                                               text
# 0     2022-11-22    5  표문 막걸리는 제가 제일 좋아하는 막걸리예요표문막걸리 런칭 첫 라이브 에서부터 편의...
# 1     2022-11-22    5  와라이브 이벤트에 후디 당첨되었어요와 진짜 당첨될줄 몰랐는데 너무 기분이 좋네요후디...
# 2     2022-11-26    5  한강주조를 처음 알게된건 인사동 어느 고기집이었는데 부모님과 함께 간단히 마시려고 ...
# 3     2022-11-28    5  축구경기 보며 마셨어요부드럽고 은은한 단맛이 너무 좋아요계속 생각나는 맛이네요 라이...
# 4     2022-11-24    5          가격이 많이 내렸네여곰표 막걸리 중독성있습니다쏘는맛없지만 부드럽고 맛있어요
# ...          ...  ...                                                ...
# 13017 2021-04-27    5
# 13018 2021-04-25    5                               캠핑와서 먹었어요부드럽게 잘 넘어가요
# 13019 2021-04-07    5                                       감사합니다 또감사합니다
# 13020 2022-04-30    5                               다른 막걸리랑 달라요도특하고 맛있어요
# 13021 2022-04-20    5                                늘 먹던거 냉장고 떨어지면 불안해요
#
# [13022 rows x 3 columns]

# %%
df[df.text.str.contains('BEST|한달사용기|재구매')] # 머릿말 들어갔는지 확인
# Out:
#             date star                                               text
# 15    2022-11-22    5                               월드컵 응원하기 위해 재구매합니다ㅎㅎ
# 25    2022-10-27    5                                      맛있었어요 재구매 할게요
# 64    2022-10-24    5                                 맛있게 잘 먹었어요재구매 할겁니다
# 76    2022-09-15    5             재구매해서 먹고 맛있어서 또 시켰습니다 적당히 달달하고 목넘김 좋아요
# 120   2022-08-03    1  그냥 가격만 비싸고 대박이나 장수가 훨씬 맛있네요 가격도 500m에 4천원꼴인데 재...
# ...          ...  ...                                                ...
# 12852 2021-04-29    5                                재구매  또 했어용 9시만 기다려용
# 12894 2021-04-13    1                        배송 최악가격대비 양 챵렬맛 평범재구매 의사 없음
# 12898 2021-04-21    5                        어제 받았습니다넘 기대되네요맛있으면 재구매하려구요
# 12935 2021-04-13    5                            역시 곰표  재구매 할거에요넘 맛있어요ㅜㅜ
# 12995 2021-04-13    5                                         재구매 하고 싶어요
#
# [425 rows x 3 columns]

# %%
df[df.text.duplicated(keep= False)] # 중복 확인

# df.drop_duplicates(['text'],ignore_index=True, inplace=True) # 중복 제거
# Out:
#             date star          text
# 20    2022-11-19    5   배송도 빠르고 좋네요
# 36    2022-11-07    4     부드럽고 맛있네요
# 43    2022-11-02    5    빠르게 잘받았습니다
# 44    2022-10-30    5   빠른 배송 감사합니다
# 45    2022-10-30    5   빠른 배송 감사합니다
# ...          ...  ...           ...
# 13003 2021-05-01    5    너무너무너무 좋아요
# 13013 2021-04-07    5     달달하니 맛있어요
# 13016 2021-04-28    5
# 13017 2021-04-27    5
# 13019 2021-04-07    5  감사합니다 또감사합니다
#
# [1013 rows x 3 columns]

# %%
df
# Out:
#             date star                                               text
# 0     2022-11-22    5  표문 막걸리는 제가 제일 좋아하는 막걸리예요표문막걸리 런칭 첫 라이브 에서부터 편의...
# 1     2022-11-22    5  와라이브 이벤트에 후디 당첨되었어요와 진짜 당첨될줄 몰랐는데 너무 기분이 좋네요후디...
# 2     2022-11-26    5  한강주조를 처음 알게된건 인사동 어느 고기집이었는데 부모님과 함께 간단히 마시려고 ...
# 3     2022-11-28    5  축구경기 보며 마셨어요부드럽고 은은한 단맛이 너무 좋아요계속 생각나는 맛이네요 라이...
# 4     2022-11-24    5          가격이 많이 내렸네여곰표 막걸리 중독성있습니다쏘는맛없지만 부드럽고 맛있어요
# ...          ...  ...                                                ...
# 13017 2021-04-27    5
# 13018 2021-04-25    5                               캠핑와서 먹었어요부드럽게 잘 넘어가요
# 13019 2021-04-07    5                                       감사합니다 또감사합니다
# 13020 2022-04-30    5                               다른 막걸리랑 달라요도특하고 맛있어요
# 13021 2022-04-20    5                                늘 먹던거 냉장고 떨어지면 불안해요
#
# [13022 rows x 3 columns]

# %%
df.to_csv("술 리뷰(곰표막걸리).csv", encoding="utf-8-sig", index=False)
