# %%
from konlpy.tag import Okt
from collections import Counter
import pandas as pd
import numpy as np
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from PIL import Image

# %%
# 형태소 단위 분석
okt = Okt()
data = '오늘 날씨가 추워서 기분이 좋지 않다.'
okt.morphs(data)
# Out:
# ['오늘', '날씨', '가', '추워서', '기분', '이', '좋지', '않다', '.']

# %%
okt.nouns(data)
# Out:
# ['오늘', '날씨', '기분']

# %%
# 어절 추출
okt.phrases(data)
# Out:
# ['오늘', '오늘 날씨', '기분', '날씨']

# %%
# 형태소 분석
okt.pos(data)
# Out:
# [('오늘', 'Noun'),
#  ('날씨', 'Noun'),
#  ('가', 'Josa'),
#  ('추워서', 'Adjective'),
#  ('기분', 'Noun'),
#  ('이', 'Josa'),
#  ('좋지', 'Adjective'),
#  ('않다', 'Verb'),
#  ('.', 'Punctuation')]

# %%
df = pd.read_csv('ratings.txt', delimiter='\t')
df.head()
# Out:
#          id                                           document  label
# 0   8112052                                어릴때보고 지금다시봐도 재밌어요ㅋㅋ      1
# 1   8132799  디자인을 배우는 학생으로, 외국디자이너와 그들이 일군 전통을 통해 발전해가는 문화산...      1
# 2   4655635               폴리스스토리 시리즈는 1부터 뉴까지 버릴께 하나도 없음.. 최고.      1
# 3   9251303  와.. 연기가 진짜 개쩔구나.. 지루할거라고 생각했는데 몰입해서 봤다.. 그래 이런...      1
# 4  10067386                        안개 자욱한 밤하늘에 떠 있는 초승달 같은 영화.      1

# %%
x = df['document'][:1000]

n=[]
for i in x :
    n.append(x)

okt = Okt()
noun = okt.nouns(str(n))
count = Counter(noun)

nount_list = count.most_common(100)
for v in nount_list :
    print(v)
# Out:
# ('다시', 2000)
# ('연기', 2000)
# ('진짜', 2000)
# ('영화', 2000)
# ('최고다', 2000)
# ('정말', 2000)
# ('때', 1000)
# ('보고', 1000)
# ('지금', 1000)
# ('디자인', 1000)
# ('학생', 1000)
# ('외국', 1000)
# ('디자이너', 1000)
# ('그', 1000)
# ('일군', 1000)
# ('전통', 1000)
# ('통해', 1000)
# ('발전', 1000)
# ('화산', 1000)
# ('폴리스스토리', 1000)
# ('시리즈', 1000)
# ('부터', 1000)
# ('뉴', 1000)
# ('하나', 1000)
# ('최고', 1000)
# ('개', 1000)
# ('생각', 1000)
# ('몰입', 1000)
# ('안개', 1000)
# ('밤하늘', 1000)
# ('초승달', 1000)
# ('이준기', 1000)
# ('평점', 1000)
# ('왜', 1000)
# ('공감', 1000)
# ('점주', 1000)
# ('게', 1000)
# ('머', 1000)
# ('임', 1000)
# ('하이킥', 1000)
# ('뉴논', 1000)
# ('정준', 1000)
# ('용', 1000)
# ('선생님', 1000)
# ('대박', 1000)

# %%
word_list = []
word_list = df['document'][:3000]

tag = []
for i in word_list :
    tag.append(okt.pos(i))

# 명사 추출
noun_list = []
for i in tag:
    for word, tag in i:
        if(tag in ['Noun']):
            noun_list.append(word)
        else:
            pass
noun_list
# Out:
# ['때',
#  '보고',
#  '지금',
#  '다시',
#  '디자인',
#  '학생',
#  '외국',
#  '디자이너',
#  '그',
#  '일군',
#  '전통',
#  '통해',
#  '발전',
#  '문화',
#  '산업',
#  '사실',
#  '우리나라',
#  '그',
#  '시절',
#  '끝',
#  '열정',
#  '노라노',
#  '전통',
#  '저',
#  '사람',
#  '꿈',
#  '수',
#  '것',
#  '폴리스스토리',
#  '시리즈',
#  '부터',
#  '뉴',
#  '하나',
#  '최고',
#  '연기',
#  '진짜',
#  '개',
#  '생각',
#  '몰입',
#  '진짜',
#  '영화',
#  '안개',
#  '밤하늘',
#  '초승달',
#  '영화',
#  '사랑',
#  '사람',
#  '라면',
#  '처음',
#  '끝',
#  '영화',
#  '완전',
#  '감동',
#  '다시',
#  '감동',
#  '개',
#  '전쟁',
#  '빠',
#  '보고',
#  '굿',
#  '바보',
#  '병',
#  '쉰',
#  '내',
#  '나이',
#  '영화',
#  '지금',
#  '나',
#  '감동',
#  '훗날',
#  '다시',
#  '사하나',
#  '그',
#  '감정',
#  '이해',
#  '고질',
#  '무',
#  '능',
#  '영화',
#  '오페라',
#  '작품',
#  '극단',
#  '평',
#  '갈림',
#  '수',
#  '듯',
#  '도',
#  '반전',
#  '제',
#  '평점',
#  '왜',
#  '긴장감',
#  '스릴',
#  '감',
#  '진짜',
#  '최고',
#  '진짜',
#  '전장',
#  '공포',
#  '전',
#  '고시',
#  '터',
#  '소재',
#  '뿐',
#  '관련',
#  '단연',
#  '최고',
#  '가면',
#  '갈수록',
#  '더욱',
#  '드',
#  '밀회',
#  '화이팅',
#  '생각',
#  '수작',
#  '일본',
#  '영화',
#  '최고',
#  '마음',
#  '임팩트',
#  '일품',
#  '만',
#  '제대로',
#  '범죄',
#  '스릴러',
#  '때',
#  '사랑',
#  '도',
#  '마디',
#  '말',
#  '밤',
#  '잠',
#  '때',
#  '징텅',
#  '교복',
#  '션',
#  '이의',
#  '볼펜',
#  '자국',
#  '역시',
#  '미처',
#  '전하',
#  '못',
#  '마음',
#  '형태',
#  '거',
#  '마지막',
#  '씬',
#  '강압',
#  '용서',
#  '세뇌',
#  '용서',
#  '대한',
#  '비판',
#  '중세시대',
#  '명작',
#  '굿',
#  '평점',
#  '왜',
#  '영상',
#  '존재',
#  '꼭',
#  '한번',
#  '제니퍼',
#  '코넬',
#  '리',
#  '아역시절',
#  '로버트',
#  '드니',
#  '의',
#  '마지막',
#  '장면',
#  '정말',
#  '가슴속',
#  '기억',
#  '최고',
#  '명작',
#  '사람',
#  '짓',
#  '수가',
#  '내',
#  '인간',
#  '잠재',
#  '악마',
#  '성은',
#  '여러',
#  '시간',
#  '공간',
#  '속',
#  '존속',
#  '이',
#  '다큐',
#  '그것',
#  '광',
#  '재현',
#  '최고다',
#  '삼일',
#  '동안',
#  '틈틈이',
#  '잠도',
#  '여운',
#  '실화',
#  '더욱',
#  '충격',
#  '어디',
#  '일어나서',
#  '각심',
#  '일',
#  '영화',
#  '존',
#  '그라샴',
#  '작품',
#  '라면',
#  '한번',
#  '농아인',
#  '문화',
#  '대한',
#  '거',
#  '때',
#  '봄',
#  '이정재',
#  '이범수',
#  '연기',
#  '쩜',
#  '친구',
#  '우정',
#  '매우',
#  '감동',
#  '굿굿굿',
#  '또',
#  '또해',
#  '제발',
#  '이',
#  '말',
#  '제이크',
#  '질렌할',
#  '넌',
#  '대체',
#  '연기',
#  '뭐',
#  '입가',
#  '미소',
#  '샤방샤방했던',
#  '영화',
#  '원표',
#  '왜',
#  '조연',
#  '이양',
#  '젤',
#  '마치',
#  '바다',
#  '속',
#  '아쿠아리움',
#  '속',
#  '느낌',
#  '영화',
#  '자녀',
#  '강추',
#  '정의',
#  '콜트',
#  '콜텍',
#  '노동자',
#  '이야기',
#  '이',
#  '화보',
#  '브라질',
#  '마음',
#  '난',
#  '남자',
#  '영화',
#  '내내',
#  '마음',
#  '내',
#  '두',
#  '여배우',
#  '도법',
#  '멤버',
#  '모두',
#  '기대',
#  '정말',
#  '영화',
#  '액션',
#  '최고',
#  '내',
#  '남자',
#  '런가',
#  '거',
#  '긴장감',
#  '흥미진진',
#  '나',
#  '런가',
#  '워낙',
#  '격투씬',
#  '그냥',
#  '생각',
#  '집',
#  '스마트',
#  '티비',
#  '봄',
#  '거',
#  '영화',
#  '인지도',
#  '암살',
#  '이정재',
#  '봄',
#  '하여튼',
#  '인정',
#  '인정',
#  '파르',
#  '년',
#  '북한',
#  '살',
#  '왜',
#  '목숨',
#  '대한민국',
#  '그거',
#  '납득',
#  '나불',
#  '거려',
#  '종북',
#  '박평',
#  '년',
#  '수',
#  '그대',
#  '비',
#  '그대',
#  '시작',
#  '얼굴',
#  '주인공',
#  '매력',
#  '이구',
#  '영화',
#  '용이',
#  '정말',
#  '요즘',
#  '아이돌',
#  '배우',
#  '해먹',
#  '정도',
#  '연기',
#  '정말재밋',
#  '봣는대',
#  '조',
#  '탱고',
#  '음악',
#  '감동',
#  '평생',
#  '후회',
#  '명작',
#  '드라마',
#  '생각',
#  '것',
#  '영상',
#  '미도',
#  '캐릭터',
#  '매력',
#  '여러가지',
#  '매력',
#  '드라마',
#  '정말',
#  '최고',
#  '마지막',
#  '결말',
#  '왜',
#  '이제',
#  '알',
#  '영화',
#  '재미',
#  '내',
#  '영화',
#  '중',
#  '순위',
#  '영화',
#  '역시',
#  '신동엽',
#  '순간',
#  '캐치',
#  '탁',
#  '감탄',
#  '이영자',
#  '함',
#  '대박',
#  '이동욱',
#  '내',
#  '인생',
#  '영화',
#  '전작',
#  '사실',
#  '쓰레기',
#  '한국영',
#  '점',
#  '별로',
#  '니',
#  '지금',
#  '다소',
#  '당시',
#  '눈물',
#  '사발',
#  '영화',
#  '신부',
#  '로서',
#  '명감',
#  '실천',
#  '제리',
#  '자신',
#  '부정',
#  '로키',
#  '우정',
#  '원주율',
#  '메이커',
#  '추석',
#  '때',
#  '특선영화',
#  '진짜',
#  '가족',
#  '끼리',
#  '보기',
#  '영화',
#  '우리',
#  '애기',
#  '영화',
#  '선택',
#  '거',
#  '생각',
#  '괜찬',
#  '조합',
#  '게',
#  '바로',
#  '대의',
#  '어머니',
#  '나',
#  '뭐',
#  '원작',
#  '사람',
#  '드래곤볼',
#  '에볼루션',
#  '만듬',
#  '우리나라',
#  '예능',
#  '중',
#  '최고',
#  '방학',
#  '때',
#  '아침',
#  '눈',
#  '티비',
#  '채널',
#  '이',
#  '영화',
#  '정말',
#  '마음',
#  '이',
#  '영화',
#  '다시',
#  '볼',
#  '수',
#  '것',
#  '엔트랩먼트',
#  '정말',
#  '권력',
#  '친구',
#  '의리',
#  '역사',
#  '사실',
#  '줌',
#  '처음',
#  '초롱',
#  '팬심',
#  '갈수록',
#  '내용',
#  '배경음악',
#  '달달',
#  '보고',
#  '완전',
#  '중간',
#  '본방',
#  '사수',
#  '스토리',
#  '흥미진진',
#  '화',
#  '배우',
#  '연기',
#  '어디',
#  '요새',
#  '수백향',
#  '내',
#  '인생',
#  '제목',
#  '음',
#  '화질',
#  '재미',
#  '가을로',
#  '가을',
#  '감동',
#  '요',
#  '때문',
#  '이건',
#  '뭐',
#  '말',
#  '벌써',
#  '퀄리티',
#  '중',
#  '일단',
#  '까지봣다',
#  '뭐',
#  '말',
#  '장국영',
#  '자살',
#  '사실',
#  '더',
#  '극적',
#  '뀰잼',
#  '뀰잼',
#  '구',
#  '짱',
#  '오',
#  '느낌',
#  '예전',
#  '양심',
#  '냉장고',
#  '감정',
#  '움찔',
#  '한가지',
#  '부탁',
#  '연기자',
#  '좀',
#  '보호',
#  '욕',
#  '폭력',
#  '걱정',
#  '저',
#  '적',
#  '성추행',
#  '상가',
#  '모든',
#  '사람',
#  '목격',
#  '증언',
#  '덕분',
#  '청소년',
#  '는',
#  '계속',
#  '경찰서',
#  '남자',
#  '주인공',
#  '멋있쪙',
#  '재밋었다',
#  '영화',
#  '중',
#  '세기',
#  '최고',
#  '수',
#  '걸',
#  '평점',
#  '사람',
#  '정말',
#  '비디오',
#  '방',
#  '친구',
#  '정말',
#  '느낌',
#  '지금',
#  '또',
#  '틈',
#  '남기남',
#  '감독',
#  '그',
#  '이름',
#  '하나',
#  '점',
#  '진짜',
#  '최고다',
#  '최고',
#  '성룡',
#  '형님',
#  '마이',
#  '우상',
#  '당신',
#  '장르',
#  '뭐',
#  '이영화',
#  '영화',
#  '장르',
#  '원',
#  '지금',
#  '영화',
#  '최고다',
#  '리타',
#  '자꾸',
#  '생각',
#  '죄책감',
#  '도잠',
#  '때',
#  '보고',
#  '커서',
#  '다시',
#  '진짜',
#  '영화',
#  '웃음',
#  '감동',
#  '정치',
#  '대한',
#  '비판',
#  '묘사',
#  '표현',
#  '흥행',
#  '기억',
#  '안나',
#  '절대',
#  '평점',
#  '영화',
#  '생각',
#  '연기자',
#  '연기',
#  '디테',
#  '일만',
#  '봉임',
#  '대박',
#  '이건',
#  '한마디',
#  '사랑',
#  '달기',
#  '게',
#  '거',
#  '마음',
#  '볼',
#  '수록',
#  '영화',
#  '살이',
#  '엇냐',
#  '남자',
#  '얼굴',
#  '성격',
#  '점',
#  '만점',
#  '점',
#  '다음',
#  '핡',
#  '초반',
#  '설정',
#  '몰입',
#  '점차',
#  '이건',
#  '판타지',
#  '우리',
#  '미래',
#  '현실',
#  '언론',
#  '탄압',
#  '대한',
#  '은유',
#  '생각',
#  '남자',
#  '주인공',
#  '오카다',
#  '예상',
#  '별',
#  '기대',
#  '의외',
#  '재미',
#  '감동',
#  '인도영화',
#  '역시',
#  '스토리',
#  '영상',
#  '배우',
#  '연기',
#  '뭐',
#  '하나',
#  '영화',
#  '대박',
#  '감동',
#  '진짜',
#  '웃음',
#  '무엇',
#  '알',
#  '수',
#  '다그',
#  '웃',
#  '때',
#  '좀',
#  '허정무',
#  '대신',
#  '장외룡',
#  '감독',
#  '한국',
#  '국',
#  '고고싱',
#  '어찌',
#  '명감',
#  '수',
#  '말',
#  '정말',
#  '계속',
#  '미소',
#  '보조개',
#  '정말',
#  '메이',
#  '션',
#  '최고봉',
#  '하나',
#  '초딩',
#  '때',
#  '진짜',
#  '봣음',
#  '비포미드나잇',
#  '마지막',
#  '그',
#  '내',
#  '심정',
#  '또한',
#  '한편',
#  '그',
#  '모습',
#  '절로',
#  '웃음',
#  '재미',
#  '뭔가',
#  '코',
#  '스케',
#  '라디오',
#  '임진강',
#  '때',
#  '눈물',
#  '한석규',
#  '연기',
#  '짱',
#  '쵝오',
#  '진짜',
#  '허니',
#  '잼',
#  '꿀잼',
#  '개꿀잼',
#  '꼭',
#  '한예슬',
#  '진짜',
#  '원래',
#  '옷',
#  '헤어',
#  '메이크업',
#  '드라마',
#  '내용',
#  '한마디',
#  '최고',
#  '재미',
#  '반',
#  '기대',
#  '네',
#  '더욱',
#  '명작',
#  '정말',
#  '완전',
#  '훈남',
#  '쉐프',
#  '보구',
#  '요리',
#  '시나리오',
#  '비고',
#  '슨',
#  '연기',
#  '잼잼꿀잼',
#  '허니',
#  '잼핵잼잼잼',
#  '개인',
#  '언제',
#  '팬텀',
#  '크리스틴',
#  '일이',
#  '전혀',
#  '스토리',
#  '처럼',
#  '크리스틴',
#  '다시',
#  '남편',
#  '곁',
#  '아쉬움',
#  '젤',
#  '개인',
#  '알파',
#  '치노',
#  '때문',
#  '이',
#  '영화',
#  '처음',
#  '끝',
#  '명화',
#  '다시',
#  '뮤지컬',
#  '역대',
#  '위',
#  '이건',
#  '정말',
#  '대부',
#  '바람',
#  '레벨',
#  '영화',
#  '명의',
#  '주인공',
#  '마치',
#  '뮤지컬',
#  '마잭',
#  '마돈나',
#  '엘비스급',
#  '춤',
#  '노래실력',
#  '바비',
#  '바스코',
#  '이번',
#  '결과',
#  '대해',
#  '불만',
#  '사람',
#  '어쩌면',
#  '거지',
#  '바비',
#  '아이돌',
#  '어쩌',
#  '바비',
#  '자격',
#  '개인',
#  '생각',
#  '코미디',
#  '사극',
#  '장혁',
#  '명품',
#  '연기',
#  '땐',
#  '온',
#  '가족',
#  '이서',
#  '영화',
#  '처음',
#  '집',
#  '마련',
#  '사마',
#  '그날',
#  '저녁',
#  '영화',
#  '그',
#  '때',
#  '기분',
#  '탓',
#  '진',
#  '수가',
#  '옛날',
#  '워낭소리',
#  '때',
#  '진짜',
#  '내',
#  '인생',
#  '최고',
#  '명작',
#  '더빙',
#  '자막',
#  '더',
#  '데',
#  '뒤',
#  '포',
#  '씨',
#  '연말',
#  '추천',
#  '영화',
#  '배경음악',
#  '한국',
#  '사회',
#  '치부',
#  '예언',
#  '수작',
#  '제',
#  '영화',
#  '진짜',
#  '영화',
#  '지금',
#  '엣날',
#  '내',
#  '제일',
#  '영화',
#  '역시',
#  '최고',
#  '슈퍼',
#  '울트라',
#  '초',
#  '노막',
#  '입',
#  '때',
#  '매력',
#  '중동',
#  '문화',
#  '대해',
#  '알',
#  '영화',
#  '명',
#  '참여',
#  '길',
#  '얼마나',
#  '봄',
#  '좀',
#  '아버지',
#  '이자',
#  '남편',
#  '무사',
#  '로서',
#  '남자',
#  '일생',
#  '의미',
#  '죽음',
#  '일지',
#  '자신',
#  '신념',
#  '멋',
#  '진일',
#  '웃음',
#  '감동',
#  '물결',
#  '기대',
#  '안',
#  '쵝오임',
#  '영화',
#  '다만',
#  '엔딩',
#  '주인공',
#  '배심원',
#  '상대로',
#  '일장',
#  '연설',
#  '작위',
#  '신파',
#  '이',
#  '연설',
#  '배심원',
#  '무죄',
#  '것',
#  '만점',
#  '못',
#  '감동',
#  '저',
#  '정말',
#  '애정',
#  '둘',
#  '이야기',
#  '정말',
#  '그',
#  '멜로',
#  '드라마',
#  '것',
#  '수',
#  '정말',
#  '최영장군',
#  '이민호',
#  '전',
#  '이민호',
#  '드라마',
#  '중',
#  '최고',
#  '생각',
#  '영화',
#  '보고',
#  '안치환',
#  '내',
#  '꿈',
#  '방향',
#  '노래',
#  '제목',
#  '스토리',
#  '세기',
#  '최고',
#  '걸작',
#  '안보',
#  '고도',
#  '오스트레일리아',
#  '조금',
#  '프랑스',
#  '식',
#  '코미디',
#  '영화',
#  '것',
#  '생각',
#  '영화',
#  '액션',
#  '신',
#  '별로',
#  '심장',
#  '쫄깃하',
#  '준',
#  '웰',
#  '메이드',
#  '범죄물',
#  '류승범',
#  '황정민',
#  '연기',
#  '영화',
#  '기쁨',
#  '배',
#  '등장인물',
#  '캐릭터',
#  '절제',
#  '감정',
#  '영화',
#  '소설가',
#  '답',
#  ...]

# %%
# 두글자 이상 단어만 추출
noun_list = [n for n in noun_list if(len(n)>1)]
noun_list
# Out:
# ['보고',
#  '지금',
#  '다시',
#  '디자인',
#  '학생',
#  '외국',
#  '디자이너',
#  '일군',
#  '전통',
#  '통해',
#  '발전',
#  '문화',
#  '산업',
#  '사실',
#  '우리나라',
#  '시절',
#  '열정',
#  '노라노',
#  '전통',
#  '사람',
#  '폴리스스토리',
#  '시리즈',
#  '부터',
#  '하나',
#  '최고',
#  '연기',
#  '진짜',
#  '생각',
#  '몰입',
#  '진짜',
#  '영화',
#  '안개',
#  '밤하늘',
#  '초승달',
#  '영화',
#  '사랑',
#  '사람',
#  '라면',
#  '처음',
#  '영화',
#  '완전',
#  '감동',
#  '다시',
#  '감동',
#  '전쟁',
#  '보고',
#  '바보',
#  '나이',
#  '영화',
#  '지금',
#  '감동',
#  '훗날',
#  '다시',
#  '사하나',
#  '감정',
#  '이해',
#  '고질',
#  '영화',
#  '오페라',
#  '작품',
#  '극단',
#  '갈림',
#  '반전',
#  '평점',
#  '긴장감',
#  '스릴',
#  '진짜',
#  '최고',
#  '진짜',
#  '전장',
#  '공포',
#  '고시',
#  '소재',
#  '관련',
#  '단연',
#  '최고',
#  '가면',
#  '갈수록',
#  '더욱',
#  '밀회',
#  '화이팅',
#  '생각',
#  '수작',
#  '일본',
#  '영화',
#  '최고',
#  '마음',
#  '임팩트',
#  '일품',
#  '제대로',
#  '범죄',
#  '스릴러',
#  '사랑',
#  '마디',
#  '징텅',
#  '교복',
#  '이의',
#  '볼펜',
#  '자국',
#  '역시',
#  '미처',
#  '전하',
#  '마음',
#  '형태',
#  '마지막',
#  '강압',
#  '용서',
#  '세뇌',
#  '용서',
#  '대한',
#  '비판',
#  '중세시대',
#  '명작',
#  '평점',
#  '영상',
#  '존재',
#  '한번',
#  '제니퍼',
#  '코넬',
#  '아역시절',
#  '로버트',
#  '드니',
#  '마지막',
#  '장면',
#  '정말',
#  '가슴속',
#  '기억',
#  '최고',
#  '명작',
#  '사람',
#  '수가',
#  '인간',
#  '잠재',
#  '악마',
#  '성은',
#  '여러',
#  '시간',
#  '공간',
#  '존속',
#  '다큐',
#  '그것',
#  '재현',
#  '최고다',
#  '삼일',
#  '동안',
#  '틈틈이',
#  '잠도',
#  '여운',
#  '실화',
#  '더욱',
#  '충격',
#  '어디',
#  '일어나서',
#  '각심',
#  '영화',
#  '그라샴',
#  '작품',
#  '라면',
#  '한번',
#  '농아인',
#  '문화',
#  '대한',
#  '이정재',
#  '이범수',
#  '연기',
#  '친구',
#  '우정',
#  '매우',
#  '감동',
#  '굿굿굿',
#  '또해',
#  '제발',
#  '제이크',
#  '질렌할',
#  '대체',
#  '연기',
#  '입가',
#  '미소',
#  '샤방샤방했던',
#  '영화',
#  '원표',
#  '조연',
#  '이양',
#  '마치',
#  '바다',
#  '아쿠아리움',
#  '느낌',
#  '영화',
#  '자녀',
#  '강추',
#  '정의',
#  '콜트',
#  '콜텍',
#  '노동자',
#  '이야기',
#  '화보',
#  '브라질',
#  '마음',
#  '남자',
#  '영화',
#  '내내',
#  '마음',
#  '여배우',
#  '도법',
#  '멤버',
#  '모두',
#  '기대',
#  '정말',
#  '영화',
#  '액션',
#  '최고',
#  '남자',
#  '런가',
#  '긴장감',
#  '흥미진진',
#  '런가',
#  '워낙',
#  '격투씬',
#  '그냥',
#  '생각',
#  '스마트',
#  '티비',
#  '영화',
#  '인지도',
#  '암살',
#  '이정재',
#  '하여튼',
#  '인정',
#  '인정',
#  '파르',
#  '북한',
#  '목숨',
#  '대한민국',
#  '그거',
#  '납득',
#  '나불',
#  '거려',
#  '종북',
#  '박평',
#  '그대',
#  '그대',
#  '시작',
#  '얼굴',
#  '주인공',
#  '매력',
#  '이구',
#  '영화',
#  '용이',
#  '정말',
#  '요즘',
#  '아이돌',
#  '배우',
#  '해먹',
#  '정도',
#  '연기',
#  '정말재밋',
#  '봣는대',
#  '탱고',
#  '음악',
#  '감동',
#  '평생',
#  '후회',
#  '명작',
#  '드라마',
#  '생각',
#  '영상',
#  '미도',
#  '캐릭터',
#  '매력',
#  '여러가지',
#  '매력',
#  '드라마',
#  '정말',
#  '최고',
#  '마지막',
#  '결말',
#  '이제',
#  '영화',
#  '재미',
#  '영화',
#  '순위',
#  '영화',
#  '역시',
#  '신동엽',
#  '순간',
#  '캐치',
#  '감탄',
#  '이영자',
#  '대박',
#  '이동욱',
#  '인생',
#  '영화',
#  '전작',
#  '사실',
#  '쓰레기',
#  '한국영',
#  '별로',
#  '지금',
#  '다소',
#  '당시',
#  '눈물',
#  '사발',
#  '영화',
#  '신부',
#  '로서',
#  '명감',
#  '실천',
#  '제리',
#  '자신',
#  '부정',
#  '로키',
#  '우정',
#  '원주율',
#  '메이커',
#  '추석',
#  '특선영화',
#  '진짜',
#  '가족',
#  '끼리',
#  '보기',
#  '영화',
#  '우리',
#  '애기',
#  '영화',
#  '선택',
#  '생각',
#  '괜찬',
#  '조합',
#  '바로',
#  '대의',
#  '어머니',
#  '원작',
#  '사람',
#  '드래곤볼',
#  '에볼루션',
#  '만듬',
#  '우리나라',
#  '예능',
#  '최고',
#  '방학',
#  '아침',
#  '티비',
#  '채널',
#  '영화',
#  '정말',
#  '마음',
#  '영화',
#  '다시',
#  '엔트랩먼트',
#  '정말',
#  '권력',
#  '친구',
#  '의리',
#  '역사',
#  '사실',
#  '처음',
#  '초롱',
#  '팬심',
#  '갈수록',
#  '내용',
#  '배경음악',
#  '달달',
#  '보고',
#  '완전',
#  '중간',
#  '본방',
#  '사수',
#  '스토리',
#  '흥미진진',
#  '배우',
#  '연기',
#  '어디',
#  '요새',
#  '수백향',
#  '인생',
#  '제목',
#  '화질',
#  '재미',
#  '가을로',
#  '가을',
#  '감동',
#  '때문',
#  '이건',
#  '벌써',
#  '퀄리티',
#  '일단',
#  '까지봣다',
#  '장국영',
#  '자살',
#  '사실',
#  '극적',
#  '뀰잼',
#  '뀰잼',
#  '느낌',
#  '예전',
#  '양심',
#  '냉장고',
#  '감정',
#  '움찔',
#  '한가지',
#  '부탁',
#  '연기자',
#  '보호',
#  '폭력',
#  '걱정',
#  '성추행',
#  '상가',
#  '모든',
#  '사람',
#  '목격',
#  '증언',
#  '덕분',
#  '청소년',
#  '계속',
#  '경찰서',
#  '남자',
#  '주인공',
#  '멋있쪙',
#  '재밋었다',
#  '영화',
#  '세기',
#  '최고',
#  '평점',
#  '사람',
#  '정말',
#  '비디오',
#  '친구',
#  '정말',
#  '느낌',
#  '지금',
#  '남기남',
#  '감독',
#  '이름',
#  '하나',
#  '진짜',
#  '최고다',
#  '최고',
#  '성룡',
#  '형님',
#  '마이',
#  '우상',
#  '당신',
#  '장르',
#  '이영화',
#  '영화',
#  '장르',
#  '지금',
#  '영화',
#  '최고다',
#  '리타',
#  '자꾸',
#  '생각',
#  '죄책감',
#  '도잠',
#  '보고',
#  '커서',
#  '다시',
#  '진짜',
#  '영화',
#  '웃음',
#  '감동',
#  '정치',
#  '대한',
#  '비판',
#  '묘사',
#  '표현',
#  '흥행',
#  '기억',
#  '안나',
#  '절대',
#  '평점',
#  '영화',
#  '생각',
#  '연기자',
#  '연기',
#  '디테',
#  '일만',
#  '봉임',
#  '대박',
#  '이건',
#  '한마디',
#  '사랑',
#  '달기',
#  '마음',
#  '수록',
#  '영화',
#  '살이',
#  '엇냐',
#  '남자',
#  '얼굴',
#  '성격',
#  '만점',
#  '다음',
#  '초반',
#  '설정',
#  '몰입',
#  '점차',
#  '이건',
#  '판타지',
#  '우리',
#  '미래',
#  '현실',
#  '언론',
#  '탄압',
#  '대한',
#  '은유',
#  '생각',
#  '남자',
#  '주인공',
#  '오카다',
#  '예상',
#  '기대',
#  '의외',
#  '재미',
#  '감동',
#  '인도영화',
#  '역시',
#  '스토리',
#  '영상',
#  '배우',
#  '연기',
#  '하나',
#  '영화',
#  '대박',
#  '감동',
#  '진짜',
#  '웃음',
#  '무엇',
#  '다그',
#  '허정무',
#  '대신',
#  '장외룡',
#  '감독',
#  '한국',
#  '고고싱',
#  '어찌',
#  '명감',
#  '정말',
#  '계속',
#  '미소',
#  '보조개',
#  '정말',
#  '메이',
#  '최고봉',
#  '하나',
#  '초딩',
#  '진짜',
#  '봣음',
#  '비포미드나잇',
#  '마지막',
#  '심정',
#  '또한',
#  '한편',
#  '모습',
#  '절로',
#  '웃음',
#  '재미',
#  '뭔가',
#  '스케',
#  '라디오',
#  '임진강',
#  '눈물',
#  '한석규',
#  '연기',
#  '쵝오',
#  '진짜',
#  '허니',
#  '꿀잼',
#  '개꿀잼',
#  '한예슬',
#  '진짜',
#  '원래',
#  '헤어',
#  '메이크업',
#  '드라마',
#  '내용',
#  '한마디',
#  '최고',
#  '재미',
#  '기대',
#  '더욱',
#  '명작',
#  '정말',
#  '완전',
#  '훈남',
#  '쉐프',
#  '보구',
#  '요리',
#  '시나리오',
#  '비고',
#  '연기',
#  '잼잼꿀잼',
#  '허니',
#  '잼핵잼잼잼',
#  '개인',
#  '언제',
#  '팬텀',
#  '크리스틴',
#  '일이',
#  '전혀',
#  '스토리',
#  '처럼',
#  '크리스틴',
#  '다시',
#  '남편',
#  '아쉬움',
#  '개인',
#  '알파',
#  '치노',
#  '때문',
#  '영화',
#  '처음',
#  '명화',
#  '다시',
#  '뮤지컬',
#  '역대',
#  '이건',
#  '정말',
#  '대부',
#  '바람',
#  '레벨',
#  '영화',
#  '명의',
#  '주인공',
#  '마치',
#  '뮤지컬',
#  '마잭',
#  '마돈나',
#  '엘비스급',
#  '노래실력',
#  '바비',
#  '바스코',
#  '이번',
#  '결과',
#  '대해',
#  '불만',
#  '사람',
#  '어쩌면',
#  '거지',
#  '바비',
#  '아이돌',
#  '어쩌',
#  '바비',
#  '자격',
#  '개인',
#  '생각',
#  '코미디',
#  '사극',
#  '장혁',
#  '명품',
#  '연기',
#  '가족',
#  '이서',
#  '영화',
#  '처음',
#  '마련',
#  '사마',
#  '그날',
#  '저녁',
#  '영화',
#  '기분',
#  '수가',
#  '옛날',
#  '워낭소리',
#  '진짜',
#  '인생',
#  '최고',
#  '명작',
#  '더빙',
#  '자막',
#  '연말',
#  '추천',
#  '영화',
#  '배경음악',
#  '한국',
#  '사회',
#  '치부',
#  '예언',
#  '수작',
#  '영화',
#  '진짜',
#  '영화',
#  '지금',
#  '엣날',
#  '제일',
#  '영화',
#  '역시',
#  '최고',
#  '슈퍼',
#  '울트라',
#  '노막',
#  '매력',
#  '중동',
#  '문화',
#  '대해',
#  '영화',
#  '참여',
#  '얼마나',
#  '아버지',
#  '이자',
#  '남편',
#  '무사',
#  '로서',
#  '남자',
#  '일생',
#  '의미',
#  '죽음',
#  '일지',
#  '자신',
#  '신념',
#  '진일',
#  '웃음',
#  '감동',
#  '물결',
#  '기대',
#  '쵝오임',
#  '영화',
#  '다만',
#  '엔딩',
#  '주인공',
#  '배심원',
#  '상대로',
#  '일장',
#  '연설',
#  '작위',
#  '신파',
#  '연설',
#  '배심원',
#  '무죄',
#  '만점',
#  '감동',
#  '정말',
#  '애정',
#  '이야기',
#  '정말',
#  '멜로',
#  '드라마',
#  '정말',
#  '최영장군',
#  '이민호',
#  '이민호',
#  '드라마',
#  '최고',
#  '생각',
#  '영화',
#  '보고',
#  '안치환',
#  '방향',
#  '노래',
#  '제목',
#  '스토리',
#  '세기',
#  '최고',
#  '걸작',
#  '안보',
#  '고도',
#  '오스트레일리아',
#  '조금',
#  '프랑스',
#  '코미디',
#  '영화',
#  '생각',
#  '영화',
#  '액션',
#  '별로',
#  '심장',
#  '쫄깃하',
#  '메이드',
#  '범죄물',
#  '류승범',
#  '황정민',
#  '연기',
#  '영화',
#  '기쁨',
#  '등장인물',
#  '캐릭터',
#  '절제',
#  '감정',
#  '영화',
#  '소설가',
#  '시나리오',
#  '무척',
#  '엄마',
#  '운전',
#  '맥거핀',
#  '아이맥스',
#  '개봉',
#  '이영화',
#  '선택',
#  '거임',
#  '완죤',
#  '스타',
#  '정부',
#  '국민',
#  '의지',
#  '정부',
#  '소재',
#  '퀘벡',
#  '영화',
#  '거지',
#  '벌써',
#  '호킹',
#  '능욕',
#  '영화',
#  '사람',
#  '감독',
#  '영화',
#  '정말',
#  '진짜',
#  '보통',
#  '전쟁영화',
#  '감독',
#  '특유',
#  '연출',
#  '감동',
#  '원작',
#  '스토리',
#  '강추',
#  '이정현',
#  '연기',
#  '소재',
#  '현실',
#  '전형',
#  '사이코',
#  '영화',
#  '우릴',
#  '욕망',
#  '명대사',
#  '기억',
#  '영화',
#  '더빙',
#  '똥칠',
#  '된거',
#  '점도',
#  '영화',
#  '블레이드러너',
#  '버금',
#  '영화',
#  '한국',
#  '결코',
#  '장면',
#  '정일우',
#  '상투',
#  '표현',
#  '영화',
#  '여운',
#  '감독',
#  '존경',
#  '반지',
#  '제왕',
#  '피터',
#  '잭슨',
#  '명작',
#  '지금',
#  '한번',
#  '감독판',
#  '정말',
#  '추억',
#  '영화',
#  '아버지',
#  '녹화',
#  '다시',
#  '리메이크',
#  '인생',
#  '최고',
#  '드라마',
#  '그대',
#  '무협',
#  '최고',
#  '재미',
#  '감동',
#  '보너스',
#  '시내',
#  '자신',
#  '용이',
#  '보신',
#  '추강',
#  '정말',
#  '아이',
#  '만화영화',
#  '액션영화',
#  '서도',
#  '귀수',
#  '아군',
#  '첫사랑',
#  '설레임',
#  '그대로',
#  '영화',
#  '만점',
#  '하나',
#  '명작',
#  '영화',
#  '시절',
#  '영화',
#  '관람',
#  '내내',
#  '향수',
#  '기분',
#  '김민선',
#  '김규리',
#  '여신',
#  '미모',
#  '연기',
#  '힐링',
#  '무비',
#  '영화',
#  '자리',
#  '연속',
#  '전혀',
#  '질리',
#  '외계인',
#  '신분',
#  '라이언',
#  '언제',
#  '기분',
#  '애니',
#  '보고',
#  '진짜',
#  '대박',
#  '코드',
#  '당시',
#  '사회',
#  '반영',
#  '짜임새',
#  '스토리',
#  '러브',
#  '모드',
#  '여주',
#  '매력',
#  '어요',
#  '얼굴',
#  '여주',
#  '하나요',
#  '만점',
#  '생각',
#  '영화',
#  '시간여행',
#  '스토리',
#  '사람',
#  '라면',
#  '트릴',
#  '영화',
#  '정말',
#  '보고',
#  '방송',
#  '털털',
#  '인간',
#  '실제',
#  '시기',
#  '나중',
#  '다시',
#  '정치',
#  '입문',
#  '정치',
#  '시기',
#  '가연',
#  '물감',
#  '액션',
#  '가족',
#  '애가',
#  '주제',
#  '영화',
#  '한국',
#  '배급사',
#  '언제',
#  '평점',
#  '감독',
#  '진짜',
#  '싸이코패스',
#  '영화',
#  '안인숙',
#  '연기',
#  '이편',
#  '조각',
#  '정말',
#  '재밋',
#  '추천',
#  '배우',
#  '연기',
#  '매우',
#  '용도',
#  '흥미진진',
#  '배우',
#  '케미',
#  '최고',
#  '다시',
#  '정말',
#  '이예',
#  '여유',
#  '일요일',
#  '오후',
#  '동화',
#  '세계',
#  '영화',
#  '스타워즈',
#  '쌍탑',
#  '영화',
#  '일견',
#  '더욱',
#  '감동',
#  ...]

# %%
tags = Counter(noun_list).most_common(1000)
tags
# Out:
# [('영화', 985),
#  ('정말', 265),
#  ('최고', 230),
#  ('진짜', 184),
#  ('감동', 155),
#  ('연기', 142),
#  ('생각', 140),
#  ('드라마', 121),
#  ('보고', 119),
#  ('사람', 110),
#  ('평점', 103),
#  ('다시', 94),
#  ('마지막', 80),
#  ('사랑', 78),
#  ('스토리', 69),
#  ('작품', 67),
#  ('지금', 66),
#  ('배우', 65),
#  ('명작', 61),
#  ('재미', 59),
#  ('마음', 56),
#  ('하나', 54),
#  ('완전', 53),
#  ('이영화', 52),
#  ('추천', 50),
#  ('장면', 49),
#  ('매력', 49),
#  ('느낌', 47),
#  ('감독', 47),
#  ('내용', 46),
#  ('현실', 46),
#  ('액션', 45),
#  ('이야기', 43),
#  ('그냥', 43),
#  ('가슴', 43),
#  ('주인공', 42),
#  ('정도', 42),
#  ('이해', 40),
#  ('한번', 40),
#  ('인생', 38),
#  ('역시', 37),
#  ('음악', 37),
#  ('처음', 36),
#  ('기억', 35),
#  ('여운', 35),
#  ('남자', 34),
#  ('눈물', 34),
#  ('우리', 34),
#  ('인간', 33),
#  ('시간', 33),
#  ('대박', 32),
#  ('한국', 32),
#  ('결말', 30),
#  ('가족', 30),
#  ('모습', 29),
#  ('연기력', 29),
#  ('최고다', 27),
#  ('대한', 26),
#  ('영상', 26),
#  ('보기', 26),
#  ('아이', 26),
#  ('가장', 26),
#  ('소재', 25),
#  ('모든', 25),
#  ('연출', 25),
#  ('여자', 25),
#  ('시리즈', 24),
#  ('모두', 24),
#  ('개인', 24),
#  ('부분', 24),
#  ('반전', 23),
#  ('때문', 23),
#  ('계속', 23),
#  ('무엇', 23),
#  ('당시', 22),
#  ('공감', 22),
#  ('긴장감', 21),
#  ('자신', 21),
#  ('이건', 21),
#  ('사실', 20),
#  ('몰입', 20),
#  ('전쟁', 20),
#  ('기대', 20),
#  ('대해', 20),
#  ('그녀', 20),
#  ('오늘', 20),
#  ('강추', 19),
#  ('캐릭터', 19),
#  ('뭔가', 19),
#  ('노래', 19),
#  ('세상', 19),
#  ('아주', 19),
#  ('감정', 18),
#  ('수작', 18),
#  ('한국영', 18),
#  ('중간', 18),
#  ('제목', 18),
#  ('표현', 18),
#  ('코미디', 18),
#  ('엔딩', 18),
#  ('이상', 18),
#  ('간만', 18),
#  ('실화', 17),
#  ('요즘', 17),
#  ('후회', 17),
#  ('기분', 17),
#  ('제일', 17),
#  ('엄마', 17),
#  ('추억', 17),
#  ('애니', 17),
#  ('배경', 17),
#  ('코믹', 17),
#  ('라면', 16),
#  ('제대로', 16),
#  ('스릴러', 16),
#  ('친구', 16),
#  ('내내', 16),
#  ('별로', 16),
#  ('웃음', 16),
#  ('나이', 15),
#  ('조금', 15),
#  ('개봉', 15),
#  ('재밋', 15),
#  ('소름', 15),
#  ('몰입도', 15),
#  ('티비', 14),
#  ('성룡', 14),
#  ('만점', 14),
#  ('사회', 14),
#  ('걸작', 14),
#  ('웃기', 14),
#  ('인상', 14),
#  ('약간', 14),
#  ('다운', 14),
#  ('기도', 14),
#  ('보지', 14),
#  ('스릴', 13),
#  ('매우', 13),
#  ('원작', 13),
#  ('절대', 13),
#  ('전혀', 13),
#  ('나름', 13),
#  ('대사', 13),
#  ('예술', 13),
#  ('공포', 12),
#  ('갈수록', 12),
#  ('언제', 12),
#  ('실제', 12),
#  ('다른', 12),
#  ('완성', 12),
#  ('진심', 12),
#  ('영화관', 12),
#  ('레전드', 12),
#  ('가지', 12),
#  ('더욱', 11),
#  ('다큐', 11),
#  ('당신', 11),
#  ('초딩', 11),
#  ('이유', 11),
#  ('얘기', 11),
#  ('재밋다', 11),
#  ('혼자', 11),
#  ('짱짱', 11),
#  ('전개', 11),
#  ('감명', 11),
#  ('위해', 11),
#  ('시절', 10),
#  ('존재', 10),
#  ('얼굴', 10),
#  ('이제', 10),
#  ('이름', 10),
#  ('한마디', 10),
#  ('꿀잼', 10),
#  ('아버지', 10),
#  ('의미', 10),
#  ('아픔', 10),
#  ('희망', 10),
#  ('이후', 10),
#  ('분위기', 10),
#  ('극장', 10),
#  ('제작', 10),
#  ('통해', 9),
#  ('우리나라', 9),
#  ('화이팅', 9),
#  ('충격', 9),
#  ('어디', 9),
#  ('여배우', 9),
#  ('흥미진진', 9),
#  ('시작', 9),
#  ('선택', 9),
#  ('자꾸', 9),
#  ('얼마나', 9),
#  ('그대로', 9),
#  ('관람', 9),
#  ('세계', 9),
#  ('목소리', 9),
#  ('집중', 9),
#  ('발견', 9),
#  ('자연', 9),
#  ('영화로', 9),
#  ('구성', 9),
#  ('아들', 9),
#  ('자체', 9),
#  ('정신', 9),
#  ('애니메이션', 9),
#  ('편이', 9),
#  ('박수', 9),
#  ('수준', 9),
#  ('문제', 9),
#  ('감상', 9),
#  ('감성', 9),
#  ('시대', 9),
#  ('출연', 9),
#  ('대한민국', 8),
#  ('순간', 8),
#  ('바로', 8),
#  ('의리', 8),
#  ('역사', 8),
#  ('비디오', 8),
#  ('다음', 8),
#  ('초반', 8),
#  ('뮤지컬', 8),
#  ('옛날', 8),
#  ('다만', 8),
#  ('안보', 8),
#  ('무비', 8),
#  ('질리', 8),
#  ('미국', 8),
#  ('거의', 8),
#  ('압도', 8),
#  ('가끔', 8),
#  ('전달', 8),
#  ('소설', 8),
#  ('시즌', 8),
#  ('어린시절', 8),
#  ('남성', 8),
#  ('심리', 8),
#  ('장난', 8),
#  ('평가', 8),
#  ('작가', 8),
#  ('천재', 8),
#  ('영화인', 8),
#  ('행복', 8),
#  ('대안', 8),
#  ('킬링타임', 8),
#  ('열정', 7),
#  ('오페라', 7),
#  ('일본', 7),
#  ('비판', 7),
#  ('그것', 7),
#  ('미소', 7),
#  ('인정', 7),
#  ('평생', 7),
#  ('쓰레기', 7),
#  ('본방', 7),
#  ('벌써', 7),
#  ('퀄리티', 7),
#  ('예전', 7),
#  ('장르', 7),
#  ('또한', 7),
#  ('쵝오', 7),
#  ('시나리오', 7),
#  ('이번', 7),
#  ('거지', 7),
#  ('더빙', 7),
#  ('이자', 7),
#  ('무척', 7),
#  ('국민', 7),
#  ('액션영화', 7),
#  ('나라', 7),
#  ('동물', 7),
#  ('누가', 7),
#  ('로맨스', 7),
#  ('개그', 7),
#  ('연애', 7),
#  ('표정', 7),
#  ('로봇', 7),
#  ('그때', 7),
#  ('상영', 7),
#  ('볼때', 7),
#  ('인물', 7),
#  ('평론가', 7),
#  ('누구', 7),
#  ('청춘', 7),
#  ('만하', 7),
#  ('포스터', 7),
#  ('비교', 7),
#  ('몇번', 7),
#  ('교훈', 7),
#  ('영웅', 7),
#  ('메시지', 7),
#  ('발전', 6),
#  ('로버트', 6),
#  ('수가', 6),
#  ('우정', 6),
#  ('어머니', 6),
#  ('권력', 6),
#  ('사수', 6),
#  ('덕분', 6),
#  ('세기', 6),
#  ('형님', 6),
#  ('미래', 6),
#  ('어찌', 6),
#  ('명화', 6),
#  ('역대', 6),
#  ('자막', 6),
#  ('스타', 6),
#  ('첫사랑', 6),
#  ('힐링', 6),
#  ('짜임새', 6),
#  ('방송', 6),
#  ('역할', 6),
#  ('말로', 6),
#  ('눈빛', 6),
#  ('비극', 6),
#  ('아빠', 6),
#  ('환상', 6),
#  ('리얼', 6),
#  ('그게', 6),
#  ('전체', 6),
#  ('색감', 6),
#  ('화가', 6),
#  ('활약', 6),
#  ('남녀', 6),
#  ('과거', 6),
#  ('고양이', 6),
#  ('상상', 6),
#  ('자유', 6),
#  ('은근', 6),
#  ('느와르', 6),
#  ('잘만', 6),
#  ('응원', 6),
#  ('야마', 6),
#  ('여행', 6),
#  ('지배', 6),
#  ('진실', 6),
#  ('점주', 6),
#  ('영환', 6),
#  ('일상', 6),
#  ('지난', 6),
#  ('줄거리', 6),
#  ('진정', 6),
#  ('해피엔딩', 6),
#  ('이란', 6),
#  ('카메라', 6),
#  ('네이버', 6),
#  ('무조건', 6),
#  ('노력', 6),
#  ('위로', 6),
#  ('대작', 6),
#  ('만화', 6),
#  ('형제', 6),
#  ('학교', 6),
#  ('카리스마', 6),
#  ('깊이', 6),
#  ('해석', 6),
#  ('배트맨', 6),
#  ('단지', 6),
#  ('노출', 6),
#  ('주윤발', 6),
#  ('의심', 6),
#  ('취향', 6),
#  ('연인', 6),
#  ('영어', 6),
#  ('학생', 5),
#  ('전통', 5),
#  ('부터', 5),
#  ('일품', 5),
#  ('드니', 5),
#  ('마치', 5),
#  ('런가', 5),
#  ('목숨', 5),
#  ('용이', 5),
#  ('감탄', 5),
#  ('로서', 5),
#  ('조합', 5),
#  ('연기자', 5),
#  ('마이', 5),
#  ('정치', 5),
#  ('묘사', 5),
#  ('흥행', 5),
#  ('최고봉', 5),
#  ('한편', 5),
#  ('절로', 5),
#  ('바람', 5),
#  ('명품', 5),
#  ('죽음', 5),
#  ('일지', 5),
#  ('멜로', 5),
#  ('프랑스', 5),
#  ('특유', 5),
#  ('나중', 5),
#  ('반성', 5),
#  ('슬픔', 5),
#  ('상상력', 5),
#  ('몽환', 5),
#  ('실감', 5),
#  ('새끼', 5),
#  ('재난영화', 5),
#  ('에피소드', 5),
#  ('과연', 5),
#  ('아저씨', 5),
#  ('점수', 5),
#  ('그림', 5),
#  ('엄정화', 5),
#  ('한순간', 5),
#  ('좀비', 5),
#  ('극장판', 5),
#  ('강력', 5),
#  ('과정', 5),
#  ('항상', 5),
#  ('국내', 5),
#  ('아무', 5),
#  ('니콜', 5),
#  ('주성치', 5),
#  ('효과', 5),
#  ('도라에몽', 5),
#  ('폭발', 5),
#  ('결혼', 5),
#  ('키드', 5),
#  ('수도', 5),
#  ('신경', 5),
#  ('전설', 5),
#  ('현재', 5),
#  ('전율', 5),
#  ('조니뎁', 5),
#  ('거리', 5),
#  ('머리', 5),
#  ('자극', 5),
#  ('용기', 5),
#  ('상처', 5),
#  ('이선균', 5),
#  ('상미', 5),
#  ('케이블', 5),
#  ('게다가', 5),
#  ('점점', 5),
#  ('블랙', 5),
#  ('먼저', 5),
#  ('어른', 5),
#  ('어제', 5),
#  ('타임', 5),
#  ('최민식', 5),
#  ('공포영화', 5),
#  ('김민희', 5),
#  ('시청률', 5),
#  ('간다', 5),
#  ('철학', 5),
#  ('괴물', 5),
#  ('후반', 5),
#  ('희생', 5),
#  ('마이클', 5),
#  ('영화사', 5),
#  ('문화', 4),
#  ('바보', 4),
#  ('가면', 4),
#  ('범죄', 4),
#  ('여러', 4),
#  ('공간', 4),
#  ('동안', 4),
#  ('대체', 4),
#  ('바다', 4),
#  ('정의', 4),
#  ('화보', 4),
#  ('그대', 4),
#  ('아이돌', 4),
#  ('다소', 4),
#  ('끼리', 4),
#  ('애기', 4),
#  ('달달', 4),
#  ('일단', 4),
#  ('양심', 4),
#  ('폭력', 4),
#  ('성격', 4),
#  ('판타지', 4),
#  ('예상', 4),
#  ('심정', 4),
#  ('한석규', 4),
#  ('원래', 4),
#  ('보구', 4),
#  ('요리', 4),
#  ('일이', 4),
#  ('아쉬움', 4),
#  ('어쩌면', 4),
#  ('신념', 4),
#  ('심장', 4),
#  ('전쟁영화', 4),
#  ('존경', 4),
#  ('리메이크', 4),
#  ('여신', 4),
#  ('자리', 4),
#  ('코드', 4),
#  ('반영', 4),
#  ('여주', 4),
#  ('시기', 4),
#  ('주제', 4),
#  ('케미', 4),
#  ('동화', 4),
#  ('주연', 4),
#  ('폭풍', 4),
#  ('래야', 4),
#  ('박중훈', 4),
#  ('편견', 4),
#  ('방금', 4),
#  ('선생님', 4),
#  ('요소', 4),
#  ('이전', 4),
#  ('감히', 4),
#  ('주의', 4),
#  ('로맨틱', 4),
#  ('상대', 4),
#  ('낫다', 4),
#  ('관점', 4),
#  ('젊은이', 4),
#  ('다해', 4),
#  ('검색', 4),
#  ('세트', 4),
#  ('재밋는데', 4),
#  ('화면', 4),
#  ('편도', 4),
#  ('리즈시절', 4),
#  ('오락', 4),
#  ('고민', 4),
#  ('관계', 4),
#  ('덴젤', 4),
#  ('헐리웃', 4),
#  ('고인', 4),
#  ('전문가', 4),
#  ('근원', 4),
#  ('시각', 4),
#  ('무슨', 4),
#  ('가치', 4),
#  ('낭만', 4),
#  ('소장', 4),
#  ('무언가', 4),
#  ('매니아', 4),
#  ('케빈', 4),
#  ('알바', 4),
#  ('정우성', 4),
#  ('역작', 4),
#  ('스님', 4),
#  ('아내', 4),
#  ('정석', 4),
#  ('다행', 4),
#  ('하나로', 4),
#  ('설명', 4),
#  ('웅장', 4),
#  ('해도', 4),
#  ('누군가', 4),
#  ('하루', 4),
#  ('각본', 4),
#  ('교과서', 4),
#  ('대표', 4),
#  ('자기', 4),
#  ('절망', 4),
#  ('잡고', 4),
#  ('스타일', 4),
#  ('두려움', 4),
#  ('욕심', 4),
#  ('지식', 4),
#  ('동생', 4),
#  ('여기', 4),
#  ('찾기', 4),
#  ('재밋음', 4),
#  ('이연걸', 4),
#  ('할아버지', 4),
#  ('직접', 4),
#  ('편의', 4),
#  ('새벽', 4),
#  ('무간도', 4),
#  ('송강호', 4),
#  ('다큐멘터리', 4),
#  ('시트콤', 4),
#  ('재밋어', 4),
#  ('방영', 4),
#  ('제임스', 4),
#  ('불구', 4),
#  ('도대체', 4),
#  ('박진', 4),
#  ('오멘', 4),
#  ('전편', 4),
#  ('광녀', 4),
#  ('단연', 3),
#  ('마디', 3),
#  ('제니퍼', 3),
#  ('제발', 3),
#  ('조연', 3),
#  ('노동자', 3),
#  ('북한', 3),
#  ('여러가지', 3),
#  ('채널', 3),
#  ('배경음악', 3),
#  ('커서', 3),
#  ('안나', 3),
#  ('설정', 3),
#  ('의외', 3),
#  ('허니', 3),
#  ('팬텀', 3),
#  ('처럼', 3),
#  ('남편', 3),
#  ('바비', 3),
#  ('바스코', 3),
#  ('결과', 3),
#  ('사극', 3),
#  ('그날', 3),
#  ('슈퍼', 3),
#  ('메이드', 3),
#  ('기쁨', 3),
#  ('의지', 3),
#  ('전형', 3),
#  ('욕망', 3),
#  ('명대사', 3),
#  ('제왕', 3),
#  ('보신', 3),
#  ('만화영화', 3),
#  ('신분', 3),
#  ('라이언', 3),
#  ('용도', 3),
#  ('여유', 3),
#  ('의문', 3),
#  ('갈등', 3),
#  ('서로', 3),
#  ('소녀시대', 3),
#  ('잘못', 3),
#  ('송지효', 3),
#  ('싸이코', 3),
#  ('사람과', 3),
#  ('터미네이터', 3),
#  ('올해', 3),
#  ('차태현', 3),
#  ('스스로', 3),
#  ('미드', 3),
#  ('캐스팅', 3),
#  ('문채원', 3),
#  ('대부분', 3),
#  ('미가', 3),
#  ('건가', 3),
#  ('키스신', 3),
#  ('예수님', 3),
#  ('패전', 3),
#  ('처리', 3),
#  ('전문', 3),
#  ('이기', 3),
#  ('본인', 3),
#  ('진행', 3),
#  ('갑자기', 3),
#  ('상태', 3),
#  ('일리', 3),
#  ('등등', 3),
#  ('초점', 3),
#  ('최상', 3),
#  ('특징', 3),
#  ('울면', 3),
#  ('구속', 3),
#  ('게이', 3),
#  ('마무리', 3),
#  ('펑펑', 3),
#  ('엉엉', 3),
#  ('야구', 3),
#  ('에리', 3),
#  ('색채', 3),
#  ('놀란', 3),
#  ('재밋네', 3),
#  ('지연', 3),
#  ('공주', 3),
#  ('안감', 3),
#  ('스케일', 3),
#  ('왜케', 3),
#  ('모험', 3),
#  ('장동건', 3),
#  ('할머니', 3),
#  ('소리', 3),
#  ('성공', 3),
#  ('정화', 3),
#  ('구조', 3),
#  ('열연', 3),
#  ('이면', 3),
#  ('흡입', 3),
#  ('침묵', 3),
#  ('선사', 3),
#  ('분노', 3),
#  ('배종옥', 3),
#  ('살기', 3),
#  ('동시', 3),
#  ('자식', 3),
#  ('방식', 3),
#  ('평균', 3),
#  ('단어', 3),
#  ('조재현', 3),
#  ('기적', 3),
#  ('강시', 3),
#  ('종교', 3),
#  ('로만', 3),
#  ('변화', 3),
#  ('근래', 3),
#  ('여성', 3),
#  ('한국인', 3),
#  ('초기', 3),
#  ('살인', 3),
#  ('메세지', 3),
#  ('흥분', 3),
#  ('화중', 3),
#  ('탄생', 3),
#  ('손색', 3),
#  ('개구쟁이', 3),
#  ('스머프', 3),
#  ('김기덕', 3),
#  ('소개', 3),
#  ('무한', 3),
#  ('사도', 3),
#  ('신의', 3),
#  ('사진', 3),
#  ('세월', 3),
#  ('미니시리즈', 3),
#  ('언니', 3),
#  ('명장', 3),
#  ('이성민', 3),
#  ('부모', 3),
#  ('겨울', 3),
#  ('이보', 3),
#  ('성장', 3),
#  ('공리', 3),
#  ('신인', 3),
#  ('가능성', 3),
#  ('심은경', 3),
#  ('감각', 3),
#  ('오오오오', 3),
#  ('홍콩', 3),
#  ('히어로', 3),
#  ('방법', 3),
#  ('토니', 3),
#  ('막장', 3),
#  ('무대', 3),
#  ('진작', 3),
#  ('러닝', 3),
#  ('으리', 3),
#  ('실망', 3),
#  ('반드시', 3),
#  ('광고', 3),
#  ('관객', 3),
#  ('백배', 3),
#  ('고독', 3),
#  ('토이스토리', 3),
#  ('도안', 3),
#  ('질서', 3),
#  ('피디', 3),
#  ('포스', 3),
#  ('오히려', 3),
#  ('주변', 3),
#  ('지루함', 3),
#  ('일반', 3),
#  ('인기', 3),
#  ('닥치고', 3),
#  ('고뇌', 3),
#  ('남아', 3),
#  ('한참', 3),
#  ('만남', 3),
#  ('전의', 3),
#  ('속편', 3),
#  ('스피드', 3),
#  ('소녀', 3),
#  ('그린', 3),
#  ('독립영화', 3),
#  ('잼슴', 3),
#  ('케릭', 3),
#  ('사라', 3),
#  ('이만', 3),
#  ('무지', 3),
#  ('본질', 3),
#  ('마리', 3),
#  ('긴장', 3),
#  ('공효진', 3),
#  ('는걸', 3),
#  ('강마', 3),
#  ('주지', 3),
#  ('압권', 3),
#  ('공포물', 3),
#  ('뇌리', 3),
#  ('아아', 3),
#  ('최선', 3),
#  ('버튼', 3),
#  ('조폭', 3),
#  ('주원', 3),
#  ('전개도', 3),
#  ('보이', 3),
#  ('로코', 3),
#  ('설마', 3),
#  ('행크스', 3),
#  ('로드무비', 3),
#  ('재미나', 3),
#  ('이지', 3),
#  ('전성기', 3),
#  ('일찍', 3),
#  ('안이', 3),
#  ('조화', 3),
#  ('평화', 3),
#  ('유덕화', 3),
#  ('상황', 3),
#  ('산업', 2),
#  ('안개', 2),
#  ('사하나', 2),
#  ('전장', 2),
#  ('관련', 2),
#  ('임팩트', 2),
#  ('미처', 2),
#  ('전하', 2),
#  ('형태', 2),
#  ('용서', 2),
#  ('잠도', 2),
#  ('일어나서', 2),
#  ('이정재', 2),
#  ('질렌할', 2),
#  ('입가', 2),
#  ('콜트', 2),
#  ('브라질', 2),
#  ('그거', 2),
#  ('종북', 2),
#  ('미도', 2),
#  ('순위', 2),
#  ('전작', 2),
#  ('명감', 2),
#  ('제리', 2),
#  ('메이커', 2),
#  ('대의', 2),
#  ('예능', 2),
#  ('방학', 2),
#  ('요새', 2),
#  ('수백향', 2),
#  ('가을', 2),
#  ('장국영', 2),
#  ('자살', 2),
#  ('뀰잼', 2),
#  ('보호', 2),
#  ('걱정', 2),
#  ('청소년', 2),
#  ('우상', 2),
#  ('죄책감', 2),
#  ('디테', 2),
#  ('수록', 2),
#  ('다그', 2),
#  ('메이', 2),
#  ('봣음', 2),
#  ('훈남', 2),
#  ('크리스틴', 2),
#  ('알파', 2),
#  ('치노', 2),
#  ('명의', 2),
#  ('이서', 2),
#  ('연말', 2),
#  ('무사', 2),
#  ('물결', 2),
#  ('배심원', 2),
#  ('연설', 2),
#  ('애정', 2),
#  ('이민호', 2),
#  ('고도', 2),
#  ('류승범', 2),
#  ('황정민', 2),
#  ('절제', 2),
#  ('거임', 2),
#  ('정부', 2),
#  ('이정현', 2),
#  ('된거', 2),
#  ('점도', 2),
#  ('버금', 2),
#  ('결코', 2),
#  ('정일우', 2),
#  ('반지', 2),
#  ('녹화', 2),
#  ('무협', 2),
#  ('추강', 2),
#  ('향수', 2),
#  ('미모', 2),
#  ('연속', 2),
#  ('러브', 2),
#  ('스타워즈', 2),
#  ('외로움', 2),
#  ('로써', 2),
#  ('내생', 2),
#  ('여명', 2),
#  ('해지', 2),
#  ('윤아', 2),
#  ('박한별', 2),
#  ('몸매', 2),
#  ('간직', 2),
#  ('리가', 2),
#  ('모슬렘', 2),
#  ('신고', 2),
#  ('행운', 2),
#  ('휴식', 2),
#  ('난리', 2),
#  ('강아지', 2),
#  ('흐름', 2),
#  ('동전', 2),
#  ('양면', 2),
#  ('매일', 2),
#  ('지오', 2),
#  ('막시무스', 2),
#  ('미화', 2),
#  ('생명', 2),
#  ('정해', 2),
#  ('가까이', 2),
#  ('위트', 2),
#  ('중학교', 2),
#  ('재난', 2),
#  ('아치', 2),
#  ('조음', 2),
#  ('박유천', 2),
#  ('한지민', 2),
#  ('최진희', 2),
#  ('중국영화', 2),
#  ('번은', 2),
#  ('하정우', 2),
#  ('의사', 2),
#  ('모던', 2),
#  ('감사용', 2),
#  ('투수', 2),
#  ('콘서트', 2),
#  ('헌신', 2),
#  ('운명', 2),
#  ('홍콩영화', 2),
#  ('경의', 2),
#  ('만큼', 2),
#  ('연민', 2),
#  ('벤자민', 2),
#  ('장거리', 2),
#  ('도시', 2),
#  ('한장', 2),
#  ('트포', 2),
#  ('대장', 2),
#  ('기술', 2),
#  ('주말', 2),
#  ('커플', 2),
#  ('결정', 2),
#  ('동양인', 2),
#  ('하자', 2),
#  ('유지', 2),
#  ('목적', 2),
#  ('봣어', 2),
#  ('인형', 2),
#  ('영화음악', 2),
#  ('라인', 2),
#  ('회상', 2),
#  ('흥미', 2),
#  ('보시', 2),
#  ('다가', 2),
#  ('거짓말', 2),
#  ('살때', 2),
#  ('등장', 2),
#  ('거기', 2),
#  ('권상우', 2),
#  ('동성애자', 2),
#  ('녀석', 2),
#  ('중반', 2),
#  ('러브스토리', 2),
#  ('생활', 2),
#  ('스포츠', 2),
#  ('스푼', 2),
#  ('카츠', 2),
#  ('지니어스', 2),
#  ('휴먼', 2),
#  ('창의', 2),
#  ('홧팅', 2),
#  ('실험', 2),
#  ('어린이날', 2),
#  ('동심', 2),
#  ('명복', 2),
#  ('욀케', 2),
#  ('독재자', 2),
#  ('주먹', 2),
#  ('단점', 2),
#  ('안성기', 2),
#  ('베니', 2),
#  ('화평', 2),
#  ('표절', 2),
#  ('긍정', 2),
#  ('도시락', 2),
#  ('배두나', 2),
#  ('기무라', 2),
#  ('어쩐지', 2),
#  ('코난', 2),
#  ('중국', 2),
#  ('위협', 2),
#  ('소화', 2),
#  ('코스트', 2),
#  ('파파로티', 2),
#  ('마블', 2),
#  ('인어공주', 2),
#  ('연성', 2),
#  ('신하균', 2),
#  ('향연', 2),
#  ('실력', 2),
#  ('니키', 2),
#  ('시사', 2),
#  ('김동욱', 2),
#  ('압축', 2),
#  ('무진장', 2),
#  ('조승우', 2),
#  ('전투씬', 2),
#  ('여름', 2),
#  ('예측', 2)]

# %%
dic = dict(tags)
dic
# Out:
# {'영화': 985,
#  '정말': 265,
#  '최고': 230,
#  '진짜': 184,
#  '감동': 155,
#  '연기': 142,
#  '생각': 140,
#  '드라마': 121,
#  '보고': 119,
#  '사람': 110,
#  '평점': 103,
#  '다시': 94,
#  '마지막': 80,
#  '사랑': 78,
#  '스토리': 69,
#  '작품': 67,
#  '지금': 66,
#  '배우': 65,
#  '명작': 61,
#  '재미': 59,
#  '마음': 56,
#  '하나': 54,
#  '완전': 53,
#  '이영화': 52,
#  '추천': 50,
#  '장면': 49,
#  '매력': 49,
#  '느낌': 47,
#  '감독': 47,
#  '내용': 46,
#  '현실': 46,
#  '액션': 45,
#  '이야기': 43,
#  '그냥': 43,
#  '가슴': 43,
#  '주인공': 42,
#  '정도': 42,
#  '이해': 40,
#  '한번': 40,
#  '인생': 38,
#  '역시': 37,
#  '음악': 37,
#  '처음': 36,
#  '기억': 35,
#  '여운': 35,
#  '남자': 34,
#  '눈물': 34,
#  '우리': 34,
#  '인간': 33,
#  '시간': 33,
#  '대박': 32,
#  '한국': 32,
#  '결말': 30,
#  '가족': 30,
#  '모습': 29,
#  '연기력': 29,
#  '최고다': 27,
#  '대한': 26,
#  '영상': 26,
#  '보기': 26,
#  '아이': 26,
#  '가장': 26,
#  '소재': 25,
#  '모든': 25,
#  '연출': 25,
#  '여자': 25,
#  '시리즈': 24,
#  '모두': 24,
#  '개인': 24,
#  '부분': 24,
#  '반전': 23,
#  '때문': 23,
#  '계속': 23,
#  '무엇': 23,
#  '당시': 22,
#  '공감': 22,
#  '긴장감': 21,
#  '자신': 21,
#  '이건': 21,
#  '사실': 20,
#  '몰입': 20,
#  '전쟁': 20,
#  '기대': 20,
#  '대해': 20,
#  '그녀': 20,
#  '오늘': 20,
#  '강추': 19,
#  '캐릭터': 19,
#  '뭔가': 19,
#  '노래': 19,
#  '세상': 19,
#  '아주': 19,
#  '감정': 18,
#  '수작': 18,
#  '한국영': 18,
#  '중간': 18,
#  '제목': 18,
#  '표현': 18,
#  '코미디': 18,
#  '엔딩': 18,
#  '이상': 18,
#  '간만': 18,
#  '실화': 17,
#  '요즘': 17,
#  '후회': 17,
#  '기분': 17,
#  '제일': 17,
#  '엄마': 17,
#  '추억': 17,
#  '애니': 17,
#  '배경': 17,
#  '코믹': 17,
#  '라면': 16,
#  '제대로': 16,
#  '스릴러': 16,
#  '친구': 16,
#  '내내': 16,
#  '별로': 16,
#  '웃음': 16,
#  '나이': 15,
#  '조금': 15,
#  '개봉': 15,
#  '재밋': 15,
#  '소름': 15,
#  '몰입도': 15,
#  '티비': 14,
#  '성룡': 14,
#  '만점': 14,
#  '사회': 14,
#  '걸작': 14,
#  '웃기': 14,
#  '인상': 14,
#  '약간': 14,
#  '다운': 14,
#  '기도': 14,
#  '보지': 14,
#  '스릴': 13,
#  '매우': 13,
#  '원작': 13,
#  '절대': 13,
#  '전혀': 13,
#  '나름': 13,
#  '대사': 13,
#  '예술': 13,
#  '공포': 12,
#  '갈수록': 12,
#  '언제': 12,
#  '실제': 12,
#  '다른': 12,
#  '완성': 12,
#  '진심': 12,
#  '영화관': 12,
#  '레전드': 12,
#  '가지': 12,
#  '더욱': 11,
#  '다큐': 11,
#  '당신': 11,
#  '초딩': 11,
#  '이유': 11,
#  '얘기': 11,
#  '재밋다': 11,
#  '혼자': 11,
#  '짱짱': 11,
#  '전개': 11,
#  '감명': 11,
#  '위해': 11,
#  '시절': 10,
#  '존재': 10,
#  '얼굴': 10,
#  '이제': 10,
#  '이름': 10,
#  '한마디': 10,
#  '꿀잼': 10,
#  '아버지': 10,
#  '의미': 10,
#  '아픔': 10,
#  '희망': 10,
#  '이후': 10,
#  '분위기': 10,
#  '극장': 10,
#  '제작': 10,
#  '통해': 9,
#  '우리나라': 9,
#  '화이팅': 9,
#  '충격': 9,
#  '어디': 9,
#  '여배우': 9,
#  '흥미진진': 9,
#  '시작': 9,
#  '선택': 9,
#  '자꾸': 9,
#  '얼마나': 9,
#  '그대로': 9,
#  '관람': 9,
#  '세계': 9,
#  '목소리': 9,
#  '집중': 9,
#  '발견': 9,
#  '자연': 9,
#  '영화로': 9,
#  '구성': 9,
#  '아들': 9,
#  '자체': 9,
#  '정신': 9,
#  '애니메이션': 9,
#  '편이': 9,
#  '박수': 9,
#  '수준': 9,
#  '문제': 9,
#  '감상': 9,
#  '감성': 9,
#  '시대': 9,
#  '출연': 9,
#  '대한민국': 8,
#  '순간': 8,
#  '바로': 8,
#  '의리': 8,
#  '역사': 8,
#  '비디오': 8,
#  '다음': 8,
#  '초반': 8,
#  '뮤지컬': 8,
#  '옛날': 8,
#  '다만': 8,
#  '안보': 8,
#  '무비': 8,
#  '질리': 8,
#  '미국': 8,
#  '거의': 8,
#  '압도': 8,
#  '가끔': 8,
#  '전달': 8,
#  '소설': 8,
#  '시즌': 8,
#  '어린시절': 8,
#  '남성': 8,
#  '심리': 8,
#  '장난': 8,
#  '평가': 8,
#  '작가': 8,
#  '천재': 8,
#  '영화인': 8,
#  '행복': 8,
#  '대안': 8,
#  '킬링타임': 8,
#  '열정': 7,
#  '오페라': 7,
#  '일본': 7,
#  '비판': 7,
#  '그것': 7,
#  '미소': 7,
#  '인정': 7,
#  '평생': 7,
#  '쓰레기': 7,
#  '본방': 7,
#  '벌써': 7,
#  '퀄리티': 7,
#  '예전': 7,
#  '장르': 7,
#  '또한': 7,
#  '쵝오': 7,
#  '시나리오': 7,
#  '이번': 7,
#  '거지': 7,
#  '더빙': 7,
#  '이자': 7,
#  '무척': 7,
#  '국민': 7,
#  '액션영화': 7,
#  '나라': 7,
#  '동물': 7,
#  '누가': 7,
#  '로맨스': 7,
#  '개그': 7,
#  '연애': 7,
#  '표정': 7,
#  '로봇': 7,
#  '그때': 7,
#  '상영': 7,
#  '볼때': 7,
#  '인물': 7,
#  '평론가': 7,
#  '누구': 7,
#  '청춘': 7,
#  '만하': 7,
#  '포스터': 7,
#  '비교': 7,
#  '몇번': 7,
#  '교훈': 7,
#  '영웅': 7,
#  '메시지': 7,
#  '발전': 6,
#  '로버트': 6,
#  '수가': 6,
#  '우정': 6,
#  '어머니': 6,
#  '권력': 6,
#  '사수': 6,
#  '덕분': 6,
#  '세기': 6,
#  '형님': 6,
#  '미래': 6,
#  '어찌': 6,
#  '명화': 6,
#  '역대': 6,
#  '자막': 6,
#  '스타': 6,
#  '첫사랑': 6,
#  '힐링': 6,
#  '짜임새': 6,
#  '방송': 6,
#  '역할': 6,
#  '말로': 6,
#  '눈빛': 6,
#  '비극': 6,
#  '아빠': 6,
#  '환상': 6,
#  '리얼': 6,
#  '그게': 6,
#  '전체': 6,
#  '색감': 6,
#  '화가': 6,
#  '활약': 6,
#  '남녀': 6,
#  '과거': 6,
#  '고양이': 6,
#  '상상': 6,
#  '자유': 6,
#  '은근': 6,
#  '느와르': 6,
#  '잘만': 6,
#  '응원': 6,
#  '야마': 6,
#  '여행': 6,
#  '지배': 6,
#  '진실': 6,
#  '점주': 6,
#  '영환': 6,
#  '일상': 6,
#  '지난': 6,
#  '줄거리': 6,
#  '진정': 6,
#  '해피엔딩': 6,
#  '이란': 6,
#  '카메라': 6,
#  '네이버': 6,
#  '무조건': 6,
#  '노력': 6,
#  '위로': 6,
#  '대작': 6,
#  '만화': 6,
#  '형제': 6,
#  '학교': 6,
#  '카리스마': 6,
#  '깊이': 6,
#  '해석': 6,
#  '배트맨': 6,
#  '단지': 6,
#  '노출': 6,
#  '주윤발': 6,
#  '의심': 6,
#  '취향': 6,
#  '연인': 6,
#  '영어': 6,
#  '학생': 5,
#  '전통': 5,
#  '부터': 5,
#  '일품': 5,
#  '드니': 5,
#  '마치': 5,
#  '런가': 5,
#  '목숨': 5,
#  '용이': 5,
#  '감탄': 5,
#  '로서': 5,
#  '조합': 5,
#  '연기자': 5,
#  '마이': 5,
#  '정치': 5,
#  '묘사': 5,
#  '흥행': 5,
#  '최고봉': 5,
#  '한편': 5,
#  '절로': 5,
#  '바람': 5,
#  '명품': 5,
#  '죽음': 5,
#  '일지': 5,
#  '멜로': 5,
#  '프랑스': 5,
#  '특유': 5,
#  '나중': 5,
#  '반성': 5,
#  '슬픔': 5,
#  '상상력': 5,
#  '몽환': 5,
#  '실감': 5,
#  '새끼': 5,
#  '재난영화': 5,
#  '에피소드': 5,
#  '과연': 5,
#  '아저씨': 5,
#  '점수': 5,
#  '그림': 5,
#  '엄정화': 5,
#  '한순간': 5,
#  '좀비': 5,
#  '극장판': 5,
#  '강력': 5,
#  '과정': 5,
#  '항상': 5,
#  '국내': 5,
#  '아무': 5,
#  '니콜': 5,
#  '주성치': 5,
#  '효과': 5,
#  '도라에몽': 5,
#  '폭발': 5,
#  '결혼': 5,
#  '키드': 5,
#  '수도': 5,
#  '신경': 5,
#  '전설': 5,
#  '현재': 5,
#  '전율': 5,
#  '조니뎁': 5,
#  '거리': 5,
#  '머리': 5,
#  '자극': 5,
#  '용기': 5,
#  '상처': 5,
#  '이선균': 5,
#  '상미': 5,
#  '케이블': 5,
#  '게다가': 5,
#  '점점': 5,
#  '블랙': 5,
#  '먼저': 5,
#  '어른': 5,
#  '어제': 5,
#  '타임': 5,
#  '최민식': 5,
#  '공포영화': 5,
#  '김민희': 5,
#  '시청률': 5,
#  '간다': 5,
#  '철학': 5,
#  '괴물': 5,
#  '후반': 5,
#  '희생': 5,
#  '마이클': 5,
#  '영화사': 5,
#  '문화': 4,
#  '바보': 4,
#  '가면': 4,
#  '범죄': 4,
#  '여러': 4,
#  '공간': 4,
#  '동안': 4,
#  '대체': 4,
#  '바다': 4,
#  '정의': 4,
#  '화보': 4,
#  '그대': 4,
#  '아이돌': 4,
#  '다소': 4,
#  '끼리': 4,
#  '애기': 4,
#  '달달': 4,
#  '일단': 4,
#  '양심': 4,
#  '폭력': 4,
#  '성격': 4,
#  '판타지': 4,
#  '예상': 4,
#  '심정': 4,
#  '한석규': 4,
#  '원래': 4,
#  '보구': 4,
#  '요리': 4,
#  '일이': 4,
#  '아쉬움': 4,
#  '어쩌면': 4,
#  '신념': 4,
#  '심장': 4,
#  '전쟁영화': 4,
#  '존경': 4,
#  '리메이크': 4,
#  '여신': 4,
#  '자리': 4,
#  '코드': 4,
#  '반영': 4,
#  '여주': 4,
#  '시기': 4,
#  '주제': 4,
#  '케미': 4,
#  '동화': 4,
#  '주연': 4,
#  '폭풍': 4,
#  '래야': 4,
#  '박중훈': 4,
#  '편견': 4,
#  '방금': 4,
#  '선생님': 4,
#  '요소': 4,
#  '이전': 4,
#  '감히': 4,
#  '주의': 4,
#  '로맨틱': 4,
#  '상대': 4,
#  '낫다': 4,
#  '관점': 4,
#  '젊은이': 4,
#  '다해': 4,
#  '검색': 4,
#  '세트': 4,
#  '재밋는데': 4,
#  '화면': 4,
#  '편도': 4,
#  '리즈시절': 4,
#  '오락': 4,
#  '고민': 4,
#  '관계': 4,
#  '덴젤': 4,
#  '헐리웃': 4,
#  '고인': 4,
#  '전문가': 4,
#  '근원': 4,
#  '시각': 4,
#  '무슨': 4,
#  '가치': 4,
#  '낭만': 4,
#  '소장': 4,
#  '무언가': 4,
#  '매니아': 4,
#  '케빈': 4,
#  '알바': 4,
#  '정우성': 4,
#  '역작': 4,
#  '스님': 4,
#  '아내': 4,
#  '정석': 4,
#  '다행': 4,
#  '하나로': 4,
#  '설명': 4,
#  '웅장': 4,
#  '해도': 4,
#  '누군가': 4,
#  '하루': 4,
#  '각본': 4,
#  '교과서': 4,
#  '대표': 4,
#  '자기': 4,
#  '절망': 4,
#  '잡고': 4,
#  '스타일': 4,
#  '두려움': 4,
#  '욕심': 4,
#  '지식': 4,
#  '동생': 4,
#  '여기': 4,
#  '찾기': 4,
#  '재밋음': 4,
#  '이연걸': 4,
#  '할아버지': 4,
#  '직접': 4,
#  '편의': 4,
#  '새벽': 4,
#  '무간도': 4,
#  '송강호': 4,
#  '다큐멘터리': 4,
#  '시트콤': 4,
#  '재밋어': 4,
#  '방영': 4,
#  '제임스': 4,
#  '불구': 4,
#  '도대체': 4,
#  '박진': 4,
#  '오멘': 4,
#  '전편': 4,
#  '광녀': 4,
#  '단연': 3,
#  '마디': 3,
#  '제니퍼': 3,
#  '제발': 3,
#  '조연': 3,
#  '노동자': 3,
#  '북한': 3,
#  '여러가지': 3,
#  '채널': 3,
#  '배경음악': 3,
#  '커서': 3,
#  '안나': 3,
#  '설정': 3,
#  '의외': 3,
#  '허니': 3,
#  '팬텀': 3,
#  '처럼': 3,
#  '남편': 3,
#  '바비': 3,
#  '바스코': 3,
#  '결과': 3,
#  '사극': 3,
#  '그날': 3,
#  '슈퍼': 3,
#  '메이드': 3,
#  '기쁨': 3,
#  '의지': 3,
#  '전형': 3,
#  '욕망': 3,
#  '명대사': 3,
#  '제왕': 3,
#  '보신': 3,
#  '만화영화': 3,
#  '신분': 3,
#  '라이언': 3,
#  '용도': 3,
#  '여유': 3,
#  '의문': 3,
#  '갈등': 3,
#  '서로': 3,
#  '소녀시대': 3,
#  '잘못': 3,
#  '송지효': 3,
#  '싸이코': 3,
#  '사람과': 3,
#  '터미네이터': 3,
#  '올해': 3,
#  '차태현': 3,
#  '스스로': 3,
#  '미드': 3,
#  '캐스팅': 3,
#  '문채원': 3,
#  '대부분': 3,
#  '미가': 3,
#  '건가': 3,
#  '키스신': 3,
#  '예수님': 3,
#  '패전': 3,
#  '처리': 3,
#  '전문': 3,
#  '이기': 3,
#  '본인': 3,
#  '진행': 3,
#  '갑자기': 3,
#  '상태': 3,
#  '일리': 3,
#  '등등': 3,
#  '초점': 3,
#  '최상': 3,
#  '특징': 3,
#  '울면': 3,
#  '구속': 3,
#  '게이': 3,
#  '마무리': 3,
#  '펑펑': 3,
#  '엉엉': 3,
#  '야구': 3,
#  '에리': 3,
#  '색채': 3,
#  '놀란': 3,
#  '재밋네': 3,
#  '지연': 3,
#  '공주': 3,
#  '안감': 3,
#  '스케일': 3,
#  '왜케': 3,
#  '모험': 3,
#  '장동건': 3,
#  '할머니': 3,
#  '소리': 3,
#  '성공': 3,
#  '정화': 3,
#  '구조': 3,
#  '열연': 3,
#  '이면': 3,
#  '흡입': 3,
#  '침묵': 3,
#  '선사': 3,
#  '분노': 3,
#  '배종옥': 3,
#  '살기': 3,
#  '동시': 3,
#  '자식': 3,
#  '방식': 3,
#  '평균': 3,
#  '단어': 3,
#  '조재현': 3,
#  '기적': 3,
#  '강시': 3,
#  '종교': 3,
#  '로만': 3,
#  '변화': 3,
#  '근래': 3,
#  '여성': 3,
#  '한국인': 3,
#  '초기': 3,
#  '살인': 3,
#  '메세지': 3,
#  '흥분': 3,
#  '화중': 3,
#  '탄생': 3,
#  '손색': 3,
#  '개구쟁이': 3,
#  '스머프': 3,
#  '김기덕': 3,
#  '소개': 3,
#  '무한': 3,
#  '사도': 3,
#  '신의': 3,
#  '사진': 3,
#  '세월': 3,
#  '미니시리즈': 3,
#  '언니': 3,
#  '명장': 3,
#  '이성민': 3,
#  '부모': 3,
#  '겨울': 3,
#  '이보': 3,
#  '성장': 3,
#  '공리': 3,
#  '신인': 3,
#  '가능성': 3,
#  '심은경': 3,
#  '감각': 3,
#  '오오오오': 3,
#  '홍콩': 3,
#  '히어로': 3,
#  '방법': 3,
#  '토니': 3,
#  '막장': 3,
#  '무대': 3,
#  '진작': 3,
#  '러닝': 3,
#  '으리': 3,
#  '실망': 3,
#  '반드시': 3,
#  '광고': 3,
#  '관객': 3,
#  '백배': 3,
#  '고독': 3,
#  '토이스토리': 3,
#  '도안': 3,
#  '질서': 3,
#  '피디': 3,
#  '포스': 3,
#  '오히려': 3,
#  '주변': 3,
#  '지루함': 3,
#  '일반': 3,
#  '인기': 3,
#  '닥치고': 3,
#  '고뇌': 3,
#  '남아': 3,
#  '한참': 3,
#  '만남': 3,
#  '전의': 3,
#  '속편': 3,
#  '스피드': 3,
#  '소녀': 3,
#  '그린': 3,
#  '독립영화': 3,
#  '잼슴': 3,
#  '케릭': 3,
#  '사라': 3,
#  '이만': 3,
#  '무지': 3,
#  '본질': 3,
#  '마리': 3,
#  '긴장': 3,
#  '공효진': 3,
#  '는걸': 3,
#  '강마': 3,
#  '주지': 3,
#  '압권': 3,
#  '공포물': 3,
#  '뇌리': 3,
#  '아아': 3,
#  '최선': 3,
#  '버튼': 3,
#  '조폭': 3,
#  '주원': 3,
#  '전개도': 3,
#  '보이': 3,
#  '로코': 3,
#  '설마': 3,
#  '행크스': 3,
#  '로드무비': 3,
#  '재미나': 3,
#  '이지': 3,
#  '전성기': 3,
#  '일찍': 3,
#  '안이': 3,
#  '조화': 3,
#  '평화': 3,
#  '유덕화': 3,
#  '상황': 3,
#  '산업': 2,
#  '안개': 2,
#  '사하나': 2,
#  '전장': 2,
#  '관련': 2,
#  '임팩트': 2,
#  '미처': 2,
#  '전하': 2,
#  '형태': 2,
#  '용서': 2,
#  '잠도': 2,
#  '일어나서': 2,
#  '이정재': 2,
#  '질렌할': 2,
#  '입가': 2,
#  '콜트': 2,
#  '브라질': 2,
#  '그거': 2,
#  '종북': 2,
#  '미도': 2,
#  '순위': 2,
#  '전작': 2,
#  '명감': 2,
#  '제리': 2,
#  '메이커': 2,
#  '대의': 2,
#  '예능': 2,
#  '방학': 2,
#  '요새': 2,
#  '수백향': 2,
#  '가을': 2,
#  '장국영': 2,
#  '자살': 2,
#  '뀰잼': 2,
#  '보호': 2,
#  '걱정': 2,
#  '청소년': 2,
#  '우상': 2,
#  '죄책감': 2,
#  '디테': 2,
#  '수록': 2,
#  '다그': 2,
#  '메이': 2,
#  '봣음': 2,
#  '훈남': 2,
#  '크리스틴': 2,
#  '알파': 2,
#  '치노': 2,
#  '명의': 2,
#  '이서': 2,
#  '연말': 2,
#  '무사': 2,
#  '물결': 2,
#  '배심원': 2,
#  '연설': 2,
#  '애정': 2,
#  '이민호': 2,
#  '고도': 2,
#  '류승범': 2,
#  '황정민': 2,
#  '절제': 2,
#  '거임': 2,
#  '정부': 2,
#  '이정현': 2,
#  '된거': 2,
#  '점도': 2,
#  '버금': 2,
#  '결코': 2,
#  '정일우': 2,
#  '반지': 2,
#  '녹화': 2,
#  '무협': 2,
#  '추강': 2,
#  '향수': 2,
#  '미모': 2,
#  '연속': 2,
#  '러브': 2,
#  '스타워즈': 2,
#  '외로움': 2,
#  '로써': 2,
#  '내생': 2,
#  '여명': 2,
#  '해지': 2,
#  '윤아': 2,
#  '박한별': 2,
#  '몸매': 2,
#  '간직': 2,
#  '리가': 2,
#  '모슬렘': 2,
#  '신고': 2,
#  '행운': 2,
#  '휴식': 2,
#  '난리': 2,
#  '강아지': 2,
#  '흐름': 2,
#  '동전': 2,
#  '양면': 2,
#  '매일': 2,
#  '지오': 2,
#  '막시무스': 2,
#  '미화': 2,
#  '생명': 2,
#  '정해': 2,
#  '가까이': 2,
#  '위트': 2,
#  '중학교': 2,
#  '재난': 2,
#  '아치': 2,
#  '조음': 2,
#  '박유천': 2,
#  '한지민': 2,
#  '최진희': 2,
#  '중국영화': 2,
#  '번은': 2,
#  '하정우': 2,
#  '의사': 2,
#  '모던': 2,
#  '감사용': 2,
#  '투수': 2,
#  '콘서트': 2,
#  '헌신': 2,
#  '운명': 2,
#  '홍콩영화': 2,
#  '경의': 2,
#  '만큼': 2,
#  '연민': 2,
#  '벤자민': 2,
#  '장거리': 2,
#  '도시': 2,
#  '한장': 2,
#  '트포': 2,
#  '대장': 2,
#  '기술': 2,
#  '주말': 2,
#  '커플': 2,
#  '결정': 2,
#  '동양인': 2,
#  '하자': 2,
#  '유지': 2,
#  '목적': 2,
#  '봣어': 2,
#  '인형': 2,
#  '영화음악': 2,
#  '라인': 2,
#  '회상': 2,
#  '흥미': 2,
#  '보시': 2,
#  '다가': 2,
#  '거짓말': 2,
#  '살때': 2,
#  '등장': 2,
#  '거기': 2,
#  '권상우': 2,
#  '동성애자': 2,
#  '녀석': 2,
#  '중반': 2,
#  '러브스토리': 2,
#  '생활': 2,
#  '스포츠': 2,
#  '스푼': 2,
#  '카츠': 2,
#  '지니어스': 2,
#  '휴먼': 2,
#  '창의': 2,
#  '홧팅': 2,
#  '실험': 2,
#  '어린이날': 2,
#  '동심': 2,
#  '명복': 2,
#  '욀케': 2,
#  '독재자': 2,
#  '주먹': 2,
#  '단점': 2,
#  '안성기': 2,
#  '베니': 2,
#  '화평': 2,
#  '표절': 2,
#  '긍정': 2,
#  '도시락': 2,
#  '배두나': 2,
#  '기무라': 2,
#  '어쩐지': 2,
#  '코난': 2,
#  '중국': 2,
#  '위협': 2,
#  '소화': 2,
#  '코스트': 2,
#  '파파로티': 2,
#  '마블': 2,
#  '인어공주': 2,
#  '연성': 2,
#  '신하균': 2,
#  '향연': 2,
#  '실력': 2,
#  '니키': 2,
#  '시사': 2,
#  '김동욱': 2,
#  '압축': 2,
#  '무진장': 2,
#  '조승우': 2,
#  '전투씬': 2,
#  '여름': 2,
#  '예측': 2}

# %%
image_file = 'alice.png'
img_file = Image.open(image_file)
alice_mask = np.array(img_file)

plt.figure(figsize=(8,8))
plt.imshow(alice_mask)
plt.axis('off')
# Out:
# (-0.5, 595.5, 638.5, -0.5)

# %%
wordcloud = WordCloud(font_path='나눔손글씨 버드나무.ttf', background_color='white', max_words=1000, mask=alice_mask)
wc = WordCloud.generate(str(tags))
plt.figure(figsize=(10,10))
plt.imshow(wc)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Study\AI\2주차\5일차\한국어 형태소.ipynb 셀 13 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Study/AI/2%EC%A3%BC%EC%B0%A8/5%EC%9D%BC%EC%B0%A8/%ED%95%9C%EA%B5%AD%EC%96%B4%20%ED%98%95%ED%83%9C%EC%86%8C.ipynb#X16sZmlsZQ%3D%3D?line=0'>1</a> wordcloud = WordCloud(font_path='나눔손글씨 버드나무.ttf', background_color='white', max_words=1000, mask=alice_mask)
# ----> <a href='vscode-notebook-cell:/c%3A/Study/AI/2%EC%A3%BC%EC%B0%A8/5%EC%9D%BC%EC%B0%A8/%ED%95%9C%EA%B5%AD%EC%96%B4%20%ED%98%95%ED%83%9C%EC%86%8C.ipynb#X16sZmlsZQ%3D%3D?line=1'>2</a> wc = WordCloud.generate(str(tags))
#       <a href='vscode-notebook-cell:/c%3A/Study/AI/2%EC%A3%BC%EC%B0%A8/5%EC%9D%BC%EC%B0%A8/%ED%95%9C%EA%B5%AD%EC%96%B4%20%ED%98%95%ED%83%9C%EC%86%8C.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(10,10))
#       <a href='vscode-notebook-cell:/c%3A/Study/AI/2%EC%A3%BC%EC%B0%A8/5%EC%9D%BC%EC%B0%A8/%ED%95%9C%EA%B5%AD%EC%96%B4%20%ED%98%95%ED%83%9C%EC%86%8C.ipynb#X16sZmlsZQ%3D%3D?line=3'>4</a> plt.imshow(wc)
#
# TypeError: generate() missing 1 required positional argument: 'text'
